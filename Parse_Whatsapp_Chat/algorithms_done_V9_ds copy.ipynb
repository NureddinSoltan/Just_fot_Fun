# %% [markdown]
# # Part 1: Function to Parse WhatsApp Chat for Task Completion

# %%
import re
from datetime import datetime, date  # Importing date to use date.today()

def parse_task_completion_and_additions(file_path, start_date, end_date):
    """
    Read the WhatsApp file path, handle the date format, convert start and end dates to determine object,
    use regex to capture the date, time, user, and message. Additionally, capture user additions.
    """
    # Set to store users who have sent 'done', 'dn', or 'تم'
    done_users = set()
    
    # Set to store users who were added or who added someone
    added_users = set()
    added_by_others = set()

    # Read the WhatsApp file
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # format (dd.mm.yyyy)
    date_format = '%d.%m.%Y'

    # Convert the start and end dates to datetime objects
    start_date = datetime.strptime(start_date, date_format).date()
    end_date = datetime.strptime(end_date, date_format).date()

    # Regex patterns
    # message_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
    # added_pattern = re.compile(r'~\s*(.*?) was added')
    # added_by_pattern = re.compile(r'~\s*(.*?) added ~\s*(.*)')
    message_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
    added_pattern = re.compile(r'~\s*(.*?) was added')
    added_by_pattern = re.compile(r'~\s*(.*?) added ~\s*(.*)')
    join_from_community_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*) joined from the community')



    current_user = None
    current_message = ""

    for line in lines:
        match = message_pattern.match(line)
        join_match = join_from_community_pattern.match(line)

        if match:
            # If there's a new match, process the previous message before resetting
            if current_user and current_message:
                # Process the previous message for task completion
                cleaned_message = current_message.strip().lower()
                if ('done' in cleaned_message or 
                    'dn' in cleaned_message or 
                    '✅' in cleaned_message or
                    'done✅' in cleaned_message or
                    'done' in cleaned_message or
                    'تم ' in cleaned_message or
                    'ضن' in cleaned_message or
                    re.search(r'\bتم\b', cleaned_message) or 
                    cleaned_message == 'تم' or 
                    'تم' in cleaned_message):
                    done_users.add(current_user)

            # Start a new message
            date_str, time_str, user, message = match.groups()
            current_user = user.strip()
            current_message = message.strip()

            # Convert message date to a date object and check if within date range
            message_date = datetime.strptime(date_str, date_format).date()

            if not (start_date <= message_date <= end_date):
                current_user = None  # Ignore this message if it's not in the date range
                current_message = ""
                continue

            # Check for added users or users added by someone
            added_match = added_pattern.search(current_message)
            added_by_match = added_by_pattern.search(current_message)

            if added_match:
                added_user = added_match.group(1).strip()
                added_users.add(added_user)

            if added_by_match:
                added_by = added_by_match.group(1).strip()
                added_user = added_by_match.group(2).strip()
                added_users.add(added_user)
                added_by_others.add(added_by)
                
            elif join_match:
                # Process the "joined from the community" message
                date_str, time_str, user, _ = join_match.groups()
                user = user.strip()
                added_users.add(user)

        else:
            # If no match, it means this is a continuation of the current message (multi-line)
            current_message += " " + line.strip()

    # Process the last message after the loop ends
    if current_user and current_message:
        cleaned_message = current_message.strip().lower()
        if ('done' in cleaned_message or 
            'dn' in cleaned_message or 
            '✅' in cleaned_message or
            'done✅' in cleaned_message or
            'done' in cleaned_message or
            'تم ' in cleaned_message or
            'ضن' in cleaned_message or
            re.search(r'\bتم\b', cleaned_message) or 
            cleaned_message == 'تم' or 
            'تم' in cleaned_message):
            done_users.add(current_user)

    return done_users, added_users, added_by_others

# %% [markdown]
# # Part 2: Compare Group Members with Task Completion

# %%
def compare_group_with_done_users_and_added(done_users, added_users, added_by_others):
    """
    Comparing the list of groups that I got from 18.08.2024 (after the deadline one) until now.
    And find the user that didn't match with the existing user that send from 26.08.2024 (deadline 3)
    Also prints added users and who added them.
    """
    # Full list of group members provided
    group_members = {
"* PS",
".",
"..",
"3bnaby",
"Abdelfattah Mohamed",
"Abdelrahman Adel PS",
"Abdulrhman Ahmed PS",
"Ahmad Zanaty",
"Ahmed Elkassrawy PS",
"Ahmed Mahmoud Dabour",
"Ahmed Mohamed PS",
"Ahmed Mounir PS",
"Ahmed Salman PS",
"Ali Ismail",
"Ali PS",
"Amany Mohammed PS",
"Amina",
"Amina PS",
"Aysha",
"Big_O PS",
"David PS",
"Elknz PS",
"Eman Ashraf PS",
"Eng Mo _ Atia",
"Esraa Elzehery",
"Esraa Salah",
"Gehad",
"Habiba Gamal PS",
"Hajer",
"Hasnaa PS",
"Hesham Elsayed PS",
"Hesham Hatem",
"Hüsam",
"Ibrahim Atef Eltahlawy 🇵🇸",
"Islam PS",
"Jehad Amjad",
"KHALED",
"Karema PS",
"Karim PS",
"Kholoud",
"MS",
"Mahmoud Salem",
"Mahmoud 🔴🔵⚽",
"Mariam Elgazzar",
"Mariam Osman PS",
"Marwa PS",
"Menna Seif",
"Merna",
"Minno PS",
"Mo7 Shdw PS",
"Mo7amed Galal PS",
"Mohamed",
"Mohamed PS",
"Mohamed Rabee PS",
"Mostafa Medhat PS",
"Mostafa Sayed",
"Nada Abdelghaffar PS",
"Nariman Awny",
"Ola",
"Omar",
"Omar Nabil PS",
"Omar Sayed",
"Omnia Ashraf PS",
"Omnia PS",
"Os!Rabe3 PS",
"PS",
"PS-StudyingDS 📔",
"Professor 👤",
"Radwan",
"Rawan",
"Reham Galal",
"Salah Mohamed Twtr",
"Salma",
"Salma Abdelkarim",
"Salma PS",
"Seif",
"Shady",
"Shahd Hamdi",
"Shahd Tamer PS",
"Shaimaa",
"Shaimaa Fikry",
"TAREK PS",
"Taha Shaban",
"Tarek PS",
"Tasneem",
"Xo_Sh3r11f",
"Yos S3D Twtr",
"Younes PS",
"Zeyad PS",
"Ziad Nasser PS",
"Zoe💜",
"alaafahiem",
"amenasaad83",
"hager ashraf",
"hussien",
"mahmoudasal",
"~ Ahmed",
"إسراء",
"رَحْمَة أَمِينٍ",
"رُفَيده سَعْد PS",
"غادة PS",
"محمد بن محمود الهواري",
"محمود محمد PS",
"ميخا PS",
"ّّّّّّّّّّّّّّّّّّّّّّّّّ",
"‎You",
"›› 라니아 ‹‹",
"☆아말☆أمل PS",
"𓂆 PS",
"𝑫𝑶𝑯𝑨",
}


    # Find users in the group who have not completed the task
    not_done_users = group_members - done_users

    # Output users who did NOT complete the task
    print("\nUsers who did NOT complete the task:")
    if not_done_users:
        for user in sorted(not_done_users):
            print(user)
    else:
        print("All users completed the task.")

    print("\n==================================")
    print("\nUsers who completed the task:")
    for user in sorted(done_users):
        print(user)

    # Output users who were added to the group
    print("\n==================================")
    print("\nUsers who were added to the group:")
    for user in sorted(added_users):
        print(user)

    # Output users who added others to the group
    print("\n==================================")
    print("\nUsers who added someone to the group:")
    for user in sorted(added_by_others):
        print(user)

# %% [markdown]
# # Part 3: Main Function

# %%
def main():
    """Main Function to apply all the functions written above"""
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_9_DS.txt'

    # Specify the date range (start date and end date)
    start_date = '01.12.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract users who completed the task between the start and end date
    done_users, added_users, added_by_others = parse_task_completion_and_additions(file_path, start_date, end_date)

    # Compare the task completion with the full list of group members and output added users
    compare_group_with_done_users_and_added(done_users, added_users, added_by_others)

if __name__ == '__main__':
    main()
# Out:
# Users who did NOT complete the task:
# .
# ..
# Abdelfattah Mohamed
# Abdulrhman Ahmed PS
# Amina
# Amina PS
# David PS
# Eng Mo _ Atia
# Esraa Elzehery
# Esraa Salah
# Gehad
# Habiba Gamal PS
# Hajer
# Hasnaa PS
# Hesham Elsayed PS
# Ibrahim Atef Eltahlawy 🇵🇸
# Islam PS
# Jehad Amjad
# Kholoud
# Mahmoud 🔴🔵⚽
# Marwa PS
# Menna Seif
# Merna
# Mohamed
# Nariman Awny
# Ola
# Omar
# PS-StudyingDS 📔
# Professor 👤
# Rawan
# Salma Abdelkarim
# Shaimaa Fikry
# Taha Shaban
# Tarek PS
# Tasneem
# Xo_Sh3r11f
# Younes PS
# Ziad Nasser PS
# alaafahiem
# إسراء
# رَحْمَة أَمِينٍ
# غادة PS
# ّّّّّّّّّّّّّّّّّّّّّّّّّ
# ‎You
#
# ==================================
#
# Users who completed the task:
# * PS
# 3bnaby
# Abdelrahman Adel PS
# Ahmad Zanaty
# Ahmed Elkassrawy PS
# Ahmed Mahmoud Dabour
# Ahmed Mohamed PS
# Ahmed Mounir PS
# Ahmed Salman PS
# Ali Ismail
# Ali PS
# Amany Mohammed PS
# Aysha
# Big_O PS
# Elknz PS
# Eman Ashraf PS
# Hesham Hatem
# Hüsam
# KHALED
# Karema PS
# Karim PS
# MS
# Mahmoud Salem
# Mariam Elgazzar
# Mariam Osman PS
# Minno PS
# Mo7 Shdw PS
# Mo7amed Galal PS
# Mohamed PS
# Mohamed Rabee PS
# Mostafa Medhat PS
# Mostafa Sayed
# Nada Abdelghaffar PS
# Omar Nabil PS
# Omar Sayed
# Omnia Ashraf PS
# Omnia PS
# Os!Rabe3 PS
# PS
# Radwan
# Reham Galal
# Salah Mohamed Twtr
# Salma
# Salma PS
# Seif
# Shady
# Shahd Hamdi
# Shahd Tamer PS
# Shaimaa
# TAREK PS
# Yos S3D Twtr
# Zeyad PS
# Zoe💜
# amenasaad83
# hager ashraf
# hussien
# mahmoudasal
# ~ Ahmed
# رُفَيده سَعْد PS
# محمد بن محمود الهواري
# محمود محمد PS
# ميخا PS
# ›› 라니아 ‹‹
# ☆아말☆أمل PS
# 𓂆 PS
# 𝑫𝑶𝑯𝑨
#
# ==================================
#
# Users who were added to the group:
# Mahmoud Salem
# Salma Abdelkarim
# mahmoudasal
#
# ==================================
#
# Users who added someone to the group:

# %% [markdown]
# # PART4: Generate a list of Group-members
# ### `(with a specific date until now)`

# %%
def extract_group_members(file_path, start_date, end_date):
    # Set to store unique users
    group_members = set()

    # Read the WhatsApp export file
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Specify the date format that matches your WhatsApp's export format (dd.mm.yyyy)
    date_format = '%d.%m.%Y'

    # Convert the start and end dates to datetime objects
    start_date = datetime.strptime(start_date, date_format).date()
    end_date = datetime.strptime(end_date, date_format).date()

    # Regex pattern to capture WhatsApp message with date, time, user, and message
    # pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
    pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')

    for line in lines:
        match = pattern.match(line)
        if match:
            date_str, time_str, user, message = match.groups()

            # Convert message date to a date object
            message_date = datetime.strptime(date_str, date_format).date()

            # Check if the message date is within the specified date range
            if start_date <= message_date <= end_date:
                # Clean up the user name by stripping extra spaces or non-visible characters
                user = user.strip()

                # Debugging: Print the users being processed
                print(f"Processing message from: {user} at {date_str}")

                group_members.add(user)
        else:
            # Log lines that don't match to debug why certain messages are missed
            print(f"Line not matched: {line.strip()}")

    return group_members

def main():
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_9_DS.txt'

    # Specify the date range (start date and end date)
    start_date = '10.11.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract group members who sent messages between the start and end date
    group_members = extract_group_members(file_path, start_date, end_date)

    # Output the group members
    print(f"\nGroup members who sent messages between {start_date} and {end_date}:")
    if group_members:
        for member in sorted(group_members):
            print(f'"{member}",')
    else:
        print("No messages found in the given date range.")

if __name__ == '__main__':
    main()
# Out:
# Line not matched: ‎[2.05.2024, 20:42:12] Kholoud: ‎sticker omitted
# Line not matched: مش عارف هنبدأ امتى
# Line not matched: بس هنبدأ
# Line not matched: ما تيلا يعم يوسف الاسبوع قرب يخلص والناس مستنيالي غلطة
# Line not matched:
# Line not matched: هنبدأ من انهاردة ان شاء الله كتاب cracking the code interview question او كما يُقال خُلاصة LeetCode لان الشركات بتجيب منه اسئلة الانترڤيوز
# Line not matched: الاول soft skills وتعمل ايه ف الانترڤيو ومرحلة قبل او بعد الانترڤيو وتعمل ايه فال cv وال FAANG ال process بتاعتها عاملة ازاي وبجد مفيد جدا بس انا مهتم بالقسم التاني، ف بصو بصة عليه هيفيدكم
# Line not matched: القسم التاني ال Topics فيها عن ال ps ومتقسم topics وشرح واسئلة عليهم
# Line not matched: هنشوف شرح الكتاب واسئلته ونذاكر من ال handbook،، الاتنين مع بعض هيخلوك تنين مجنح
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: انا بصيت في الهند بوك في جزء الarrays
# Line not matched: بس لسا محلتش عليه عشان لسا داخلة امبارح وكدا
# Line not matched: واتراكم عليا ٣ ايام
# Line not matched: ف باذن الله هتشجع هحلهم
# Line not matched: بجيب الفكرة وبعرف اعملها trace بس بتطول معايا ككود 😅😅 لو حد عنده نصيحة بخصوص النقطة هذه
# Line not matched: لسه هحل
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: نتو بتسلمو ف حته معينه يعني ولا أي م فاهم نا كل مالي فهمته دلوقتي ني احل الاسئله دي صح كده ول ااي
# Line not matched: ‎[24.06.2024, 17:23:27] ~ Aya Ragab: ‎sticker omitted
# Line not matched:
# Line not matched: الكتاب فيه شرح advanced لواحد فاهم والاسئلة شرحها قليل ومش بيفهمك السؤال ١٠٠٪؜ او ايه المطلوب
# Line not matched: ع كدا قولت نبدا مذاكرة من الهاند بوك + مجمع الاسئلة ال ف الكتاب وال شبهها ف لييت كود وحاططهم ف الريبو
# Line not matched:
# Line not matched: الهاند بوك شرحه رائع وبيديك الخلاصة والحاجات ال انت محتاج تركز عليها ف كل توبك وايه ال edge cases لكل حاجة وفيه اسئلة من لييت كود بردو ‎<This message was edited>
# Line not matched:
# Line not matched: بس اكيد كل حاجة صعبة ف الاول ومحتاجة وقت ف بديهي يعني ‎<This message was edited>
# Line not matched: ومينفعش تذاكري توبيك جديد الا لما تكوني قادرة تحلي المسائل البيزك اللي هي تطبيق مباشر علي التوبيك ويفضل كمان مسائل متوسطة
# Line not matched:
# Line not matched: انا لما كنت في ال Training كنا بناخد التوبيك يوم السبت في سيشن والسيشن بيكون فيها جزء عملي كبير وبيحل معانا مسائل، وبقيت الأسبوع بينزل شيت علي التوبيك نقعد نحل فيه، غير كدا الموضوع هيبقي صعب إن واحد بيذاكر التوبيكس دي لأول مرة يتمكن منها
# Line not matched: فا كدا هي مجرد معلومات باخدها واركنها
# Line not matched: والموضوع في ال ps مش بيمشي كدا الأساس هو الحل
# Line not matched: ‎[24.06.2024, 19:47:17] Tohamy PS: ‎image omitted
# Line not matched: ف اول واحده أن يكون ف الداتا سيت بتاعتك كذا عنصر متكررين ورا بعض
# Line not matched: لكن التاني دا عباره عن كذا عنصر متكررين بس متوزعين ف الداتا سيت كلها مش لازم يبقوا ورا بعض
# Line not matched: (محليتش السؤال برضه) بس دا للي ذاكرته يعني مش من البدايه
# Line not matched:
# Line not matched: الكتاب
# Line not matched:
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched:
# Line not matched: الهاندبوك
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: انا ممكن اريكاب ليكم الدنيا مفيش اشطر مني ف مذاكرة الاراي 😂😂
# Line not matched: وبعدها نبدا شابتر ٢ ان شاء الله
# Line not matched: ميتنج بكرة نراجع سريعا شابتر ١
# Line not matched: ‎OPTION: ٨ (6 votes)
# Line not matched: ‎OPTION: ٩ (1 vote)
# Line not matched: ‎OPTION: ١٠ (1 vote)
# Line not matched: ‎OPTION: ١١ (18 votes)
# Line not matched: ‎[29.06.2024, 23:00:15] Hüsam: ‎image omitted
# Line not matched: Arr[R ]- Arr [L-1]
# Line not matched: دخل ٣٠٠ واحد
# Line not matched: ‎[29.06.2024, 23:31:05] Ayash PS: ‎video omitted
# Line not matched: لينك الديسكورد
# Line not matched: فيه موقع كويس ممكن تشرحي عليه بدل ما تنقلي كل شوية ل leet @201096942964.
# Line not matched:
# Line not matched: والخط بتاعه friendly جدا، لو هتذاكر أو تحل مسألة محتاج تمسك فيها ورقة وقلم أو هتشرح لحد حاجة.
# Line not matched: اسمه: excalidraw.com
# Line not matched:
# Line not matched: وفيه خواص جميلة بال AI، وفيه ال laser pointer، اللي يا دوب بتشاور على الحاجة وبيروح تلقائيا،
# Line not matched: وفيه text to diagram، اديله شرح لأي حاجة وهيحولهالك ل diagram منظم بدل ما تقعدوا ترسموا رسومات مش مفهومة.
# Line not matched:
# Line not matched: جربوه؛ هيعجبكم. ‎<This message was edited>
# Line not matched: ‎[30.06.2024, 00:47:05] Kholoud: ‎sticker omitted
# Line not matched: وانتي جدعة معروفة
# Line not matched: ‎[30.06.2024, 03:29:32] Kholoud: ‎sticker omitted
# Line not matched: ‎[30.06.2024, 03:52:31] Kholoud: ‎sticker omitted
# Line not matched: خلصنا الاسبوع ال فات ال arrays & hash maps & strings
# Line not matched:
# Line not matched: الاسبوع دا ان شاء الله هنذاكر ال linked lists
# Line not matched:
# Line not matched: المطلوب
# Line not matched: - مذاكرة ال singly & doubly linked lists من الهاند بوك هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل اسئلتهم من هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/tree/master/chapter-02
# Line not matched:
# Line not matched: - الديدلاين يوم الحد الجاي (اسبوع كامل عشان نلم ال topic كله) ‎<This message was edited>
# Line not matched: ‎[1.07.2024, 01:28:59] Yousef Fathy PS: ‎image omitted
# Line not matched: لو سؤال linked list مش بيتحل معاك اعمل dummy node
# Line not matched: ‎[2.07.2024, 06:18:00] Mai Samir PS: ‎image omitted
# Line not matched: من دلوقتي لحد الساعه 1 اتمني مايكونش فيه مسدجات غير *الفيدباك* بس  ي شباب
# Line not matched: من دلوقت للساعة ١ ياريت ن share our progress ع نشوف مين معانا ومين معانا ومين علينا
# Line not matched: اسأل السؤال تاني بكرا😂
# Line not matched: خلصنا الاسبوع ال فات ال arrays & hash maps & strings
# Line not matched:
# Line not matched: الاسبوع دا ان شاء الله هنذاكر ال linked lists
# Line not matched:
# Line not matched: المطلوب
# Line not matched: - مذاكرة ال singly & doubly linked lists من الهاند بوك هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل اسئلتهم من هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/tree/master/chapter-02
# Line not matched:
# Line not matched: - الديدلاين يوم الحد الجاي (اسبوع كامل عشان نلم ال topic كله)
# Line not matched: بلان واحده وبنوزعها 😂😂😂
# Line not matched: ممكن حد يرشحلك مصادر احسن هنا
# Line not matched: ‎[4.07.2024, 12:51:20] Kholoud: ‎sticker omitted
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: ‎[4.07.2024, 15:53:54] Hüsam: ‎sticker omitted
# Line not matched: ‎[4.07.2024, 15:54:08] Habiba Gamal PS: ‎sticker omitted
# Line not matched: ‎[4.07.2024, 15:55:22] Habiba Gamal PS: ‎sticker omitted
# Line not matched: يعني مش بندي كل توبيك حقه من حل وهكذا
# Line not matched: ‎[4.07.2024, 16:00:21] Hüsam: ‎image omitted
# Line not matched: انا بقولك وجهة نظري
# Line not matched: ‎[4.07.2024, 16:28:39] NamNam Twtr: ‎video omitted
# Line not matched: ‎[6.07.2024, 00:53:47] Hüsam: ‎video omitted
# Line not matched: - ⁠هنمشي شوية ف ال handbook
# Line not matched: - ⁠وبعدين ندخل ع الكتاب ان شاء الله
# Line not matched: - هنذاكر arrays & strings & hash table ونحل عليهم اسئلة من LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي ‎<This message was edited>
# Line not matched: انا عاوزة ابدا اخل على ليت كود عموما
# Line not matched: عدد الجروب كبير جدا ومش كله بيذاكر معانا
# Line not matched: ف من اول ديدلاين ال مش حالل هيطلع م الجروب ‎<This message was edited>
# Line not matched: ‎[6.07.2024, 01:38:48] Ayash PS: ‎sticker omitted
# Line not matched: ‎[6.07.2024, 01:41:30] Mai Samir PS: ‎Contact card omitted
# Line not matched: عشان مش بعرف اجيبه من هناك
# Line not matched: @201096942964
# Line not matched: ‎[6.07.2024, 01:52:29] Kholoud: ‎sticker omitted
# Line not matched: مش عارفه دا بسبب ايه
# Line not matched: ‎[6.07.2024, 01:59:38] Hasnaa PS: ‎image omitted
# Line not matched: انت كاتب ف اول المسدج ان معانا الhash table  ف افتكرته معانا وكنت بجمع الماتريال ع اللاب
# Line not matched: - هنذاكر arrays & strings ونحل عليهم اسئلة ع LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي
# Line not matched: ف من اول ديدلاين ال مش حالل هيطلع م الجروب
# Line not matched: عشان عايزة اللي يساعدني ازاكر معاه
# Line not matched: اللي عنده حاجة عاوز يسال عليها وحد عارف بيجاوبه
# Line not matched: لو في توبك نتناقش فيه
# Line not matched: Leet code Beginner's Guide
# Line not matched: لو حد مش متعود على الويب سايت بتاع ليت كود و عايز يعرف ينڤيجات ازاى وكدة ممكن بيص عليه سريعا.
# Line not matched: بس كنا فى ميتينج دلوقتى انا و ابراهيم و يونس و كنا اتكلمنا على الموضوع ده
# Line not matched: شكرا على وقتكم ي شباب
# Line not matched: و على فكرة أنا مستوايا مش عالى اوى
# Line not matched: طبعا ادمن الجروب كان حاطط فى ال pinned messages اللى المفروض نذاكره ف وقت معين
# Line not matched: ارراى و سترينج فى عشر ايام يعنى خمسة للاراى و خمسة للسترينج
# Line not matched: ممكن اول يوم يبقى مذاكرة للتوبيك بشكل عام من اى مصدر يوتيوب مثلا و بقيت الاربع ايام فى سشكن فى الهاندبوك اسمه essential questions
# Line not matched: ممكن كل يوم من الاربع ايام ناخد مسألة واحدة من المسائل الموجودة فيه (دى عبارة عن لينكات مسائل على ليت كود) نحاول نحلها مع نفسنا فى ساعة لو معرفناش ناخد اسم المسألة برقمها و نشرس على يوتيوب هتلاقى كذا حد شارحها
# Line not matched: وعادى جدا انك تفهم المسألة غلط
# Line not matched: وعادى انك متعرفش تحل أو حتى متعرفش تفكر
# Line not matched: بس المهم تاخد خبرة و تعرف حلول أو شرح من كذا حد ده هيخليك تعرف تفكر قدام
# Line not matched: دى كانت وجهة نظرى و اكيد اكيد فى ناس هنا اشطر منى و عندها بلان افضل بس قولت ممكن كلامى يفرق مع حد مبتدأ زيي ‎<This message was edited>
# Line not matched: عملتو ايه انهاردة
# Line not matched: انا عارفه انى بطيئة 🌚
# Line not matched: بس هحاول انجز عشان اكون معاكم على نفس الخط ان شاء الله
# Line not matched: Product of array except self
# Line not matched: امبارح مع نفسي تفكير ووقف معايا مشكلة time limit exceeded
# Line not matched: و مكنتش عارفة افكر ازاى اعملها امبروڤمنت ف شوفت انهاردة شرح فديو ليها على قناة احمد الامام و كام بيشرحها بشمهندس اسمه احمد جمال بجد شارحها واحدة واحدة و كان فديو كويس
# Line not matched: ‎[11.07.2024, 22:41:57] Gehad: ‎sticker omitted
# Line not matched: الديديلاين بعد يومين
# Line not matched: وال مذاكرش هيطلع من الجروب عشان محدش يزعل 😔
# Line not matched: ‎[13.07.2024, 04:00:56] NamNam Twtr: ‎sticker omitted
# Line not matched: انا بتكلم ع الناس تذاكر 🤷🏻
# Line not matched: بس بكرة هنشوف مين حل ومين محلّش ع ندخل ف ال بعده
# Line not matched: انهاردة يوم ١٥، لحد بكرة الساعة ١٢ ياريت كل ال ذاكر يقولي
# Line not matched:
# Line not matched: ابعت ال done التمام، غير كدا ابعتلي برايفيت …وال مش هيبعت done هيركب ٦ الا تلت ‎<This message was edited>
# Line not matched: ‎[16.07.2024, 01:33:23] Karim PS: ‎sticker omitted
# Line not matched: ‎[16.07.2024, 03:40:41] NamNam Twtr: ‎sticker omitted
# Line not matched: في حجات كتير م اعرفها سرشت مواقع فيها الأسأله تدريجيه ف بذاكرها واحل اللي عرفتو وكذالك بس ذاكرت الهاند بوك م متخاذله بذاكر 😔
# Line not matched: ذاكرت كله  بس كان في بمسالتين تلاته  محلتهمش ‎<This message was edited>
# Line not matched: بس محلتش كله
# Line not matched: بس حليت علي التوبيكس من كود فورسيز شيت أسيوط
# Line not matched: ‎[17.07.2024, 03:50:55] Hüsam: ‎video omitted
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر ‎<This message was edited>
# Line not matched: ‎[18.07.2024, 06:19:13] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: ‎[18.07.2024, 06:19:38] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: ‎[18.07.2024, 06:20:02] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: ‎[18.07.2024, 06:20:18] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: ماشاء الله عليكم
# Line not matched: عاش ي شباب بجد 👏🤍
# Line not matched: فيه لينكات
# Line not matched: الواحد يذاكرها برضوا ؟!
# Line not matched: What's the main difference between Arrays and Strings in most programming languages? #INTERVIEW
# Line not matched: ‎OPTION: Arrays can store integers while strings can store chars (1 vote)
# Line not matched: ‎OPTION: Arrays are mutable while strings are immutable in most langs (14 votes)
# Line not matched: ‎OPTION: Arrays are used for sorting data, while strings are used for searching data (0 votes)
# Line not matched: ‎OPTION: Arrays can store data of different types while strings can only store single types of data (8 votes)
# Line not matched: بس الاسترينج كاركتر بس
# Line not matched: في الشباك أنت بتستقبل أي حاجة ك string ‎<This message was edited>
# Line not matched: ‎[19.07.2024, 16:19:17] Islam PS: ‎audio omitted
# Line not matched: واعملي print للتايب بتاع اي اندكس ف الاراي و في الاتسترينج هتعرفي السبب
# Line not matched: السي و السي بلص بيتخزن نوع واحد
# Line not matched: ‎[19.07.2024, 16:21:33] Islam PS: ‎audio omitted
# Line not matched: الأصح تتكتب بس هي تتفهم من السياق
# Line not matched: ال شافو المسدج 26
# Line not matched: ال جاوبو وشاركو 13
# Line not matched: ‎[19.07.2024, 17:30:57] NamNam Twtr: ‎audio omitted
# Line not matched: ‎[20.07.2024, 12:14:33] Hüsam: ‎sticker omitted
# Line not matched: ‎[20.07.2024, 12:18:28] Islam PS: ‎sticker omitted
# Line not matched: ‎[20.07.2024, 12:20:28] Hüsam: ‎sticker omitted
# Line not matched: ‎[20.07.2024, 12:37:04] Islam PS: ‎sticker omitted
# Line not matched: وواحد بدءت م السطر الاول
# Line not matched:
# Line not matched: كل واحد خد تايم مختلف تمامممماااا
# Line not matched: ع العموم دة بيحصل لما يكون التايم بتاع المسأله قليل اساسا فبتفرق في millie seconds كدة
# Line not matched: ‎[21.07.2024, 07:19:38] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: ‎[21.07.2024, 07:19:38] Mohamed Ibrahim PS: ‎image omitted
# Line not matched: - هنذاكر arrays & strings ونحل عليهم اسئلة ع LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر
# Line not matched:
# Line not matched: و ذاكرتوا topics ايه خلال الفتره الي فاتت عشان اذاكرها الفتره دي و ابقي ماشي معاكو
# Line not matched:
# Line not matched: و المسائل برضو الي حليتوها ع التوبيكس دي هي الي علي notion ولا كل واحد مع نفسه
# Line not matched: - هنذاكر arrays & strings ونحل عليهم اسئلة ع LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر
# Line not matched: للشباب ال لسه داخله جديد وعايزة تكمل معانا ف مذاكرة ال data structures
# Line not matched: احنا خلصنا اول جزء كان ع ال arrays & strings واللينكات اهي 👇🏻
# Line not matched: - هنذاكر arrays & strings ونحل عليهم اسئلة ع LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي
# Line not matched: لينكات ال linked list والمطلوب 👇🏻
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر
# Line not matched: ‎[24.07.2024, 18:36:03] Hüsam: ‎sticker omitted
# Line not matched: ‎[24.07.2024, 18:47:02] Kholoud: ‎image omitted
# Line not matched: ‎[24.07.2024, 18:47:07] Kholoud: ‎sticker omitted
# Line not matched: وع فيه ناس دخلت جديد ف خلينا الديدلاين يوم ٣٠
# Line not matched: ‎[24.07.2024, 18:54:53] Kholoud: ‎sticker omitted
# Line not matched: ‎[24.07.2024, 19:01:53] Hüsam: ‎sticker omitted
# Line not matched: ‎[24.07.2024, 23:01:41] Hüsam: ‎sticker omitted
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر
# Line not matched: لينكات ال linked list والمطلوب 👇🏻
# Line not matched: عشان بعانى مع اليوتيوب
# Line not matched: الموضوع عاملى تشتت كبير
# Line not matched: ‎[25.07.2024, 13:18:30] Ahmed Mounir PS: ‎image omitted
# Line not matched: ‎[25.07.2024, 13:22:14] ~ Adam♡: ‎image omitted
# Line not matched: ‎[25.07.2024, 13:22:50] ~ Adam♡: ‎audio omitted
# Line not matched: انتو حاليا بتحلو علي إيه ؟
# Line not matched: لينكات ال linked list والمطلوب 👇🏻
# Line not matched: استكمالاً لما بدأناه
# Line not matched:
# Line not matched: هنذاكر ال linked lists
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-02%2FREADME.md
# Line not matched:
# Line not matched: المذاكرة من اي مكان عادي، ال handbook فيه الخلاصة والاحسن انك تخلص مذاكرة وتبص عليه قبل م تحل
# Line not matched:
# Line not matched: المرادي عايزين نحل ع LeetCode
# Line not matched: ف هنحل من الريبو ال فوق 👆 (اقل حاجة ٤ مسائل) وقبل الديدلاين الناس تبعتلي انها حلت المسائل
# Line not matched:
# Line not matched: الديدلاين يوم ٢٥ القادم ان شاء الله
# Line not matched: 📛 ال مش حالل هيركب القطر
# Line not matched: الديدلاين والقطر يوم ٣٠
# Line not matched: باي
# Line not matched: ‎[28.07.2024, 17:27:50] Marwa PS: ‎sticker omitted
# Line not matched: ‎[28.07.2024, 17:32:24] Hüsam: ‎sticker omitted
# Line not matched: ‎[28.07.2024, 17:32:41] Marwa PS: ‎sticker omitted
# Line not matched: بس حليت الايزى بس🧑‍🦯
# Line not matched: مسائل على الينكيد ليست باصى
# Line not matched: لو حد يباصى لينا احنا الاتنين
# Line not matched: اكون شاكرة ليه جداً
# Line not matched: @All
# Line not matched: جزاكم الله كل خير ربنا يكرمكم يارب
# Line not matched: ف خلصت ال strings &arrays
# Line not matched: وال linked lists
# Line not matched: والtime complexity كجدعنه مني✨
# Line not matched: ‎[29.07.2024, 21:03:15] Hüsam: ‎video omitted
# Line not matched: ‎[29.07.2024, 21:04:12] Amira PS: ‎sticker omitted
# Line not matched: ‎[29.07.2024, 22:56:11] Ali PS: ‎image omitted
# Line not matched: ‎[30.07.2024, 05:07:07] Hüsam: ‎sticker omitted
# Line not matched: ‎[30.07.2024, 16:25:51] Shahd Tamer PS: ‎sticker omitted
# Line not matched: ع داوود يعمل ميمز ✅✅✅✅
# Line not matched: ‎[30.07.2024, 23:56:15] Hasnaa PS: ‎sticker omitted
# Line not matched: ‎[31.07.2024, 00:00:35] Islam PS: ‎image omitted
# Line not matched: من دلوقت لحد الساعة ١٢ بالليل بكرة ال ذاكر يديني ال done التمام 🫡
# Line not matched:
# Line not matched: بعد ١٢ بالليل بكرة مذبحة القلعة وهنشوف هنذاكر ايه جديد ونكمل ان شاء الله 🥳
# Line not matched: ‎[1.08.2024, 01:17:50] Hüsam: ‎video omitted
# Line not matched:
# Line not matched: هنذاكر hash table
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched:
# Line not matched: https://www.geeksforgeeks.org/hash-table-data-structure/
# Line not matched:
# Line not matched: https://www.programiz.com/dsa/hash-table
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=mFY0J5W8Udk
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=2Ti5yvumFTU
# Line not matched:
# Line not matched: - حل
# Line not matched: شوية م الاسئلة هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-01%2FREADME.md
# Line not matched:
# Line not matched: https://leetcode.com/problemset/?topicSlugs=hash-table&page=1&difficulty=EASY
# Line not matched:
# Line not matched: الديدلاين يوم ١٠
# Line not matched: ‎[1.08.2024, 01:38:46] Hüsam: ‎audio omitted
# Line not matched: ‎[1.08.2024, 01:41:31] Hüsam: ‎audio omitted
# Line not matched: يوم ١٠ بنوقف يوم ع الناس تقول انها ذاكرت وندخل ع التوبك ال بعده (ونحجز تذاكر)
# Line not matched: اسمك جه قدامي قولت اكيد مذاكر وبعت وانا ال مركزتش ومطلعتكش 😔
# Line not matched:
# Line not matched: طعنة الغدر بتيجي من اقرب الناس فعلا
# Line not matched: ‎[2.08.2024, 19:55:39] Hasnaa PS: ‎sticker omitted
# Line not matched: جروب الds بي لايك: الناس ف الكوميونتي مقطعين بعضهم عليا 😂
# Line not matched: ‎[4.08.2024, 19:25:02] Mohamed Ibrahim PS: ‎sticker omitted
# Line not matched: ‎[5.08.2024, 00:27:53] Elknz PS: ‎video omitted
# Line not matched: ‎[5.08.2024, 16:41:29] Habiba Gamal PS: ‎sticker omitted
# Line not matched: ‎[6.08.2024, 04:11:24] Hasnaa PS: ‎sticker omitted
# Line not matched:
# Line not matched: https://youtu.be/Nu8YGneFCWE?si=EJRB4EHfl3RzUFSy
# Line not matched: دا فيديو بيشرح فكرة الهاشنج نفسها
# Line not matched:
# Line not matched: https://youtu.be/2Ti5yvumFTU?si=3P9yZlFOmkfbpkv_
# Line not matched: وعمو يعقوب احسن واحد يفهمكم ازاي بنإمبلمنت الهاش تيبل
# Line not matched:
# Line not matched: #DeepLearning
# Line not matched: عليه افضل الصلاة و السلام
# Line not matched: ‎[7.08.2024, 18:15:16] Amira PS: ‎sticker omitted
# Line not matched:
# Line not matched: عشان ال topic مهم وصعب بصراحة ومحتاج وقت، شدّوا حيلكم
# Line not matched: ‎[7.08.2024, 18:20:37] Ali PS: ‎sticker omitted
# Line not matched: ‎[7.08.2024, 18:24:46] Islam PS: ‎video omitted
# Line not matched:
# Line not matched: هنذاكر hash table
# Line not matched:
# Line not matched: - مذاكرة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched:
# Line not matched: https://www.geeksforgeeks.org/hash-table-data-structure/
# Line not matched:
# Line not matched: https://www.programiz.com/dsa/hash-table
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=mFY0J5W8Udk
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=2Ti5yvumFTU
# Line not matched:
# Line not matched: - حل
# Line not matched: شوية م الاسئلة هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/blob/master/chapter-01%2FREADME.md
# Line not matched:
# Line not matched: https://leetcode.com/problemset/?topicSlugs=hash-table&page=1&difficulty=EASY
# Line not matched:
# Line not matched: الديدلاين يوم ١٠
# Line not matched: يعنى ممكن نستغنى عنها يعنى؟
# Line not matched: بس ال map موجود صح ؟
# Line not matched: ولا زيها
# Line not matched: لو الواحد خلص من الtopic المحدده شنو المفروض يعمله، streak ؟
# Line not matched: ‎[10.08.2024, 14:49:14] Salah Mohamed Twtr: ‎image omitted
# Line not matched: ‎[11.08.2024, 04:51:19] Salah Mohamed Twtr: ‎sticker omitted
# Line not matched: @905525834783
# Line not matched: ‎[12.08.2024, 00:28:23] Elknz PS: ‎image omitted
# Line not matched:
# Line not matched: ع بعد الساعة ١٢ نتصرف مع ال مقالش done 🫡🫡
# Line not matched: رغم انووا لسه حاسة انوا محتاجة ابراكتس اكتر عليه
# Line not matched: ‎[12.08.2024, 10:57:04] Islam PS: ‎image omitted
# Line not matched:
# Line not matched: هنذاكر `stack` & `queue`
# Line not matched:
# Line not matched: stack
# Line not matched: - https://www.geeksforgeeks.org/stack-data-structure/
# Line not matched: - https://www.programiz.com/dsa/stack
# Line not matched: - ⁠https://www.javatpoint.com/data-structure-stack
# Line not matched: - ⁠https://www.youtube.com/watch?v=KInG04mAjO0&pp=ygUIc3RhY2sgZHM%3D
# Line not matched: - ⁠https://www.techinterviewhandbook.org/algorithms/stack/
# Line not matched: queue
# Line not matched: - https://www.geeksforgeeks.org/queue-data-structure/
# Line not matched: - ⁠https://www.programiz.com/dsa/queue
# Line not matched: - ⁠https://www.youtube.com/watch?v=XuCbpw6Bj1U&pp=ygUIcXVldWUgZHM%3D
# Line not matched: - ⁠https://www.javatpoint.com/data-structure-queue
# Line not matched: - ⁠https://www.techinterviewhandbook.org/algorithms/queue/
# Line not matched:
# Line not matched: الديدلاين يوم ٢٠ ان شاء الله
# Line not matched:
# Line not matched: (هغفلكم والمرة الجاية هنركب طيارة مش قطر) ‎<This message was edited>
# Line not matched: انا لقيت ده مجمع فيديوهات ومقالات وكويز ومسائل على كل توبيك
# Line not matched: حان الوقت لنطالب ب قروب "crying corner"
# Line not matched: ويكون دقيق نسبيا 🤏🏽
# Line not matched: https://play.google.com/store/apps/details?id=com.tayu.tau.pedometer
# Line not matched:
# Line not matched: لكن لو عاوزه حاجه شغاله معاك علي طول في منهم كتير اوي يعني
# Line not matched: #include<stack>
# Line not matched: #include<string>
# Line not matched: using namespace std;
# Line not matched: int prec (char c)
# Line not matched: {
# Line not matched: if (c=='*'||c=='/')
# Line not matched: return 2;
# Line not matched: else if (c=='+'|| c=='-')
# Line not matched: return 1;
# Line not matched: else
# Line not matched: return 0;
# Line not matched:
# Line not matched:
# Line not matched: }
# Line not matched: string intopr(string t)
# Line not matched: {
# Line not matched: stack<char>s;
# Line not matched: string posfix="";
# Line not matched: for (int i=0;i<t.size();i++)
# Line not matched: {
# Line not matched: if (t[i]>=0&&t[i]<=9)
# Line not matched: {
# Line not matched: posfix+=t[i];
# Line not matched: }
# Line not matched: else
# Line not matched: {
# Line not matched: while (!s.empty()&& prec(s.top())>=prec(t[i]))
# Line not matched: {
# Line not matched: posfix+=s.top();
# Line not matched: s.pop();
# Line not matched: }
# Line not matched: s.push(t[i]);
# Line not matched: }
# Line not matched: }
# Line not matched: while (!s.empty())
# Line not matched: {
# Line not matched: posfix+=s.top();
# Line not matched: s.pop();
# Line not matched: }
# Line not matched: return posfix;
# Line not matched: }
# Line not matched: int main()
# Line not matched: {
# Line not matched: string str="1+2+4";
# Line not matched: cout <<intopr(str)<<endl;
# Line not matched:
# Line not matched:
# Line not matched: return 0;
# Line not matched: }
# Line not matched:
# Line not matched: //135+*82/-
# Line not matched: if (t[i]>=0&&t[i]<=9)
# Line not matched: دي غلط
# Line not matched: انتي بتت check ـي ع char مش int
# Line not matched: if (t[i] >= '0' && t[i] <= '9')
# Line not matched: (اظن)
# Line not matched:
# Line not matched: لو ال input val كانت 12 مثلا
# Line not matched: يطلع
# Line not matched: +12+4 ‎<This message was edited>
# Line not matched: ‎[16.08.2024, 21:31:48] Hüsam: ‎audio omitted
# Line not matched: جربتها وظبطت
# Line not matched: وكمان مع ال 12وطلعها صح
# Line not matched: what():  stoi
# Line not matched: احنا حاليا فى ال stack, queue
# Line not matched: ‎[18.08.2024, 04:42:05] Kholoud: ‎sticker omitted
# Line not matched: ‎[18.08.2024, 04:43:15] Hüsam: ‎sticker omitted
# Line not matched: راح فين الكلام الدوغرى
# Line not matched: ‎[18.08.2024, 04:44:42] Hüsam: ‎video omitted
# Line not matched: انا بعانى وانا بحل على ليت
# Line not matched: المسألة بتاخد وقت طويل
# Line not matched: وتطلع فى النهاية غلطاتى فيها تافهة
# Line not matched: خلود:
# Line not matched: ‎[18.08.2024, 04:45:38] Kholoud: ‎sticker omitted
# Line not matched: على ليت وكود فورس
# Line not matched: الحلول تقصد؟!
# Line not matched: فبخربط كتير عقبال ما افهم
# Line not matched: يعنى اكتبها السودوا كود على اللاب بحيث ارجعله بعدين
# Line not matched: ‎[18.08.2024, 04:52:40] Kholoud: ‎video omitted
# Line not matched: ‎[18.08.2024, 04:52:45] Abdelrahman Adel PS: ‎image omitted
# Line not matched: ‎[18.08.2024, 04:53:04] Kholoud: ‎sticker omitted
# Line not matched: ‎[18.08.2024, 04:54:39] Hasnaa PS: ‎sticker omitted
# Line not matched: ‎[18.08.2024, 05:01:16] Hasnaa PS: ‎sticker omitted
# Line not matched: كان فيه حاجة لازم اضغط عليها الاول هشان تظهر
# Line not matched: هايظهرلك كل المسائل بتاعت الستاك
# Line not matched: Queue❌❗
# Line not matched: 🧑‍🦯🧑‍🦯
# Line not matched: ‎[19.08.2024, 08:25:56] Salah Mohamed Twtr: ‎image omitted
# Line not matched: ‎[20.08.2024, 03:15:53] Salah Mohamed Twtr: ‎image omitted
# Line not matched: الديدلاين انهاردة
# Line not matched: ‎[20.08.2024, 03:40:51] Hüsam: ‎sticker omitted
# Line not matched: ‎[20.08.2024, 03:42:47] Hasnaa PS: ‎sticker omitted
# Line not matched: ‎[20.08.2024, 03:43:40] Hüsam: ‎image omitted
# Line not matched: نجونا و لله الحمد
# Line not matched: كنت فاكرة الديدلاين يوم ٢٦ و منتظرة و قولت هما لى بيبعتو من دلوقتى 😂😂😂😂
# Line not matched: ‎[21.08.2024, 00:16:35] Younes PS: ‎sticker omitted
# Line not matched:
# Line not matched: ياريت ال ذاكر يديني ال done التمام ع نشوف مين متخاذل 🫵🏻
# Line not matched: خلصت التالت وبذاكر في الرابع بس لسه بدا فيه 🥲
# Line not matched:
# Line not matched: هنذاكر recursion
# Line not matched:
# Line not matched: ال recursion هو concept مهم ف ال programming (وصعب بردو)، ال جاي بنسبة كبيرة جدا هيكون مُعتمد عليه سواء matrix & tree & graph & DP & sorting/searching وحتى ال خلصناه عشان تعمله optimization هتحتاج فيه recursion
# Line not matched:
# Line not matched: ف اتمنى نذاكره كويس عشان مهم
# Line not matched:
# Line not matched: المطلوب:
# Line not matched: - كل الاسئلة ال هنا حاول فيها (٨ اسئلة)
# Line not matched: https://leetcode.com/problemset/?page=1&topicSlugs=recursion&difficulty=EASY
# Line not matched: - ممكن تجرب ف شيت ريكريچن ف شيتات اسيوط
# Line not matched: - ⁠بص بصة هنا جامد بردو
# Line not matched: https://www.techinterviewhandbook.org/algorithms/recursion/
# Line not matched: - ذاكر من اي مكان اظن مفيش اكتر من شرح اليوتيوب اي حد بتتابعه ف الشرح اكيد هتلاقيه شارح recursion
# Line not matched:
# Line not matched: 🛑 الديدلاين يوم ٢ ف الشهر القادم
# Line not matched: 🛑 ال مش هيذاكر مش هيكمل معانا ف الجروب
# Line not matched:
# Line not matched: هذاكره معاكم لان اديلي تقريبا سنة بحل ع لييت كود وبخاف من اسئلة ال recursion ‎<This message was edited>
# Line not matched: ‎[26.08.2024, 07:54:34] David PS: ‎video omitted
# Line not matched: الديدلاين يوم ٢
# Line not matched: ‎[31.08.2024, 06:00:29] Hüsam: ‎sticker omitted
# Line not matched: Can we have a session on this topic?
# Line not matched: ‎[31.08.2024, 10:52:17] Mohamed Ibrahim PS: ‎sticker omitted
# Line not matched: الأيام بتجري هواااا
# Line not matched: ( هتبقى مدبحة )
# Line not matched: ‎[2.09.2024, 08:43:29] Hasnaa PS: ‎sticker omitted
# Line not matched: ‎[2.09.2024, 11:58:25] ~ Ahmed Usama: ‎image omitted
# Line not matched: وملقيتش حد جايب الفكرة في السوليوشنز خالص 😭😭
# Line not matched: أبعت الحل كوبي؟
# Line not matched:
# Line not matched: bool recursive(int x,int n)
# Line not matched: {
# Line not matched: if(pow(2,x)>n)
# Line not matched: return false;
# Line not matched:
# Line not matched: if(pow(2,x)==n)
# Line not matched: return true;
# Line not matched:
# Line not matched: return recursive(x+1,n);
# Line not matched: }
# Line not matched:
# Line not matched: public:
# Line not matched: bool isPowerOfTwo(int n) {
# Line not matched: return recursive(0,n);
# Line not matched: }
# Line not matched: };
# Line not matched: خش الميديام عقد نفسك و اخرج
# Line not matched: انا حليتها بطريقة ابسط
# Line not matched: من كدا
# Line not matched: بس تسلم حلك جامد واضح فيا المجهود
# Line not matched: ‎[2.09.2024, 12:12:34] Salah Mohamed Twtr: ‎image omitted
# Line not matched: بس لقيت ملهاش لازمه
# Line not matched: ‎[2.09.2024, 12:14:29] Hasnaa PS: ‎image omitted
# Line not matched: ‎[2.09.2024, 13:05:11] Ahmed Jamal Sultan PS: ‎image omitted
# Line not matched: و ياه لو كان على الديلى تبقى جمدان
# Line not matched: @905525834783
# Line not matched: حاسانى قريتها قبل كدا لكن مش فاكرة
# Line not matched: ماحدش بيعت عليه غيرى
# Line not matched:
# Line not matched: ال ذاكر يقول فضلا
# Line not matched: Done
# Line not matched: ‎[6.09.2024, 01:54:48] Hasnaa PS: ‎sticker omitted
# Line not matched: احمد اسامة ف اول مرة اتاخر*
# Line not matched: ‎[7.09.2024, 12:38:04] Hüsam: ‎video omitted
# Line not matched:
# Line not matched: هنذاكر Matrix
# Line not matched: صراحة توبك سهل ولكن محتاج وقت + بييجي كتير جدا ف الانترڤيوز
# Line not matched: - يُفضل تذاكرها من articles لان شرحها افضل ومش هيفرق بتذاكر منين يعني
# Line not matched: - ⁠اهم حاجة ف المذاكرة الحل لانك بتختبر ال ذاكرته وهل انت فاهم ١٠٠‎%‎ ولا لا
# Line not matched: - وكالعادة الزتونة هنا شوفها بعد ما تخلص
# Line not matched: https://www.techinterviewhandbook.org/algorithms/matrix/
# Line not matched: - اخر حاجة واهم حاجة صديقنا نور الدين⁩ عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين يوم ١٤ ‎<This message was edited>
# Line not matched: ‎[10.09.2024, 00:49:39] Hüsam: ‎image omitted
# Line not matched: matrix resources رجاء
# Line not matched: Articles geeks of geeks  كويسه
# Line not matched: ياريت لو حد من الشباب في الجروب يساعد ويبعت
# Line not matched: بكرة يوم ١٤ (الديدلاين)
# Line not matched:
# Line not matched: هنذاكر Matrix
# Line not matched: صراحة توبك سهل ولكن محتاج وقت + بييجي كتير جدا ف الانترڤيوز
# Line not matched: - يُفضل تذاكرها من articles لان شرحها افضل ومش هيفرق بتذاكر منين يعني
# Line not matched: - ⁠اهم حاجة ف المذاكرة الحل لانك بتختبر ال ذاكرته وهل انت فاهم ١٠٠‎%‎ ولا لا
# Line not matched: - وكالعادة الزتونة هنا شوفها بعد ما تخلص
# Line not matched: https://www.techinterviewhandbook.org/algorithms/matrix/
# Line not matched: - اخر حاجة واهم حاجة صديقنا نور الدين⁩ عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين يوم ١٤
# Line not matched: ‎[13.09.2024, 03:54:51] Abdelhadi PS: ‎sticker omitted
# Line not matched: ح تقدر ان شاءالله.  ال topic نوعا ما بسيط
# Line not matched: مساء الخير يولاد، الديدلاين جه
# Line not matched: ياريت نركز ف الكلمتين دول
# Line not matched: ١. ال بعت done يبعت تاني عشان هنحاسب من دلوقت
# Line not matched: ٢. ⁠هتبعت مسدج واحدة فيها “done” اي حاجة غير كدا invalid
# Line not matched: ٣. ⁠من دلوقت لحد بكرة ١٢ بالليل بنبعت done وبعدها بنركب القطر
# Line not matched:
# Line not matched:
# Line not matched: بشكر نور الدين⁩ تاني ع الاسكريبت ال انقذ حياتي (حرفيا) وهيختصر وقت كتير ❤️ ‎<This message was edited>
# Line not matched:
# Line not matched: - هنذاكر Trees 🌳
# Line not matched: - اخدنا وقتنا ف ال recursion ف اظن هيكون سهل، محتاج وقت بس ع الدنيا تظبط
# Line not matched:
# Line not matched: المطلوب:
# Line not matched: - ال tree as a concept
# Line not matched: - ⁠ال binary tree
# Line not matched: - ⁠ال AVL tree
# Line not matched: - ⁠ال Big O لل trees
# Line not matched:
# Line not matched:
# Line not matched: لو هحط ريسورسز لل trees ف اكيد هحط الفيديوهات دي لل MIT
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=9Jry5-82I68&pp=ygUIdHJlZSBtaXQ%3D
# Line not matched: دول بيشرحو ال core لل trees بالتفصيل الممل ( كل كلمة تقريبا مهمة ) بعد كدا شوف بت implement ال tree ازاي ف ال language بتاعتك وال operations عليها ازاي
# Line not matched:
# Line not matched: كالعادة الزتونة هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/tree/
# Line not matched:
# Line not matched:
# Line not matched: ال data structure و ال algorithms هم حاجة واحدة بنسبة كبيرة ف ممكن حاجة ناخدها هنا وناخدها تاني ف ال algos والعكس
# Line not matched:
# Line not matched: الديدلاين يوم ٣٠ ‎<This message was edited>
# Line not matched: I will make sure to remove the ones who did not study
# Line not matched:
# Line not matched: - هنذاكر Trees 🌳
# Line not matched: - اخدنا وقتنا ف ال recursion ف اظن هيكون سهل، محتاج وقت بس ع الدنيا تظبط
# Line not matched:
# Line not matched: المطلوب:
# Line not matched: - ال tree as a concept
# Line not matched: - ⁠ال binary tree
# Line not matched: - ⁠ال AVL tree
# Line not matched: - ⁠ال Big O لل trees
# Line not matched:
# Line not matched:
# Line not matched: لو هحط ريسورسز لل trees ف اكيد هحط الفيديوهات دي لل MIT
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=9Jry5-82I68&pp=ygUIdHJlZSBtaXQ%3D
# Line not matched: دول بيشرحو ال core لل trees بالتفصيل الممل ( كل كلمة تقريبا مهمة ) بعد كدا شوف بت implement ال tree ازاي ف ال language بتاعتك وال operations عليها ازاي
# Line not matched:
# Line not matched: كالعادة الزتونة هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/tree/
# Line not matched:
# Line not matched:
# Line not matched: ال data structure و ال algorithms هم حاجة واحدة بنسبة كبيرة ف ممكن حاجة ناخدها هنا وناخدها تاني ف ال algos والعكس
# Line not matched:
# Line not matched: الديدلاين يوم ٣٠
# Line not matched: انا متأخرة خالص بس انبسطت والله 😂
# Line not matched: ممكن ال ذاكر يبعت "done"
# Line not matched: ‎[4.10.2024, 02:19:31] Hüsam: ‎video omitted
# Line not matched:
# Line not matched: هنذاكر graph
# Line not matched: الحل ف التوبيك دا اهم من المذاكرة 💀
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=utDu3Q7Flrw&t=175s&pp=ygUUZ3JhcGggZGF0YSBzdHJ1Y3R1cmU%3D
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=pcKY4hjDrxk&pp=ygUUZ3JhcGggZGF0YSBzdHJ1Y3R1cmU%3D
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=gXgEDyodOJU&pp=ygUUZ3JhcGggZGF0YSBzdHJ1Y3R1cmU%3D
# Line not matched:
# Line not matched: الزتونة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/graph/
# Line not matched:
# Line not matched: اسئلة الجراف ع لييت كود
# Line not matched: https://leetcode.com/problemset/?page=1&topicSlugs=graph&sorting=W3sic29ydE9yZGVyIjoiQVNDRU5ESU5HIiwib3JkZXJCeSI6IkRJRkZJQ1VMVFkifV0%3D&difficulty=MEDIUM
# Line not matched:
# Line not matched: الديدلاين يوم ١٤ ‎<This message was edited>
# Line not matched:
# Line not matched: ف ناس كدا ذي؟ ولا انا متأخرة عنكم و محتاجه اضغط؟ ‎<This message was edited>
# Line not matched: بس انا تمام مستوعبه انى اول مرة اذاكرها فمش بفهم 100%
# Line not matched: فابتديت امسكها من الاول و امشي فالتوبيك براحتى
# Line not matched: و فنفس الوقت بحاول افهم الجديد و احل ‎<This message was edited>
# Line not matched: ‎[13.10.2024, 13:19:17] Elknz PS: ‎image omitted
# Line not matched: ‎[13.10.2024, 13:19:40] Elknz PS: ‎sticker omitted
# Line not matched: ‎[13.10.2024, 13:20:04] Elknz PS: ‎sticker omitted
# Line not matched:
# Line not matched: ياريت ال ذاكر يبعت ديدلاين ع نحجز تذاكر 🥰
# Line not matched: ولا مش عايزين ds تاني
# Line not matched:
# Line not matched: هنذاكر Trie
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=tUBFINxzlLg&pp=ygUMdHJpZSBleHBsYWlu
# Line not matched:
# Line not matched: https://www.youtube.com/watch?v=3CbFFVHQrk4&t=51s&pp=ygUMdHJpZSBleHBsYWlu
# Line not matched:
# Line not matched: الزتونة
# Line not matched: https://www.techinterviewhandbook.org/algorithms/trie/
# Line not matched:
# Line not matched: الحل ع لييت كود
# Line not matched: https://leetcode.com/problemset/?topicSlugs=trie&page=1&sorting=W3sic29ydE9yZGVyIjoiQVNDRU5ESU5HIiwib3JkZXJCeSI6IkRJRkZJQ1VMVFkifV0%3D
# Line not matched:
# Line not matched: الديدلاين يوم ٢٤
# Line not matched:
# Line not matched: بادئين اديلنا فوق الاربع شهور، ف ال وصل هنا وبيقرا المسدج دي must be proud of himself ❤️
# Line not matched:
# Line not matched: وبعتذر لو الطرد او النظام مضايق حد بس دا اكتر حاجة effective للناس وبتخلي الواحد مجبر يخلص ال عليه 👈🏻👉🏻 ‎<This message was edited>
# Line not matched: انهاردة الديدلاين، ياريت ال خلص يبعت done وال بعت يبعت تاني فضلا
# Line not matched: وال مش هيبعت ميزعلش 🔪
# Line not matched:
# Line not matched: كنت ب check ف الليست ال ماشيين عليها والحاجات ال المفروض نخلصها لقيت ان آخر توبيك هو ال trie 🥹
# Line not matched:
# Line not matched: بدأنا يوم ٢١ يونيو وانهاردة ٣٠ اكتوبر يعني تقريبا ٤ شهور من ال data structure اظن كافيين جدا يخلوك تحل اي سؤال او اي توبيك ع لييت كود وحتى تبدا contests 🔥
# Line not matched:
# Line not matched: انا فخور باي حد لسه ف الجروب لحد دلوقت (وحتى لو حد طلع ودخل تاني انا فخور بيه اكتر عشان حاطط الموضوع فدماغه ومستسلمش) وانتو كمان المفروض تكونو فخورين بنفسكم 💖
# Line not matched:
# Line not matched: اصعب حاجة اليومين دول ان الواحد يكون مُنتظم ع حاجة معينة لفترة طويلة and YOU DID IT ❤️
# Line not matched:
# Line not matched: (١٥ ريآكت ع المسدج ونأجلها)
# Line not matched: هتخلصو امتحانات امتى عشان نبدأ؟
# Line not matched: ‎OPTION: بعد يوم ١٠ ف الشهر (7 votes)
# ...
# Processing message from: ميخا PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 02:06:40] Mohamed PS: ‎sticker omitted
# Processing message from: ميخا PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 02:06:54] ميخا PS: ‎sticker omitted
# Processing message from: Mohamed PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: Big_O PS at 9.12.2024
# Line not matched: اللي في هندسه حاسبات حتا مش اي قسم تاني
# Line not matched: نفسه كان يبقي في حاسبات
# Line not matched: انا لولا الأزهر الجميل بس
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Mohamed PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Mohamed PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 02:10:45] Mohamed PS: ‎sticker omitted
# Processing message from: Big_O PS at 9.12.2024
# Line not matched: انا بجد كان نفسي يبقي في حاسبات في الأزهر بدل الكليه اللي ملهاش ريحه اللازمه دي
# Line not matched: انا كل سنه مفيش غير ماده واحده سوفت وير!!!
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Ahmad Zanaty at 9.12.2024
# Line not matched: ‎[9.12.2024, 02:15:53] ~ Ahmad Zanaty: ‎video omitted
# Processing message from: Ahmad Zanaty at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Habiba Gamal PS at 9.12.2024
# Processing message from: Ahmad Zanaty at 9.12.2024
# Processing message from: Mohamed Rabee PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 09:03:27] Mohamed Rabee PS: ‎sticker omitted
# Processing message from: mahmoudasal at 9.12.2024
# Processing message from: Hüsam at 9.12.2024
# Line not matched: ولسه بنتخانق مين احسن حاسبات ولا هندسة
# Line not matched:
# Line not matched: بال بيشتغل ف الاخر يجدعان والله 😂😂😂😂😂😂😂😂😂😂😂😂😂😂
# Processing message from: Hüsam at 9.12.2024
# Line not matched: ‎[9.12.2024, 10:07:50] Mohamed Rabee PS: ‎audio omitted
# Processing message from: Tasneem at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 13:29:38] Abdelrahman Adel PS: ‎sticker omitted
# Line not matched: ‎[9.12.2024, 13:44:06] ~ Salma: ‎sticker omitted
# Processing message from: Shady at 9.12.2024
# Processing message from: Hüsam at 9.12.2024
# Processing message from: Abdelrahman Adel PS at 9.12.2024
# Processing message from: Shady at 9.12.2024
# Processing message from: Abdelrahman Adel PS at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: Shady at 9.12.2024
# Line not matched: Data science
# Line not matched: ML
# Line not matched: دول ايه الدنيا 👈🏻👉🏻
# Processing message from: Shady at 9.12.2024
# Line not matched: ‎[9.12.2024, 15:26:23] ~ Shady: ‎sticker omitted
# Processing message from: Abdelrahman Adel PS at 9.12.2024
# Processing message from: Abdelrahman Adel PS at 9.12.2024
# Line not matched: ‎[9.12.2024, 15:27:18] Abdelrahman Adel PS: ‎sticker omitted
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: Hüsam at 9.12.2024
# Processing message from: ميخا PS at 9.12.2024
# Processing message from: Hüsam at 9.12.2024
# Line not matched: ‎[9.12.2024, 15:32:53] ~ Shady: ‎sticker omitted
# Processing message from: Abdelrahman Adel PS at 9.12.2024
# Processing message from: Os!Rabe3 PS at 10.12.2024
# Processing message from: Hüsam at 10.12.2024
# Processing message from: Os!Rabe3 PS at 10.12.2024
# Processing message from: Hüsam at 10.12.2024
# Processing message from: Os!Rabe3 PS at 10.12.2024
# Processing message from: Hüsam at 10.12.2024
# Line not matched: وإجازة اسبوع
# Processing message from: 𝑫𝑶𝑯𝑨 at 10.12.2024
# Processing message from: Hüsam at 10.12.2024
# Line not matched: ‎[10.12.2024, 15:27:26] Hüsam: ‎sticker omitted
# Processing message from: 𝑫𝑶𝑯𝑨 at 10.12.2024
# Line not matched: ‎[10.12.2024, 15:28:07] ~ 𝑫𝑶𝑯𝑨: ‎sticker omitted
# Processing message from: Shaimaa at 10.12.2024
# Line not matched: ‎[10.12.2024, 16:59:46] Hüsam: ‎sticker omitted
# Line not matched: ‎[10.12.2024, 17:30:01] ~ Shaimaa: ‎sticker omitted
# Processing message from: Habiba Gamal PS at 10.12.2024
# Processing message from: Habiba Gamal PS at 10.12.2024
# Processing message from: Abdelrahman Adel PS at 10.12.2024
# Line not matched: ‎[10.12.2024, 18:04:13] Hüsam: ‎sticker omitted
# Processing message from: Salma Abdelkarim at 10.12.2024
# Processing message from: Salma Abdelkarim at 11.12.2024
# Processing message from: Amina at 11.12.2024
# Processing message from: . at 11.12.2024
# Processing message from: Nariman Awny at 11.12.2024
# Processing message from: ~ Ahmed at 11.12.2024
# Processing message from: Ali Ismail at 11.12.2024
# Processing message from: Ibrahim Atef Eltahlawy 🇵🇸 at 11.12.2024
# Processing message from: TAREK PS at 11.12.2024
# Processing message from: Karim PS at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Line not matched: بحاول احط حاجات خفيفة ع الناس متتعقدش
# Line not matched: بس تمام
# Line not matched: ‎[11.12.2024, 12:53:54] ~ Shaimaa: ‎sticker omitted
# Line not matched: ‎[11.12.2024, 12:55:20] ~ Salma: ‎sticker omitted
# Processing message from: Hüsam at 11.12.2024
# Processing message from: hussien at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Salah Mohamed Twtr at 11.12.2024
# Processing message from: Mohamed PS at 11.12.2024
# Processing message from: PS at 11.12.2024
# Processing message from: Ahmed Mohamed PS at 11.12.2024
# Processing message from: Ahmed Mohamed PS at 11.12.2024
# Processing message from: Mariam Elgazzar at 11.12.2024
# Processing message from: Ahmed Mohamed PS at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Mohamed PS at 11.12.2024
# Processing message from: Mohamed PS at 11.12.2024
# Processing message from: Karema PS at 11.12.2024
# Processing message from: Karema PS at 11.12.2024
# Processing message from: Zeyad PS at 11.12.2024
# Processing message from: Salma at 11.12.2024
# Processing message from: Nada Abdelghaffar PS at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Abdelrahman Adel PS at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Ahmad Zanaty at 11.12.2024
# Processing message from: Zoe💜 at 11.12.2024
# Processing message from: Karema PS at 11.12.2024
# Processing message from: Ali PS at 11.12.2024
# Processing message from: hussien at 11.12.2024
# Processing message from: Mohamed PS at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Line not matched: ‎[11.12.2024, 17:17:15] Hüsam: ‎sticker omitted
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Hüsam at 11.12.2024
# Processing message from: Mo7amed Galal PS at 11.12.2024
# Line not matched: ‎[11.12.2024, 17:18:20] hussien: ‎sticker omitted
# Line not matched: ‎[11.12.2024, 17:18:27] Mohamed PS: ‎sticker omitted
# Processing message from: Mohamed PS at 11.12.2024
# Processing message from: ☆아말☆أمل PS at 11.12.2024
# Processing message from: Salma PS at 11.12.2024
# Processing message from: amenasaad83 at 11.12.2024
# Processing message from: hager ashraf at 11.12.2024
# Processing message from: 𓂆 PS at 11.12.2024
# Processing message from: Mohamed Rabee PS at 12.12.2024
# Processing message from: Eman Ashraf PS at 12.12.2024
# Processing message from: 𝑫𝑶𝑯𝑨 at 12.12.2024
# Processing message from: Shady at 12.12.2024
# Processing message from: Zeyad PS at 12.12.2024
# Processing message from: Karema PS at 12.12.2024
# Processing message from: Karema PS at 12.12.2024
# Processing message from: Abdelrahman Adel PS at 12.12.2024
# Processing message from: Ahmad Zanaty at 12.12.2024
# Processing message from: Ahmad Zanaty at 12.12.2024
# Processing message from: Ahmad Zanaty at 12.12.2024
# Processing message from: Hüsam at 12.12.2024
# Line not matched:
# Line not matched: انهاردة يوم ١٢، يعني الديدلاين 🔪
# Line not matched: ياريت من انهاردة لبكرة الساعة ١٢ ال ذاكر وخلص ياريت يبعت done او Done فقط لا غير ع الاسكريبت
# Line not matched:
# Line not matched: وال بعت بردو يبعت تاني ع الاسكريبت هيشتغل من بعد المسدج دي
# Processing message from: Abdelrahman Adel PS at 12.12.2024
# Processing message from: ☆아말☆أمل PS at 12.12.2024
# Processing message from: Karema PS at 12.12.2024
# Processing message from: Karema PS at 12.12.2024
# Processing message from: Mohamed PS at 12.12.2024
# Processing message from: Mostafa Sayed at 12.12.2024
# Processing message from: Radwan at 12.12.2024
# Processing message from: Salma PS at 12.12.2024
# Processing message from: Nada Abdelghaffar PS at 12.12.2024
# Processing message from: Ahmad Zanaty at 12.12.2024
# Processing message from: Salma at 12.12.2024
# Processing message from: Shady at 12.12.2024
# Processing message from: Karema PS at 12.12.2024
# Processing message from: Ahmed Mohamed PS at 12.12.2024
# Processing message from: Os!Rabe3 PS at 12.12.2024
# Processing message from: Mostafa Medhat PS at 12.12.2024
# Processing message from: Zeyad PS at 12.12.2024
# Processing message from: Omar Sayed at 12.12.2024
# Processing message from: amenasaad83 at 12.12.2024
# Processing message from: ~ Ahmed at 12.12.2024
# Processing message from: MS at 12.12.2024
# Processing message from: Rawan at 12.12.2024
# Processing message from: Amany Mohammed PS at 12.12.2024
# Processing message from: Mariam Osman PS at 12.12.2024
# Processing message from: Ahmed Salman PS at 12.12.2024
# Processing message from: Ahmed Mounir PS at 12.12.2024
# Processing message from: * PS at 12.12.2024
# Processing message from: MS at 12.12.2024
# Processing message from: PS at 12.12.2024
# Processing message from: KHALED at 12.12.2024
# Processing message from: Ahmed Elkassrawy PS at 12.12.2024
# Processing message from: Ahmed Mahmoud Dabour at 12.12.2024
# Processing message from: Shaimaa at 12.12.2024
# Processing message from: Seif at 12.12.2024
# Processing message from: Shahd Hamdi at 12.12.2024
# Processing message from: Omar Nabil PS at 12.12.2024
# Processing message from: Mahmoud Salem at 12.12.2024
# Processing message from: ّّّّّّّّّّّّّّّّّّّّّّّّّ at 12.12.2024
# Processing message from: Omnia Ashraf PS at 12.12.2024
# Processing message from: amenasaad83 at 12.12.2024
# Processing message from: hussien at 13.12.2024
# Processing message from: hager ashraf at 13.12.2024
# Processing message from: Big_O PS at 13.12.2024
# Processing message from: PS-StudyingDS 📔 at 13.12.2024
# Processing message from: Hüsam at 13.12.2024
# Line not matched:
# Line not matched: فيه كذا حد كلمني عشان الديدلاين وانه لسه مخلصش والوقت كان ضيّق
# Line not matched:
# Line not matched: فـ هنمد الديدلاين ل يومين كمان (لحد يوم ١٥) ال مخلصش حاجة يخلصها وال محلش يحل بحيث نقفل الدنيا ومندخلش ع الجديد من غير ما نكون متمكنين من القديم
# Line not matched:
# Line not matched: اعذروني ولكن ال مش هيذاكر ال متفقين عليه لحد الديدلاين هيبقى out، وشكرا
# Processing message from: Hüsam at 13.12.2024
# Processing message from: رَحْمَة أَمِينٍ at 13.12.2024
# Processing message from: Hajer at 14.12.2024
# Processing message from: Hüsam at 15.12.2024
# Line not matched:
# Line not matched: عارف انه الساعة لسه مجاتش ١٢، بس اظن الناس خلصت بعد ما مدينا الديدلاين
# Line not matched:
# Line not matched: ف ياريت ال خلص مذاكرة يبعت done او Done ف مسدج من دلوقت لحد الساعة ١٢ بكرة (ال بعت مش محتاج يبعت تاني بتكلم ع ال لسه مخلصش)
# Processing message from: Hüsam at 15.12.2024
# Processing message from: PS-StudyingDS 📔 at 15.12.2024
# Processing message from: Aysha at 15.12.2024
# Processing message from: Abdelrahman Adel PS at 15.12.2024
# Processing message from: Omnia Ashraf PS at 15.12.2024
# Processing message from: Hesham Hatem at 15.12.2024
# Processing message from: ›› 라니아 ‹‹ at 15.12.2024
# Processing message from: Karema PS at 15.12.2024
# Processing message from: Zeyad PS at 15.12.2024
# Processing message from: Zoe💜 at 15.12.2024
# Line not matched: للتاكبد
# Processing message from: ☆아말☆أمل PS at 15.12.2024
# Processing message from: Hasnaa PS at 15.12.2024
# Processing message from: Hüsam at 15.12.2024
# Processing message from: hager ashraf at 15.12.2024
# Processing message from: 3bnaby at 15.12.2024
# Processing message from: Minno PS at 15.12.2024
# Processing message from: mahmoudasal at 15.12.2024
# Processing message from: Ahmad Zanaty at 15.12.2024
# Processing message from: محمد بن محمود الهواري at 15.12.2024
# Processing message from: Mohamed Rabee PS at 15.12.2024
# Processing message from: MS at 15.12.2024
# Processing message from: Reham Galal at 15.12.2024
# Processing message from: Shahd Tamer PS at 15.12.2024
# Processing message from: Mo7 Shdw PS at 16.12.2024
# Processing message from: KHALED at 16.12.2024
# Processing message from: Mahmoud Salem at 16.12.2024
# Processing message from: Salah Mohamed Twtr at 16.12.2024
# Processing message from: Mariam Elgazzar at 16.12.2024
# Processing message from: محمود محمد PS at 16.12.2024
# Processing message from: 𓂆 PS at 16.12.2024
# Processing message from: Elknz PS at 16.12.2024
# Processing message from: Ahmed Salman PS at 16.12.2024
# Processing message from: hussien at 16.12.2024
# Processing message from: رُفَيده سَعْد PS at 16.12.2024
# Processing message from: Ahmed Elkassrawy PS at 16.12.2024
# Processing message from: ميخا PS at 16.12.2024
# Processing message from: Omnia PS at 16.12.2024
# Processing message from: Merna at 16.12.2024
#
# Group members who sent messages between 10.11.2024 and 17.12.2024:
# "* PS",
# ".",
# "..",
# "3bnaby",
# "Abdelfattah Mohamed",
# "Abdelrahman Adel PS",
# "Abdulrhman Ahmed PS",
# "Ahmad Zanaty",
# "Ahmed Elkassrawy PS",
# "Ahmed Mahmoud Dabour",
# "Ahmed Mohamed PS",
# "Ahmed Mounir PS",
# "Ahmed Salman PS",
# "Ali Ismail",
# "Ali PS",
# "Amany Mohammed PS",
# "Amina",
# "Amina PS",
# "Aysha",
# "Big_O PS",
# "David PS",
# "Elknz PS",
# "Eman Ashraf PS",
# "Eng Mo _ Atia",
# "Esraa Elzehery",
# "Esraa Salah",
# "Gehad",
# "Habiba Gamal PS",
# "Hajer",
# "Hasnaa PS",
# "Hesham Elsayed PS",
# "Hesham Hatem",
# "Hüsam",
# "Ibrahim Atef Eltahlawy 🇵🇸",
# "Islam PS",
# "Jehad Amjad",
# "KHALED",
# "Karema PS",
# "Karim PS",
# "Kholoud",
# "MS",
# "Mahmoud Salem",
# "Mahmoud 🔴🔵⚽",
# "Mariam Elgazzar",
# "Mariam Osman PS",
# "Marwa PS",
# "Menna Seif",
# "Merna",
# "Minno PS",
# "Mo7 Shdw PS",
# "Mo7amed Galal PS",
# "Mohamed",
# "Mohamed PS",
# "Mohamed Rabee PS",
# "Mostafa Medhat PS",
# "Mostafa Sayed",
# "Nada Abdelghaffar PS",
# "Nariman Awny",
# "Ola",
# "Omar",
# "Omar Nabil PS",
# "Omar Sayed",
# "Omnia Ashraf PS",
# "Omnia PS",
# "Os!Rabe3 PS",
# "PS",
# "PS-StudyingDS 📔",
# "Professor 👤",
# "Radwan",
# "Rawan",
# "Reham Galal",
# "Salah Mohamed Twtr",
# "Salma",
# "Salma Abdelkarim",
# "Salma PS",
# "Seif",
# "Shady",
# "Shahd Hamdi",
# "Shahd Tamer PS",
# "Shaimaa",
# "Shaimaa Fikry",
# "TAREK PS",
# "Taha Shaban",
# "Tarek PS",
# "Tasneem",
# "Xo_Sh3r11f",
# "Yos S3D Twtr",
# "Younes PS",
# "Zeyad PS",
# "Ziad Nasser PS",
# "Zoe💜",
# "alaafahiem",
# "amenasaad83",
# "hager ashraf",
# "hussien",
# "mahmoudasal",
# "~ Ahmed",
# "إسراء",
# "رَحْمَة أَمِينٍ",
# "رُفَيده سَعْد PS",
# "غادة PS",
# "محمد بن محمود الهواري",
# "محمود محمد PS",
# "ميخا PS",
# "ّّّّّّّّّّّّّّّّّّّّّّّّّ",
# "‎You",
# "›› 라니아 ‹‹",
# "☆아말☆أمل PS",
# "𓂆 PS",
# "𝑫𝑶𝑯𝑨",
