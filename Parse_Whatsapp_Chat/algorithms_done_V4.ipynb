# %% [markdown]
# # Part 1: Function to Parse WhatsApp Chat for Task Completion

# %%
import re
from datetime import datetime, date  # Importing date to use date.today()

def parse_task_completion_and_additions(file_path, start_date, end_date):
    """
    Read the WhatsApp file path, handle the date format, convert start and end dates to determine object,
    use regex to capture the date, time, user, and message. Additionally, capture user additions.
    """
    # Set to store users who have sent 'done', 'dn', or 'تم'
    done_users = set()
    
    # Set to store users who were added or who added someone
    added_users = set()
    added_by_others = set()

    # Read the WhatsApp file
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # format (dd.mm.yyyy)
    date_format = '%d.%m.%Y'

    # Convert the start and end dates to datetime objects
    start_date = datetime.strptime(start_date, date_format).date()
    end_date = datetime.strptime(end_date, date_format).date()

    # Regex patterns
    message_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
    added_pattern = re.compile(r'~\s*(.*?) was added')
    added_by_pattern = re.compile(r'~\s*(.*?) added ~\s*(.*)')

    current_user = None
    current_message = ""

    for line in lines:
        match = message_pattern.match(line)

        if match:
            # If there's a new match, process the previous message before resetting
            if current_user and current_message:
                # Process the previous message for task completion
                cleaned_message = current_message.strip().lower()
                if ('done' in cleaned_message or 
                    'dn' in cleaned_message or 
                    '✅' in cleaned_message or
                    'done✅' in cleaned_message or
                    'done' in cleaned_message or
                    'تم ' in cleaned_message or
                    'ضن' in cleaned_message or
                    re.search(r'\bتم\b', cleaned_message) or 
                    cleaned_message == 'تم' or 
                    'تم' in cleaned_message):
                    done_users.add(current_user)

            # Start a new message
            date_str, time_str, user, message = match.groups()
            current_user = user.strip()
            current_message = message.strip()

            # Convert message date to a date object and check if within date range
            message_date = datetime.strptime(date_str, date_format).date()

            if not (start_date <= message_date <= end_date):
                current_user = None  # Ignore this message if it's not in the date range
                current_message = ""
                continue

            # Check for added users or users added by someone
            added_match = added_pattern.search(current_message)
            added_by_match = added_by_pattern.search(current_message)

            if added_match:
                added_user = added_match.group(1).strip()
                added_users.add(added_user)

            if added_by_match:
                added_by = added_by_match.group(1).strip()
                added_user = added_by_match.group(2).strip()
                added_users.add(added_user)
                added_by_others.add(added_by)

        else:
            # If no match, it means this is a continuation of the current message (multi-line)
            current_message += " " + line.strip()

    # Process the last message after the loop ends
    if current_user and current_message:
        cleaned_message = current_message.strip().lower()
        if ('done' in cleaned_message or 
            'dn' in cleaned_message or 
            '✅' in cleaned_message or
            'done✅' in cleaned_message or
            'done' in cleaned_message or
            'تم ' in cleaned_message or
            'ضن' in cleaned_message or
            re.search(r'\bتم\b', cleaned_message) or 
            cleaned_message == 'تم' or 
            'تم' in cleaned_message):
            done_users.add(current_user)

    return done_users, added_users, added_by_others

# %% [markdown]
# # Part 2: Compare Group Members with Task Completion

# %%
def compare_group_with_done_users_and_added(done_users, added_users, added_by_others):
    """
    Comparing the list of groups that I got from 18.08.2024 (after the deadline one) until now.
    And find the user that didn't match with the existing user that send from 26.08.2024 (deadline 3)
    Also prints added users and who added them.
    """
    # Full list of group members provided
    group_members = {
	'*',
	'.',
	'Abdelhadi',
	'Ahmed Abdelsamie',
	'Ahmed Elkassrawy',
	'Ahmed Hesham',
	'Ahmed Jamal Sultan',
	'Ahmed Mounir',
	'Ahmed Salman',
	'Ali Ismail',
	'Amal Eltelbany',
	'Amany Mohammed',
	'Amira Hussein',
	'Asma 🪄',
	'Aysha',
	'David',
	'Elknz',
	'Eman Ashraf',
	'Esraa Ashraf',
	'Gehad',
	'Gehad🌺',
	'Habiba Gamal',
	'Hadi Heikal',
	'Hoda Salim',
	'Hüsam',
	'KHALED',
	'Karema',
	'MGamal',
	'Mahmoud Elsheemy',
	'Mai Samir',
	'Manar',
	'Mariam Osman',
	'Mennatallah',
	'Minno',
	'Mohamed Rabee',
	'Nada Fahmy',
	'NourEldien Alsharif',
	'Omnia',
	'Omnia Ashraf 🍁🍂',
	'Os!Rabe3',
	'Salah Mohamed',
	'Shahd Tamer',
	'Shaimaa',
	'Younes',
	'Yousef Saad',
	'Youssef Al-Saeedi',
	'Youssef Yousry',
	'Zeyad',
	'Zeyad Albadawy',
	'Ziad Nasser',
	'sarah farouq♡.',
	'~Motaz',
	'~X0🦂',
	'أَدْهَم عَلَّاَم',
	'رُفيدة',
	'رِيمُو♡',
	'عمر',
	'𓂆',
	'𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚',
	'𝓐𝓁𝒶𝒶',
    }


    # Find users in the group who have not completed the task
    not_done_users = group_members - done_users

    # Output users who did NOT complete the task
    print("\nUsers who did NOT complete the task:")
    if not_done_users:
        for user in sorted(not_done_users):
            print(user)
    else:
        print("All users completed the task.")

    print("\n==================================")
    print("\nUsers who completed the task:")
    for user in sorted(done_users):
        print(user)

    # Output users who were added to the group
    print("\n==================================")
    print("\nUsers who were added to the group:")
    for user in sorted(added_users):
        print(user)

    # Output users who added others to the group
    print("\n==================================")
    print("\nUsers who added someone to the group:")
    for user in sorted(added_by_others):
        print(user)

# %% [markdown]
# # Part 3: Main Function

# %%
def main():
    """Main Function to apply all the functions written above"""
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_3.txt'

    # Specify the date range (start date and end date)
    start_date = '26.08.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract users who completed the task between the start and end date
    done_users, added_users, added_by_others = parse_task_completion_and_additions(file_path, start_date, end_date)

    # Compare the task completion with the full list of group members and output added users
    compare_group_with_done_users_and_added(done_users, added_users, added_by_others)

if __name__ == '__main__':
    main()
# Out:
# Users who did NOT complete the task:
# *
# .
# Abdelhadi
# Ahmed Abdelsamie
# Ahmed Elkassrawy
# Ahmed Hesham
# Ahmed Jamal Sultan
# Ahmed Mounir
# Ahmed Salman
# Ali Ismail
# Amal Eltelbany
# Amany Mohammed
# Amira Hussein
# Asma 🪄
# Aysha
# David
# Elknz
# Eman Ashraf
# Esraa Ashraf
# Gehad
# Gehad🌺
# Habiba Gamal
# Hadi Heikal
# Hoda Salim
# Hüsam
# KHALED
# Karema
# MGamal
# Mahmoud Elsheemy
# Mai Samir
# Manar
# Mariam Osman
# Mennatallah
# Minno
# Mohamed Rabee
# Nada Fahmy
# NourEldien Alsharif
# Omnia
# Omnia Ashraf 🍁🍂
# Os!Rabe3
# Salah Mohamed
# Shahd Tamer
# Shaimaa
# Younes
# Yousef Saad
# Youssef Al-Saeedi
# Youssef Yousry
# Zeyad
# Zeyad Albadawy
# Ziad Nasser
# sarah farouq♡.
# ~Motaz
# ~X0🦂
# أَدْهَم عَلَّاَم
# رُفيدة
# رِيمُو♡
# عمر
# 𓂆
# 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚
# 𝓐𝓁𝒶𝒶
#
# ==================================
#
# Users who completed the task:
#
# ==================================
#
# Users who were added to the group:
#
# ==================================
#
# Users who added someone to the group:

# %% [markdown]
# # PART4: Generate a list of Group-members
# ### `(with a specific date until now)`

# %%
def extract_group_members(file_path, start_date, end_date):
    # Set to store unique users
    group_members = set()

    # Read the WhatsApp export file
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Specify the date format that matches your WhatsApp's export format (dd.mm.yyyy)
    date_format = '%d.%m.%Y'

    # Convert the start and end dates to datetime objects
    start_date = datetime.strptime(start_date, date_format).date()
    end_date = datetime.strptime(end_date, date_format).date()

    # Regex pattern to capture WhatsApp message with date, time, user, and message
    pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')

    for line in lines:
        match = pattern.match(line)
        if match:
            date_str, time_str, user, message = match.groups()

            # Convert message date to a date object
            message_date = datetime.strptime(date_str, date_format).date()

            # Check if the message date is within the specified date range
            if start_date <= message_date <= end_date:
                # Clean up the user name by stripping extra spaces or non-visible characters
                user = user.strip()

                # Debugging: Print the users being processed
                print(f"Processing message from: {user} at {date_str}")

                group_members.add(user)
        else:
            # Log lines that don't match to debug why certain messages are missed
            print(f"Line not matched: {line.strip()}")

    return group_members

def main():
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_3.txt'

    # Specify the date range (start date and end date)
    start_date = '18.08.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract group members who sent messages between the start and end date
    group_members = extract_group_members(file_path, start_date, end_date)

    # Output the group members
    print(f"\nGroup members who sent messages between {start_date} and {end_date}:")
    if group_members:
        for member in sorted(group_members):
            print(f"'{member}',")
    else:
        print("No messages found in the given date range.")

if __name__ == '__main__':
    main()
# Out:
# Line not matched: [2.05.2024, 12:42:34 AM] PS-StudyingDS 📔: ‎Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them.
# Line not matched: [2.05.2024, 12:42:34 AM] PS-StudyingDS 📔: ‎You created this group
# Line not matched: [2.05.2024, 12:42:52 AM] PS-StudyingDS 📔: ‎You changed the settings so only admins can edit the group settings
# Line not matched: [2.05.2024, 12:42:54 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [2.05.2024, 12:43:12 AM] PS-StudyingDS 📔: ‎You added Uncle Yos and khld
# Line not matched: [2.05.2024, 4:20:39 AM] PS-StudyingDS 📔: ‎You added Mo7 Nsr X, Momen, and 4 others. Tap to see all.
# Line not matched: [2.05.2024, 8:41:32 PM] khld: بسم الله ماشاءالله دول كلهم عايزين يقرأو الكتاب
# Line not matched: [2.05.2024, 8:41:35 PM] khld: دانتو سنتكو بيضا لو مالتزمتوش
# Line not matched: ‎[2.05.2024, 8:42:12 PM] khld: ‎sticker omitted
# Line not matched: [5.05.2024, 10:23:15 PM] ‪+20 114 773 5844‬: ‎‪+20 114 773 5844‬ left
# Line not matched: [7.05.2024, 2:17:53 AM] ~ Alaa Mahmoud: ‎~ Alaa Mahmoud joined using this group's invite link
# Line not matched: [7.05.2024, 2:25:58 AM] Hüsam: ⭕️ هنبدأ كتاب cracking the interview questions هنا ونتابع بعض ان شاء الله ،، هنبدا قريبا
# Line not matched: [7.05.2024, 2:36:09 AM] ~ Eman: ‎~ Eman joined using this group's invite link
# Line not matched: [7.05.2024, 3:15:15 AM] ~ Sleeping: ‎~ Sleeping joined using this group's invite link
# Line not matched: [7.05.2024, 3:43:05 AM] ‪+20 114 600 8867‬: ‎‪+20 114 600 8867‬ joined using this group's invite link
# Line not matched: [7.05.2024, 9:41:27 AM] ‪+971 56 258 8105‬: ‎‪+971 56 258 8105‬ joined using this group's invite link
# Line not matched: [7.05.2024, 2:59:16 PM] ‪+20 103 095 5315‬: ‎‎‪+20 103 095 5315‬ changed their phone number to a new number. ‎Tap to message or add the new number.
# Line not matched: [8.05.2024, 12:32:42 AM] ~ Don Abdrabo: ‎~ Don Abdrabo left
# Line not matched: [8.05.2024, 2:36:30 AM] ‪+20 112 915 2979‬: ‎‪+20 112 915 2979‬ left
# Line not matched: [8.05.2024, 3:00:07 PM] ‪+20 106 654 2944‬: ‎‪+20 106 654 2944‬ joined using this group's invite link
# Line not matched: [8.05.2024, 9:26:18 PM] ‪+20 114 600 8867‬: ‎‪+20 114 600 8867‬ left
# Line not matched: [10.05.2024, 4:35:26 AM] Hüsam: هنبدأ
# Line not matched: مش عارف هنبدأ امتى
# Line not matched: بس هنبدأ
# Line not matched: [10.05.2024, 2:37:22 PM] Hüsam: لو الاسبوع دا خلص ومبدأناش سموني حسام المتخاذل
# Line not matched: [10.05.2024, 5:00:25 PM] ~ Abdulrahman Ashraf: ‎~ Abdulrahman Ashraf joined using this group's invite link
# Line not matched: [11.05.2024, 5:27:34 PM] ~ Nada Zaki: ‎~ Nada Zaki joined using this group's invite link
# Line not matched: [12.05.2024, 11:20:15 PM] ‪+20 101 064 5335‬: ‎‪+20 101 064 5335‬ left
# Line not matched: [13.05.2024, 6:08:20 PM] ‪+20 106 485 0962‬: ‎‪+20 106 485 0962‬ left
# Line not matched: [16.05.2024, 12:30:56 AM] Hüsam: @201124044081
# Line not matched: ما تيلا يعم يوسف الاسبوع قرب يخلص والناس مستنيالي غلطة
# Line not matched: [16.05.2024, 12:48:24 AM] khld: سيب يوسف ف حاله
# Line not matched: [17.05.2024, 10:14:31 AM] Hüsam: طيب هناجلها ع الامتحانات مش ع انا متخاذل
# Line not matched: [18.05.2024, 3:38:05 PM] Uncle Yos: ايه 😂😂
# Line not matched: [18.05.2024, 4:53:41 PM] Hüsam: اصلا
# Line not matched: [18.05.2024, 4:54:28 PM] Uncle Yos: مش بعد الامتحانات ؟
# Line not matched: [18.05.2024, 11:24:17 PM] Hüsam: بعد ي فنان
# Line not matched: [18.05.2024, 11:24:27 PM] Ayash PS: ‎You added Ayash PS
# Line not matched: [19.05.2024, 3:32:00 PM] ~ Alaa Hussein: ‎~ Alaa Hussein joined using this group's invite link
# Line not matched: [21.05.2024, 11:15:39 PM] Ahmed Nageh PS: ‎Ahmed Nageh PS left
# Line not matched: [3.06.2024, 10:41:31 AM] Omr PS: ‎Omr PS left
# Line not matched: [20.06.2024, 6:28:44 PM] ‪+20 155 669 4608‬: ‎‪+20 155 669 4608‬ left
# Line not matched: [21.06.2024, 11:28:03 AM] Hüsam: عاد من الموت
# Line not matched:
# Line not matched: هنبدأ من انهاردة ان شاء الله كتاب cracking the code interview question او كما يُقال خُلاصة LeetCode لان الشركات بتجيب منه اسئلة الانترڤيوز
# Line not matched: [21.06.2024, 11:30:18 AM] Hüsam: مبدئيا الكتاب فيه قسمين
# Line not matched: الاول soft skills وتعمل ايه ف الانترڤيو ومرحلة قبل او بعد الانترڤيو وتعمل ايه فال cv وال FAANG ال process بتاعتها عاملة ازاي وبجد مفيد جدا بس انا مهتم بالقسم التاني، ف بصو بصة عليه هيفيدكم
# Line not matched: القسم التاني ال Topics فيها عن ال ps ومتقسم topics وشرح واسئلة عليهم
# Line not matched: [21.06.2024, 11:31:11 AM] Hüsam: هنعمل ايه احنا بردو؟
# Line not matched: هنشوف شرح الكتاب واسئلته ونذاكر من ال handbook،، الاتنين مع بعض هيخلوك تنين مجنح
# Line not matched: [21.06.2024, 11:37:09 AM] Hüsam: المطلوب؟
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: [21.06.2024, 5:13:48 PM] Hüsam: *يُفضل* نشوف شرح الهاند بوك الاول وبعدين نشوف شرح الكتاب، الكتاب ممكن تلاقوه advanced شوية لانه بيشرح ل واحد اوريدي فاهم ومذاكر قبل كدا
# Line not matched: [23.06.2024, 10:32:05 AM] Hüsam: وصلتو لفين ؟ حد ذاكر من ال هاند بوك ؟ او حد بص ع الكتاب ؟
# Line not matched: [23.06.2024, 10:40:31 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [23.06.2024, 10:46:52 AM] ~ Zoe💜: صباح الخير
# Line not matched: انا بصيت في الهند بوك في جزء الarrays
# Line not matched: بس لسا محلتش عليه عشان لسا داخلة امبارح وكدا
# Line not matched: واتراكم عليا ٣ ايام
# Line not matched: ف باذن الله هتشجع هحلهم
# Line not matched: [23.06.2024, 10:53:40 AM] ‪+20 128 811 3507‬: حليت مسائل الكتاب وأول 3 techniques من ال arrays في ال handbook
# Line not matched: بجيب الفكرة وبعرف اعملها trace بس بتطول معايا ككود 😅😅 لو حد عنده نصيحة بخصوص النقطة هذه
# Line not matched: [23.06.2024, 12:07:27 PM] ‪+20 122 561 0518‬: ‎‪+20 122 561 0518‬ left
# Line not matched: [23.06.2024, 12:34:14 PM] Marwa PS: ممكن حد يبعت الكتاب تاني لأن مش لاقياه ؟
# Line not matched: [23.06.2024, 12:34:37 PM] Hüsam: ..
# Line not matched: [23.06.2024, 12:35:04 PM] Marwa PS: شكرا شكرا
# Line not matched: [23.06.2024, 12:35:10 PM] Gehad PS: بصيت ع الهاند بوك  ان شاء الله النهارده أشوف أول توبيك من الكتاب
# Line not matched: [23.06.2024, 1:41:32 PM] Omnia Ashraf PS: هبدأ ف الكتاب دلوقتى
# Line not matched: [23.06.2024, 1:42:54 PM] ibrahim Orabi PS: فين الكتاب
# Line not matched: [23.06.2024, 1:43:34 PM] Omnia Ashraf PS: ....
# Line not matched: [23.06.2024, 1:44:13 PM] Omnia Ashraf PS: .....
# Line not matched: [23.06.2024, 1:44:45 PM] Mariam Osman PS: بصيت ف الهاند بوك وقريت التوبيك من الكتاب
# Line not matched: لسه هحل
# Line not matched: [23.06.2024, 1:44:48 PM] Younes PS: الرسالة دي مش عندي دخلت بعدها
# Line not matched: [23.06.2024, 1:45:33 PM] Gehad PS: المطلوب؟
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: [23.06.2024, 6:06:10 PM] ~ Tohamy: هو فين ال handbook ؟
# Line not matched: [23.06.2024, 6:07:04 PM] khld: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: [23.06.2024, 6:23:52 PM] Sayed Zayan PS: ‎This message was deleted.
# Line not matched: [23.06.2024, 7:10:41 PM] Karema PS: ‎Karema PS left
# Line not matched: [23.06.2024, 8:36:03 PM] ~ AalbertoSeka ☯️: نا لسه داخل جديد ي شباب ممكن حد يفهمني اي الدنيا 😅
# Line not matched: [23.06.2024, 9:34:12 PM] Habiba Gamal PS: المطلوب؟
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: [23.06.2024, 9:34:19 PM] Habiba Gamal PS: .
# Line not matched: [23.06.2024, 9:52:12 PM] ~ AalbertoSeka ☯️: طب واي ال deadline يوم الجمعة الجاية
# Line not matched: نتو بتسلمو ف حته معينه يعني ولا أي م فاهم نا كل مالي فهمته دلوقتي ني احل الاسئله دي صح كده ول ااي
# Line not matched: [24.06.2024, 11:38:18 AM] ‪+20 114 503 7756‬: ‎‪+20 114 503 7756‬ joined using this group's invite link
# Line not matched: [24.06.2024, 2:20:59 PM] Hüsam: انا خلصت ال arrays & strings
# Line not matched: [24.06.2024, 2:21:05 PM] Hüsam: عملتو ايه ؟
# Line not matched: [24.06.2024, 3:26:19 PM] Uncle Yos: انا مخلص ال arrays & strings من قبل كده ومستني نبدء في اللي بعده
# Line not matched: [24.06.2024, 4:46:32 PM] ~ Mazen: يعني سيكوانس القرايه هيبقا من الكتاب وبعدين الاسئله اللي ف الهاند بوك صح ؟
# Line not matched: [24.06.2024, 4:47:13 PM] Hüsam: *يُفضل* نشوف شرح الهاند بوك الاول وبعدين نشوف شرح الكتاب، الكتاب ممكن تلاقوه advanced شوية لانه بيشرح ل واحد اوريدي فاهم ومذاكر قبل كدا
# Line not matched: [24.06.2024, 4:48:29 PM] ~ Mazen: انا حاسس ان متلخبط بين حوار الهاند بوك والكتاب هو الكتاب ده اللي علي جيت هاب بتاعك صح اما الهاند بوك دي اسئله ليت كود ؟
# Line not matched: [24.06.2024, 5:22:53 PM] ~ Aya Ragab: هو طبيعي اني لما اعرف technique جديدة زي ال2 pointer او sliding window اني معرفش احل بيهم فالبداية لوحدي صح؟
# Line not matched: [24.06.2024, 5:23:23 PM] ~ Aya Ragab: اصل المسألة الeasy الي نزلت النهاردة دي لحد دلوقتي مش بتpass معايا
# Line not matched: ‎[24.06.2024, 5:23:27 PM] ~ Aya Ragab: ‎sticker omitted
# Line not matched: [24.06.2024, 5:26:39 PM] Hüsam: الاتنين فيهم شرح واسئلة
# Line not matched:
# Line not matched: الكتاب فيه شرح advanced لواحد فاهم والاسئلة شرحها قليل ومش بيفهمك السؤال ١٠٠٪؜ او ايه المطلوب
# Line not matched: ع كدا قولت نبدا مذاكرة من الهاند بوك + مجمع الاسئلة ال ف الكتاب وال شبهها ف لييت كود وحاططهم ف الريبو
# Line not matched:
# Line not matched: الهاند بوك شرحه رائع وبيديك الخلاصة والحاجات ال انت محتاج تركز عليها ف كل توبك وايه ال edge cases لكل حاجة وفيه اسئلة من لييت كود بردو ‎<This message was edited>
# Line not matched: [24.06.2024, 5:27:24 PM] Hüsam: انا مبعرفش احل sliding window لحد دلوقت 💀
# Line not matched:
# Line not matched: بس اكيد كل حاجة صعبة ف الاول ومحتاجة وقت ف بديهي يعني ‎<This message was edited>
# Line not matched: [24.06.2024, 5:28:30 PM] Gehad PS: التوبيك ده لما نيجي نحل عليه المرة دي خلينا نديله مدة اطول ياريت عشان معصبني أنا كمان
# Line not matched: [24.06.2024, 5:31:01 PM] Karim PS: هل دي علامة اني بحاول بقالي شوية ومش جاي معايا 😂😂
# Line not matched: [24.06.2024, 5:31:23 PM] Karim PS: ال two pointer تمام، بس ازاي بقى اعملها بال sliding windiw
# Line not matched: [24.06.2024, 5:31:57 PM] Karim PS: هل هنحل المسائل الي ف الهاند بوك، الي ف كل توبيك؟
# Line not matched: [24.06.2024, 5:32:09 PM] ~ Aya Ragab: ماشي ما اقصد دلوقتي انا قاعدة اذاكر الtechniques دي تمام، ف بيكون فدماغي اني عشان اكون "خلصت مذاكرتها" دا معناه اني عارفة اطبقها خلاص، اومال لما اجي اذاكرها المفروض اعمل ايه؟😂
# Line not matched: [24.06.2024, 5:32:47 PM] ~ Aya Ragab: يعني ايه الي لما اوصله اقول انا خلصت التوبيك دا
# Line not matched: [24.06.2024, 6:51:12 PM] أَدْهَم عَلَّاَم PS: انا مش عارف انتوا ماشيين في الكتاب ده ازاي، بس عموماً التوبيكس دي مينفعش تذاكريها وتحلي عليها كام مسألة في اليوم وخلاص
# Line not matched: ومينفعش تذاكري توبيك جديد الا لما تكوني قادرة تحلي المسائل البيزك اللي هي تطبيق مباشر علي التوبيك ويفضل كمان مسائل متوسطة
# Line not matched:
# Line not matched: انا لما كنت في ال Training كنا بناخد التوبيك يوم السبت في سيشن والسيشن بيكون فيها جزء عملي كبير وبيحل معانا مسائل، وبقيت الأسبوع بينزل شيت علي التوبيك نقعد نحل فيه، غير كدا الموضوع هيبقي صعب إن واحد بيذاكر التوبيكس دي لأول مرة يتمكن منها
# Line not matched: [24.06.2024, 6:53:02 PM] أَدْهَم عَلَّاَم PS: من الأخر لو بذاكر كل يوم توبيك جديد وبطبق عليه مسألتين وخلاص
# Line not matched: فا كدا هي مجرد معلومات باخدها واركنها
# Line not matched: والموضوع في ال ps مش بيمشي كدا الأساس هو الحل
# Line not matched: [24.06.2024, 7:11:57 PM] ~ Aya Ragab: اكيد فعلا عندك حق
# Line not matched: ‎[24.06.2024, 7:47:17 PM] ~ Tohamy: ‎image omitted
# Line not matched: [24.06.2024, 7:52:30 PM] Ali PS: لو دي حاجه ليها علاقه بال data science
# Line not matched: ف اول واحده أن يكون ف الداتا سيت بتاعتك كذا عنصر متكررين ورا بعض
# Line not matched: لكن التاني دا عباره عن كذا عنصر متكررين بس متوزعين ف الداتا سيت كلها مش لازم يبقوا ورا بعض
# Line not matched: [24.06.2024, 8:12:36 PM] ~ Tohamy: هو ده فال handbook شرح عن ال array عموما
# Line not matched: [24.06.2024, 8:13:05 PM] Ali PS: عموما هي نفس الفكره ونفس التعريف
# Line not matched: [24.06.2024, 8:13:12 PM] ~ Tohamy: فكرتك منطقية اعتقد هي القصد من الكلام فعلا
# Line not matched: [25.06.2024, 4:55:31 AM] Thoria PS: هل الكتاب بيفتح مع حد؟
# Line not matched: [25.06.2024, 4:55:57 AM] Omr PS: يب
# Line not matched: [25.06.2024, 4:56:11 AM] Thoria PS: الكتاب للي علي جيت هاب
# Line not matched: [25.06.2024, 4:56:20 AM] Thoria PS: مش الهاند بوك
# Line not matched: [25.06.2024, 4:56:26 AM] Omr PS: يب
# Line not matched: [25.06.2024, 4:56:38 AM] Thoria PS: مش بيفتح عندي
# Line not matched: [25.06.2024, 4:57:12 AM] NamNam Twtr: اعملي download
# Line not matched: [25.06.2024, 4:57:18 AM] Thoria PS: اوك شكرا
# Line not matched: [25.06.2024, 5:02:11 AM] ~ Hesham hatem: مش بيفتح معايا بردو بس اعتقد علشان الكتاب كبير و كنت قرأت انه اوقات بيحصل مشاكل من جيت هاب ف ال pdf او ال چوبيتر فايلز لما حجمهم بيكون كبير او المحتوى طويل يعني
# Line not matched: [25.06.2024, 5:04:37 AM] Thoria PS: لقيته pdf الحمد لله
# Line not matched: [25.06.2024, 5:06:38 AM] Hasnaa PS: ممكن تبعتيه
# Line not matched: [25.06.2024, 5:06:45 AM] ~ Hesham hatem: داونلود ولا اونلاين ؟ علشان عايز اشوفه بردو
# Line not matched: [25.06.2024, 5:08:21 AM] Thoria PS: https://www.haiocloud.com/app/uploads/2021/12/Cracking-the-Coding-Interview-189-Programming-Questions-and-Solutions-by-Gayle-Laakmann-McDowell-z-lib.org_.pdf
# Line not matched: [25.06.2024, 6:12:35 AM] ‪+20 103 010 9121‬: هو في مكان كويس اقدر اشتريه منه ؟ وال بتقروا منه اونلاين ؟
# Line not matched: [25.06.2024, 7:14:50 AM] Thoria PS: انا بقرأ اونلاين
# Line not matched: [25.06.2024, 7:14:55 AM] Thoria PS: معنديش فكره تشتري منين صراحه
# Line not matched: [25.06.2024, 7:15:04 AM] Thoria PS: بس انا شوفته قبل كدا في مكتبات عادي
# Line not matched: [25.06.2024, 7:16:43 AM] ‪+20 103 010 9121‬: تمام شكرا ليكي جدا
# Line not matched: [25.06.2024, 7:56:49 AM] Habiba Gamal PS: ‎This message was deleted.
# Line not matched: [25.06.2024, 7:57:44 AM] Habiba Gamal PS: ‎This message was deleted.
# Line not matched: [25.06.2024, 7:58:20 AM] Habiba Gamal PS: ‎This message was deleted.
# Line not matched: [25.06.2024, 8:25:25 AM] ~ AalbertoSeka ☯️: ‎This message was deleted.
# Line not matched: [25.06.2024, 8:27:52 AM] Hüsam: الهاند بوك مش كل اسئلته سهلة المهم الكتاب
# Line not matched: [25.06.2024, 8:28:13 AM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [25.06.2024, 12:23:20 PM] Thoria PS: كان عندي انترفيو علي ال stack ف خلصت من الهاند بوك ال stack
# Line not matched: (محليتش السؤال برضه) بس دا للي ذاكرته يعني مش من البدايه
# Line not matched: [26.06.2024, 1:49:03 AM] Yousef Fathy PS: حد معاه لينك الكتاب و الهاند بوك عشان هبدا انهارده ؟
# Line not matched: [26.06.2024, 1:50:30 AM] Mayar PS: +١
# Line not matched: [26.06.2024, 2:04:43 AM] ~ Norhan Mohamed: https://www.haiocloud.com/app/uploads/2021/12/Cracking-the-Coding-Interview-189-Programming-Questions-and-Solutions-by-Gayle-Laakmann-McDowell-z-lib.org_.pdf
# Line not matched:
# Line not matched: الكتاب
# Line not matched:
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched:
# Line not matched: الهاندبوك
# Line not matched: [26.06.2024, 12:27:29 PM] Rodina Twtr: Chapter 1 بس مش كدا ؟
# Line not matched: [26.06.2024, 12:34:22 PM] Hüsam: اه
# Line not matched: [26.06.2024, 12:35:09 PM] Hüsam: الديدلاين يوم الجمعة 📣
# Line not matched: [26.06.2024, 12:35:14 PM] Hüsam: هندخل ع الشابتر ال بعده
# Line not matched: [26.06.2024, 12:36:05 PM] Rodina Twtr: تمام جدًا
# Line not matched: [27.06.2024, 2:58:47 AM] Mayar PS: اللى بعده اللى هوا انهى عشان انا لسه جايه 👀
# Line not matched: [27.06.2024, 2:58:52 AM] Mayar PS: يعنى مخلصتوش غير شابتر ١ بس
# Line not matched: [27.06.2024, 7:02:41 AM] Hüsam: المطلوب؟
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: [27.06.2024, 11:07:50 AM] Hüsam: الديدلاين يوم الجمعة وهندخل ع الشابتر التاني just a reminder
# Line not matched: [28.06.2024, 2:08:02 PM] Hüsam: نعمل سيشن بالليل ن recap فيه الشابتر ؟
# Line not matched: [28.06.2024, 2:11:14 PM] khld: ياسلاااام
# Line not matched: انا ممكن اريكاب ليكم الدنيا مفيش اشطر مني ف مذاكرة الاراي 😂😂
# Line not matched: [28.06.2024, 2:12:22 PM] ~ Norhan Mohamed: ياريت
# Line not matched: [28.06.2024, 7:36:18 PM] Hüsam: ان شاء الله الساعة ١١ مساءا ندخل ندردش ف اول شابتر -لو مفقدتش الشغف-
# Line not matched: [28.06.2024, 7:37:15 PM] Ayash PS: أنتو مين
# Line not matched: [28.06.2024, 7:37:41 PM] Hüsam: يعم انا هدخل اقرا الكتاب ف ديسكورد
# Line not matched: [28.06.2024, 7:38:47 PM] Ayash PS: الخدعة والمهارة
# Line not matched: [28.06.2024, 7:38:48 PM] Ayash PS: والريكاب
# Line not matched: [28.06.2024, 8:35:53 PM] Younes PS: حد اشتري الكتاب يقولي اجيبه من فين
# Line not matched: [28.06.2024, 8:41:31 PM] Hüsam: 📣📣📣📣📣📣
# Line not matched: [28.06.2024, 10:02:55 PM] Hüsam: ممكن نخلي الميتنج بكرة الساعة ١٠ ؟
# Line not matched: وبعدها نبدا شابتر ٢ ان شاء الله
# Line not matched: [28.06.2024, 10:04:26 PM] Gehad PS: أنا مع أي حاجة تأجل ميتنج اليوم
# Line not matched: [28.06.2024, 10:04:41 PM] Gehad PS: مع إن بكرة الميعاد غالبا مش مناسب برده😂
# Line not matched: [28.06.2024, 10:04:51 PM] Rodina Twtr: +١
# Line not matched: [28.06.2024, 10:05:30 PM] Hüsam: ‎POLL:
# Line not matched: ميتنج بكرة نراجع سريعا شابتر ١
# Line not matched: ‎OPTION: ٨ (6 votes)
# Line not matched: ‎OPTION: ٩ (1 vote)
# Line not matched: ‎OPTION: ١٠ (1 vote)
# Line not matched: ‎OPTION: ١١ (18 votes)
# Line not matched: [28.06.2024, 10:05:39 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [29.06.2024, 9:37:26 AM] Hüsam: معادنا الساعة ١١ ان شاء الله
# Line not matched: [29.06.2024, 4:32:11 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [29.06.2024, 7:26:57 PM] PS-StudyingDS 📔: ‎You changed the group name to “PS-CtCIQ 📔”
# Line not matched: [29.06.2024, 7:31:04 PM] ~ Aya Ragab: ‎~ Aya Ragab left
# Line not matched: [29.06.2024, 10:57:35 PM] Hüsam: حد جاي ؟
# Line not matched: [29.06.2024, 10:58:31 PM] Ayash PS: معاك 18 واحد، لو ما حضروش افرض عليهم عقوبات وزود الضرايب. ‎<This message was edited>
# Line not matched: [29.06.2024, 10:58:54 PM] ‪+20 128 811 3507‬: اتفق
# Line not matched: [29.06.2024, 10:59:09 PM] Hüsam: انا كنت تعبان امبارح ع كدا اجلت
# Line not matched: [29.06.2024, 10:59:16 PM] Elhrbty PS: أنا
# Line not matched: [29.06.2024, 10:59:17 PM] Elhrbty PS: رايحين فين
# Line not matched: [29.06.2024, 10:59:20 PM] Hüsam: ودلوقت تعبان وموجود لو حد هييجي
# Line not matched: [29.06.2024, 10:59:21 PM] Islam PS: يلا تعالى نتناقش في البرفيكس و السفيكس
# Line not matched: [29.06.2024, 10:59:29 PM] Ayash PS: اللي يحضر ازرع له شجرة
# Line not matched: [29.06.2024, 10:59:47 PM] Hüsam: I AM IN
# Line not matched: [29.06.2024, 11:00:04 PM] Islam PS: ابعت اللينك
# Line not matched: ‎[29.06.2024, 11:00:15 PM] Hüsam: ‎image omitted
# Line not matched: [29.06.2024, 11:00:29 PM] Ayash PS: الموضوع كله
# Line not matched: Arr[R ]- Arr [L-1]
# Line not matched: [29.06.2024, 11:00:54 PM] Islam PS: خلاص الموضوع اتناقش مش داخل
# Line not matched: [29.06.2024, 11:01:33 PM] Ayash PS: لازم تختصر عشان تنتصر
# Line not matched: [29.06.2024, 11:02:06 PM] Islam PS: احنا عايزين المفيد احنا لسه هنفهم و بتاع
# Line not matched: [29.06.2024, 11:02:11 PM] Ayash PS: نوقش.*
# Line not matched: [29.06.2024, 11:02:41 PM] Islam PS: تمت المناقشة
# Line not matched: [29.06.2024, 11:02:48 PM] Ayash PS: يتم تأكيد
# Line not matched: [29.06.2024, 11:29:05 PM] Hüsam: قولت الناس مش هتدخل وهنام
# Line not matched: دخل ٣٠٠ واحد
# Line not matched: [29.06.2024, 11:30:11 PM] Ayash PS: 300؟
# Line not matched: [29.06.2024, 11:30:13 PM] Ayash PS: ما شاء الله
# Line not matched: [29.06.2024, 11:30:19 PM] Ayash PS: لم من كل واحد 5 جنيه
# Line not matched: [29.06.2024, 11:30:53 PM] Hüsam: بلحة ريأكت لاڤ
# Line not matched: [29.06.2024, 11:30:57 PM] Ayash PS: 300*5 ب 1500 ولو عملت مييتنج كل أسبوع يعني 1500*4 يعني 6000 جنيه
# Line not matched: ‎[29.06.2024, 11:31:05 PM] Ayash PS: ‎video omitted
# Line not matched: [29.06.2024, 11:31:56 PM] Yos S3D Twtr: الخمسة ده جنيه مش هتأثر مع حد كله لأجل الكومينيتي
# Line not matched: [29.06.2024, 11:32:11 PM] Ayash PS: لو معاك طبق كشري
# Line not matched: [29.06.2024, 11:33:42 PM] Hüsam: خلود كانت بتشرح hash
# Line not matched: [29.06.2024, 11:33:47 PM] Hüsam: دخلت تحل ع لييت كود
# Line not matched: [29.06.2024, 11:34:01 PM] Karim PS: جاي لكم لو مطولين 😂
# Line not matched: [29.06.2024, 11:34:11 PM] ~ Zoe💜: هو الميتنج خلص؟!
# Line not matched: [29.06.2024, 11:34:20 PM] Hüsam: لا
# Line not matched: [29.06.2024, 11:34:36 PM] ~ Zoe💜: طيب فين اللينك تاه وسط الشات ده كله
# Line not matched: [29.06.2024, 11:35:09 PM] Hüsam: https://discord.com/invite/SWBYmUWV
# Line not matched: لينك الديسكورد
# Line not matched: [29.06.2024, 11:43:36 PM] Ayash PS: السلام عليكم،
# Line not matched: فيه موقع كويس ممكن تشرحي عليه بدل ما تنقلي كل شوية ل leet @201096942964.
# Line not matched:
# Line not matched: والخط بتاعه friendly جدا، لو هتذاكر أو تحل مسألة محتاج تمسك فيها ورقة وقلم أو هتشرح لحد حاجة.
# Line not matched: اسمه: excalidraw.com
# Line not matched:
# Line not matched: وفيه خواص جميلة بال AI، وفيه ال laser pointer، اللي يا دوب بتشاور على الحاجة وبيروح تلقائيا،
# Line not matched: وفيه text to diagram، اديله شرح لأي حاجة وهيحولهالك ل diagram منظم بدل ما تقعدوا ترسموا رسومات مش مفهومة.
# Line not matched:
# Line not matched: جربوه؛ هيعجبكم. ‎<This message was edited>
# Line not matched: [29.06.2024, 11:44:19 PM] ~ Zoe💜: بارك الله فيك
# Line not matched: [29.06.2024, 11:45:00 PM] Ayash PS: آمين وإياكم ‎<This message was edited>
# Line not matched: [30.06.2024, 12:12:05 AM] khld: حلو جدا بس المره الجايه نبهوني اني المفروض اشرح
# Line not matched: [30.06.2024, 12:12:15 AM] khld: مش مره واحده امسكي الماوس واشرحي 😂😂
# Line not matched: [30.06.2024, 12:45:05 AM] ~ Zoe💜: هنقولك ارتجلي يا خلود حاضر
# Line not matched: ‎[30.06.2024, 12:47:05 AM] khld: ‎sticker omitted
# Line not matched: [30.06.2024, 12:47:07 AM] khld: بلوق
# Line not matched: [30.06.2024, 12:47:37 AM] ~ Zoe💜: بعدين يبه الارتجال للجدعان
# Line not matched: وانتي جدعة معروفة
# Line not matched: [30.06.2024, 12:50:30 AM] khld: طب ذاكري js عشان ماوركيش الجدعنه 😂😂😡
# Line not matched: [30.06.2024, 12:54:02 AM] ~ Zoe💜: كنت بزاكر في الكتاب شوية بتاع حسام 😂😂😂
# Line not matched: [30.06.2024, 2:25:16 AM] ‪+972 59‑426‑4855‬: ‎‪+972 59‑426‑4855‬ left
# Line not matched: ‎[30.06.2024, 3:29:32 AM] khld: ‎sticker omitted
# Line not matched: [30.06.2024, 3:29:44 AM] khld: شكلك هتركبي القطر قريب 😂😂
# Line not matched: [30.06.2024, 3:50:44 AM] Zeyad Albadawy PS: يعني لازم تقولك كتاب خلود 😞
# Line not matched: [30.06.2024, 3:50:59 AM] Zeyad Albadawy PS: ابق نزلي التاسكات انتي ونقول كتاب خلود 😂
# Line not matched: [30.06.2024, 3:52:25 AM] khld: المفروض كل حاجه تتنسب ليا 😩😔😔
# Line not matched: ‎[30.06.2024, 3:52:31 AM] khld: ‎sticker omitted
# Line not matched: [30.06.2024, 12:58:09 PM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [30.06.2024, 1:03:43 PM] Hüsam: ⛔️ المطلوب الاسبوع التاني
# Line not matched: خلصنا الاسبوع ال فات ال arrays & hash maps & strings
# Line not matched:
# Line not matched: الاسبوع دا ان شاء الله هنذاكر ال linked lists
# Line not matched:
# Line not matched: المطلوب
# Line not matched: - مذاكرة ال singly & doubly linked lists من الهاند بوك هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل اسئلتهم من هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/tree/master/chapter-02
# Line not matched:
# Line not matched: - الديدلاين يوم الحد الجاي (اسبوع كامل عشان نلم ال topic كله) ‎<This message was edited>
# Line not matched: [30.06.2024, 1:03:54 PM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [30.06.2024, 1:58:12 PM] ~ Noor: ‎~ Noor left
# Line not matched: [30.06.2024, 3:09:19 PM] ~ SAGDA FATHY: ‎~ SAGDA FATHY left
# Line not matched: ‎[1.07.2024, 1:28:59 AM] Yousef Fathy PS: ‎image omitted
# Line not matched: [1.07.2024, 1:32:05 AM] Omnia Ashraf PS: شابتر 2 😎
# Line not matched: [1.07.2024, 1:47:35 AM] ~ Habiba: ‎~ Habiba joined using this group's invite link
# Line not matched: [1.07.2024, 10:55:20 AM] Hüsam: قال رجل حكيم ذات مرة
# Line not matched: لو سؤال linked list مش بيتحل معاك اعمل dummy node
# Line not matched: [1.07.2024, 5:19:52 PM] ‪+20 109 744 1733‬: ‎‪+20 109 744 1733‬ left
# Line not matched: [1.07.2024, 10:54:01 PM] ‪+20 109 011 4233‬: ‎‪+20 109 011 4233‬ left
# Line not matched: [2.07.2024, 4:18:01 AM] ‪+20 101 171 3065‬: ‎‪+20 101 171 3065‬ left
# Line not matched: ‎[2.07.2024, 6:18:00 AM] Mai Samir PS: ‎image omitted
# Line not matched: [3.07.2024, 12:06:36 AM] khld: 🔴🔴
# Line not matched: من دلوقتي لحد الساعه 1 اتمني مايكونش فيه مسدجات غير *الفيدباك* بس  ي شباب
# Line not matched: [3.07.2024, 12:07:12 AM] Hüsam: منهم او من برا عادي هو حاططلك مصادر مساعدة
# Line not matched: [3.07.2024, 4:56:37 PM] Karema PS: ‎Karema PS left
# Line not matched: [3.07.2024, 7:48:11 PM] ‪+20 101 254 9090‬: ‎‪+20 101 254 9090‬ left
# Line not matched: [4.07.2024, 12:17:12 AM] Hüsam: 📣📣📣📣📣📣📣📣📣📣📣📣
# Line not matched: من دلوقت للساعة ١ ياريت ن share our progress ع نشوف مين معانا ومين معانا ومين علينا
# Line not matched: [4.07.2024, 11:55:25 AM] Hüsam: حد خلص حاجة ؟
# Line not matched: [4.07.2024, 12:36:16 PM] Amira PS: في حد بيحاول يخلص
# Line not matched: اسأل السؤال تاني بكرا😂
# Line not matched: [4.07.2024, 12:45:19 PM] ~ Habiba: هو انا لسه عامله join للجروب دا من قريب 😅ممكن اعرف بتذاكرو منين data structure
# Line not matched: [4.07.2024, 12:46:06 PM] Amira PS: ⛔️ المطلوب الاسبوع التاني
# Line not matched: خلصنا الاسبوع ال فات ال arrays & hash maps & strings
# Line not matched:
# Line not matched: الاسبوع دا ان شاء الله هنذاكر ال linked lists
# Line not matched:
# Line not matched: المطلوب
# Line not matched: - مذاكرة ال singly & doubly linked lists من الهاند بوك هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/linked-list/
# Line not matched: - حل اسئلتهم من هنا
# Line not matched: https://github.com/husamahmud/CTCIQ/tree/master/chapter-02
# Line not matched:
# Line not matched: - الديدلاين يوم الحد الجاي (اسبوع كامل عشان نلم ال topic كله)
# Line not matched: [4.07.2024, 12:46:44 PM] khld: نفس ال كنت قايلالك عليه ي حبيبه
# Line not matched: بلان واحده وبنوزعها 😂😂😂
# Line not matched: [4.07.2024, 12:47:07 PM] Amira PS: دي اخر حاجه كانت علينا وانا بذاكر م الهاند بوك وبسيرش لو وقف معايا حاجه بس بمر ب فتره تخاذل 😂
# Line not matched: ممكن حد يرشحلك مصادر احسن هنا
# Line not matched: [4.07.2024, 12:48:09 PM] ~ Habiba: انا كدا اطمنت على نفسي 😂😂
# Line not matched: [4.07.2024, 12:49:30 PM] khld: بتمري بفترة تخاذل ممممممم
# Line not matched: [4.07.2024, 12:50:14 PM] Amira PS: في الكتاب بس بلاش ظلم بقا
# Line not matched: [4.07.2024, 12:50:43 PM] khld: يعني انتي شايفاني ظالمه ممممممم
# Line not matched: [4.07.2024, 12:51:02 PM] Amira PS: يختاااااي مش لاعبه 😭😂😂😂
# Line not matched: ‎[4.07.2024, 12:51:20 PM] khld: ‎sticker omitted
# Line not matched: [4.07.2024, 3:09:54 PM] Mayar PS: 👀
# Line not matched: [4.07.2024, 3:49:12 PM] Ahmed Salman PS: ممكن المطلوب للاسبوع الاول
# Line not matched: [4.07.2024, 3:49:49 PM] Hüsam: المطلوب؟
# Line not matched: - اول شابتر ف الكتاب arrays - strings كلام بسيط بس الكتاب فيه معلومات انا متاكد ان الاغلب ميعرفهاش
# Line not matched: - ⁠مذاكرة ال arrays و ال strings من ال handbook
# Line not matched:
# Line not matched: ال deadline يوم الجمعة الجاية
# Line not matched: - لينك الكتاب
# Line not matched: https://github.com/husamahmud/CTCIQ
# Line not matched: الاسئلة ال ف الكتاب شرحها مش واضح ١٠٠٪؜ ف انا مجمع الاسئلة ال شبها ف leetcode هنا
# Line not matched: - ال arrays
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال hashing
# Line not matched: https://www.techinterviewhandbook.org/algorithms/hash-table/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: [4.07.2024, 3:50:28 PM] Ahmed Salman PS: تسلم ❤
# Line not matched: [4.07.2024, 3:51:25 PM] Habiba Gamal PS: م هتاخذو بريك اسبوع طيب😔
# Line not matched: [4.07.2024, 3:52:19 PM] Hüsam: لا انا كنت هوقف خالص ع الناس مش متجاوبة بس @201114317340 @201123034620 انقذو الجروب
# Line not matched: [4.07.2024, 3:53:05 PM] Habiba Gamal PS: هنشد جامد اوي 🌚
# Line not matched: [4.07.2024, 3:53:18 PM] Habiba Gamal PS: عارفه انك محتاج ترتاح يا حسام خد بريك
# Line not matched: ‎[4.07.2024, 3:53:54 PM] Hüsam: ‎sticker omitted
# Line not matched: ‎[4.07.2024, 3:54:08 PM] Habiba Gamal PS: ‎sticker omitted
# Line not matched: [4.07.2024, 3:54:10 PM] Hüsam: الديدلاين يوم الاحد
# Line not matched: ‎[4.07.2024, 3:55:22 PM] Habiba Gamal PS: ‎sticker omitted
# Line not matched: [4.07.2024, 3:55:50 PM] ‪+20 106 356 3698‬: ‎‪+20 106 356 3698‬ left
# Line not matched: [4.07.2024, 3:55:57 PM] Karim PS: عندي سؤال، هو مش كده احنا بنجري ف الكتاب
# Line not matched: يعني مش بندي كل توبيك حقه من حل وهكذا
# Line not matched: [4.07.2024, 3:57:12 PM] Hüsam: انا مدي اسبوع لل arrays & maps
# Line not matched: [4.07.2024, 3:57:18 PM] Hüsam: واسبوع لل linkedlist
# Line not matched: [4.07.2024, 3:57:22 PM] Hüsam: قليل ؟ 😀
# Line not matched: [4.07.2024, 3:57:48 PM] Hüsam: اسبوع بتراجع وبتحل
# Line not matched: [4.07.2024, 3:57:57 PM] Karim PS: أسبوع كتير 😀؟
# Line not matched: [4.07.2024, 3:58:12 PM] Karim PS: لا انا بذاكرها لأول مره يمكن ف مش براجع
# Line not matched: [4.07.2024, 3:58:23 PM] Karim PS: ف ماشي براحتي شوية
# Line not matched: [4.07.2024, 3:59:06 PM] Hüsam: بتذاكر ال arrays وال hashmaps ف اكتر من اسبوع ي كريم ؟
# Line not matched: [4.07.2024, 3:59:21 PM] Hüsam: @201025332113
# Line not matched: [4.07.2024, 3:59:33 PM] Karim PS: حل يا حسام
# Line not matched: [4.07.2024, 3:59:51 PM] Karim PS: مش حاسس اني بعرف احل كويس
# Line not matched: [4.07.2024, 3:59:53 PM] Karim PS: فاهم
# Line not matched: [4.07.2024, 4:00:02 PM] Karim PS: ف طبيعي
# Line not matched: ‎[4.07.2024, 4:00:21 PM] Hüsam: ‎image omitted
# Line not matched: [4.07.2024, 4:01:07 PM] Karim PS: انا بحل مع نيت كود + الديلي الي بتنزله
# Line not matched: [4.07.2024, 4:02:28 PM] Hüsam: حد تاني معترض عن ان اسبوع قليل ع ال topic ال بننزله ؟
# Line not matched: [4.07.2024, 4:02:53 PM] Karim PS: انا مش معترض
# Line not matched: انا بقولك وجهة نظري
# Line not matched: [4.07.2024, 4:03:02 PM] Karim PS: ف ناس بالنسبة لها التوبيك سهلة
# Line not matched: [4.07.2024, 4:03:14 PM] Karim PS: ف محتاجين يدخلوا ع الحاجات الي بعد كده
# Line not matched: [4.07.2024, 4:08:35 PM] Habiba Gamal PS: انا كنت ذكرت شويه برضو حسيت الوضع رخم بالنسبالي وان في ناس فاهمه بتجري ف قولت م وقتو 🙂
# Line not matched: [4.07.2024, 4:24:48 PM] Amira PS: لا لا كملي حتي لو لسه المسائل رخمه عادي
# Line not matched: ‎[4.07.2024, 4:28:39 PM] NamNam Twtr: ‎video omitted
# Line not matched: [4.07.2024, 4:29:02 PM] Hüsam: Ma boy
# Line not matched: [4.07.2024, 4:32:06 PM] Omnia Ashraf PS: لسه جبت عامل مساعد من برا ف ي مسهل 😂😂
# Line not matched: [4.07.2024, 5:29:32 PM] Mai Samir PS: انا مش عارفة حاسة بالنسبالى قليل ممكن عشان حاليا بشتغل وفى حاجات تانية بعملها بس انا مش مقياس اكيد
# Line not matched: [4.07.2024, 6:26:09 PM] Amira PS: @905525834783 نخلي الديدلاين اسبوع ونص ؟
# Line not matched: [4.07.2024, 6:48:23 PM] Hasnaa PS: اسبوعين كويس
# Line not matched: [4.07.2024, 8:09:16 PM] ‪+20 109 179 2456‬: ‎‪+20 109 179 2456‬ left
# Line not matched: [4.07.2024, 9:17:48 PM] Hüsam: مش هنخلص الكتاب كدا
# Line not matched: [4.07.2024, 9:17:55 PM] Hüsam: اسبوع ف اللينكد ليست
# Line not matched: [4.07.2024, 9:18:07 PM] Hüsam: امال ال graph و recursion
# Line not matched: [4.07.2024, 9:57:38 PM] Ayash PS: المذاكرة ما بتخلصش
# Line not matched: [4.07.2024, 10:02:20 PM] Hüsam: يعم الكتاب الكتااااب
# Line not matched: [4.07.2024, 10:04:43 PM] Ayash PS: ما هو الكتاب فيه ريكرجن والريكرجن ما بيخلصش
# Line not matched: [4.07.2024, 10:17:10 PM] Karim PS: ف ديدلاين يعني نخلص فيه الكناب 😂
# Line not matched: [4.07.2024, 11:29:10 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [4.07.2024, 11:29:10 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [4.07.2024, 11:30:15 PM] Hüsam: هنظم ال roamap واظبط الديدلاينز ونبدأ من الاول، لعل وعسى الناس تشد حيلها المرادي :)
# Line not matched: ‎[6.07.2024, 12:53:47 AM] Hüsam: ‎video omitted
# Line not matched: [6.07.2024, 12:54:17 AM] Hüsam: - هنبدأ من الاول ان شاء الله هنذاكر DSA
# Line not matched: - ⁠هنمشي شوية ف ال handbook
# Line not matched: - ⁠وبعدين ندخل ع الكتاب ان شاء الله
# Line not matched: [6.07.2024, 12:54:17 AM] Hüsam: المطلوب؟
# Line not matched: - هنذاكر arrays & strings & hash table ونحل عليهم اسئلة من LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي ‎<This message was edited>
# Line not matched: [6.07.2024, 12:54:55 AM] Hüsam: انا اتحمست صراحة بعد الميتنج وعايز ارجع احل ع لييت كود، حد جاي؟
# Line not matched: [6.07.2024, 12:55:43 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [6.07.2024, 12:56:00 AM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [6.07.2024, 12:56:09 AM] Amira PS: النهارده day 1 ليا🥳🥳🥳🥳
# Line not matched: [6.07.2024, 12:56:49 AM] Hasnaa PS: على ديس دلوقتى يعنى ؟
# Line not matched: [6.07.2024, 12:57:11 AM] Hüsam: عموما
# Line not matched: [6.07.2024, 12:57:19 AM] khld: ‎This message was deleted.
# Line not matched: [6.07.2024, 12:57:53 AM] Hasnaa PS: اوكيه
# Line not matched: انا عاوزة ابدا اخل على ليت كود عموما
# Line not matched: [6.07.2024, 1:27:20 AM] Mai Samir PS: ممكن اضيف حد فى الجروب؟
# Line not matched: [6.07.2024, 1:36:13 AM] Hüsam: مفيش مشاكل
# Line not matched: [6.07.2024, 1:36:39 AM] Hüsam: ياريت تبعتي المطلوب عشان تدخل تفهم الدنيا
# Line not matched: [6.07.2024, 1:38:16 AM] Hüsam: ⛔️⛔️⛔️⛔️⛔️⛔️⛔️⛔️⛔️⛔️⛔️⛔️
# Line not matched: عدد الجروب كبير جدا ومش كله بيذاكر معانا
# Line not matched: ف من اول ديدلاين ال مش حالل هيطلع م الجروب ‎<This message was edited>
# Line not matched: ‎[6.07.2024, 1:38:48 AM] Ayash PS: ‎sticker omitted
# Line not matched: [6.07.2024, 1:41:04 AM] Mai Samir PS: تمام شكرا جدا هبعت الرقم عشان بيقولى الادمن بس اللى بيضيف
# Line not matched: ‎[6.07.2024, 1:41:30 AM] Mai Samir PS: ‎Contact card omitted
# Line not matched: [6.07.2024, 1:41:55 AM] Mai Samir PS: اه اكيد هبعتله الرسالة
# Line not matched: [6.07.2024, 1:42:14 AM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [6.07.2024, 1:42:44 AM] Mai Samir PS: وه... الموضوع جد لا لازم نذاكر كويس المرة دى بقى😂
# Line not matched: [6.07.2024, 1:45:30 AM] Mayar PS: مش احنا بنحل اصلا السؤال اللى بتنزلهولنا كل يوم
# Line not matched: [6.07.2024, 1:45:52 AM] Mayar PS: الميتينج دا اجمل ميتينج دخلته ف حياتى والله ايه السكر دا
# Line not matched: [6.07.2024, 1:46:06 AM] Hasnaa PS: ماننزل السؤال فى مكان تانى غير نوشن
# Line not matched: عشان مش بعرف اجيبه من هناك
# Line not matched: [6.07.2024, 1:46:16 AM] Mayar PS: خلود مبهوره بيكي
# Line not matched: @201096942964
# Line not matched: [6.07.2024, 1:48:58 AM] Hüsam: دي حاجة ودي حاجة
# Line not matched: [6.07.2024, 1:49:03 AM] Hüsam: ليه ؟
# Line not matched: [6.07.2024, 1:49:25 AM] Mayar PS: اللى تشوفه انا تمام جايه
# Line not matched: ‎[6.07.2024, 1:52:29 AM] khld: ‎sticker omitted
# Line not matched: [6.07.2024, 1:56:40 AM] Hasnaa PS: علطول لما بضغط اللينك المسالة مش بيوصلنى للمسالة على ليت
# Line not matched: مش عارفه دا بسبب ايه
# Line not matched: [6.07.2024, 1:57:47 AM] Hüsam: HOW
# Line not matched: ‎[6.07.2024, 1:59:38 AM] Hasnaa PS: ‎image omitted
# Line not matched: [6.07.2024, 1:59:56 AM] Hüsam: دوسي ع رقم السؤال
# Line not matched: [6.07.2024, 2:00:13 AM] Hasnaa PS: اه خلاص
# Line not matched: [6.07.2024, 2:10:10 AM] Mayar PS: مش هيبقى فيه اسئله زى قبل كدا ؟ يعنى احنا اللى هنجيب اسئله  عشوائيه؟
# Line not matched: [6.07.2024, 2:10:43 AM] Mayar PS: زى هنا كدا كان فيه اسئله
# Line not matched: [6.07.2024, 2:14:23 AM] Mayar PS: اه اوكيه هيا نفس الاسئله لحد دلوقتي ف اللينك معانا
# Line not matched: [6.07.2024, 2:17:18 AM] Mai Samir PS: اه كنت عايزة اتاكد من النقطة دى
# Line not matched: [6.07.2024, 2:18:00 AM] Hüsam: ف ال handbook اسئلة (الافكار الاساسية لل topic)
# Line not matched: [6.07.2024, 2:19:41 AM] Mayar PS: هيا نفسها اللى انت حاطط اللينكات بتاعتها ف لينك جيت هب؟
# Line not matched: [6.07.2024, 2:22:13 AM] Hüsam: لا هنأجل ال ف github شوية
# Line not matched: [6.07.2024, 2:22:33 AM] Mayar PS: اوكيه زى الفل💗💗
# Line not matched: [6.07.2024, 2:28:19 AM] Mayar PS: . لينك handbook  ال hashing  هنا هوا نسي يحطو ف المسدج الجديده  بس هوا معانا عشان ميقعش منكو 🌚
# Line not matched: [6.07.2024, 2:29:02 AM] Hüsam: لا منسيتش حاجة
# Line not matched: [6.07.2024, 2:29:48 AM] Mayar PS: علينا ال array, strings بس ؟
# Line not matched: [6.07.2024, 2:29:57 AM] Hüsam: اه
# Line not matched: [6.07.2024, 2:31:59 AM] Mayar PS: حلو 😂
# Line not matched: انت كاتب ف اول المسدج ان معانا الhash table  ف افتكرته معانا وكنت بجمع الماتريال ع اللاب
# Line not matched: [6.07.2024, 2:32:43 AM] Mayar PS: اسفه👀
# Line not matched: [6.07.2024, 2:32:57 AM] Hüsam: المطلوب؟
# Line not matched: - هنذاكر arrays & strings ونحل عليهم اسئلة ع LeetCode
# Line not matched: - ⁠ال array
# Line not matched: https://www.techinterviewhandbook.org/algorithms/array/
# Line not matched: - ⁠ال strings
# Line not matched: https://www.techinterviewhandbook.org/algorithms/string/
# Line not matched: - لو حد معندوش خلفيه عن ال data structures ياريت يذاكرهم الاول وبعدين يذاكر من ال handbook ع فيه خلاصة الخلاصة والحاجات ال تركز عليهم ف الانترڤيوز
# Line not matched: - ⁠ذاكر من اي حتة المهم بعد م تخلص تذاكر الكلمتين ال ف ال handbook وتحل عليهم
# Line not matched:
# Line not matched: الديدلاين يوم ١٥/٧
# Line not matched:
# Line not matched: متفرهدونيش ع انا صحتي ع قدي
# Line not matched: [6.07.2024, 2:33:37 AM] Hüsam: ⛔️ عدد الجروب كبير جدا ومش كله بيذاكر معانا
# Line not matched: ف من اول ديدلاين ال مش حالل هيطلع م الجروب
# Line not matched: [6.07.2024, 2:33:46 AM] Ayash PS: ‎You deleted this message as admin
# Line not matched: [6.07.2024, 2:34:06 AM] Ayash PS: ‎You deleted this message as admin
# Line not matched: [6.07.2024, 2:34:18 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [6.07.2024, 2:34:54 AM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [6.07.2024, 2:34:59 AM] PS-StudyingDS 📔: ‎You pinned a message
# Line not matched: [6.07.2024, 2:45:49 AM] Uncle Yos: انا جاي
# Line not matched: [7.07.2024, 12:16:08 PM] ~ Youssif Hassan: ‎~ Youssif Hassan left
# Line not matched: [7.07.2024, 1:17:58 PM] khld: ‎khld left
# Line not matched: [7.07.2024, 2:55:34 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [7.07.2024, 10:10:30 PM] Younes PS: حد فاضي نبدء الشابتر علي ديسكورد علي 12 كدة
# Line not matched: [7.07.2024, 10:13:31 PM] ~ Zoe💜: انهي شابتر ؟!
# Line not matched: عشان عايزة اللي يساعدني ازاكر معاه
# Line not matched: [7.07.2024, 10:13:38 PM] Younes PS: شابتر 1
# Line not matched: [7.07.2024, 10:13:45 PM] Younes PS: مش هما تقريبا بدءو من الاول تاني
# Line not matched: [7.07.2024, 10:25:30 PM] ibrahim Orabi PS: معاك
# Line not matched: [7.07.2024, 10:27:35 PM] ~ Zoe💜: انا برجع واحدة هتبقوا قاعدين
# Line not matched: [7.07.2024, 10:28:16 PM] Younes PS: ان شاء الله
# Line not matched: [7.07.2024, 10:32:10 PM] Mai Samir PS: انا ممكن اجى برضه اشوف كدة يمكن اطلع بذاكر غلط😂
# Line not matched: [7.07.2024, 11:18:45 PM] Hasnaa PS: ++
# Line not matched: [7.07.2024, 11:55:33 PM] Younes PS: ٥ وهنبدء يا شباب
# Line not matched: [7.07.2024, 11:58:19 PM] Mai Samir PS: هو ده هيبقى ميتينج كدة برضه فى ال weekly meeting?
# Line not matched: [7.07.2024, 11:59:07 PM] Younes PS: لا ده بس هنذاكر اللي هنقدر عليه من الشابتر
# Line not matched: [8.07.2024, 12:00:36 AM] Mai Samir PS: اوكيه انا بس مش متعودة افتح ديسكورد و مش بستخدمه فكنت عايزة اعرف هيكون عبارة عن ميتينج وكدة ولا ايه
# Line not matched: [8.07.2024, 12:01:43 AM] Younes PS: بنذاكر
# Line not matched: اللي عنده حاجة عاوز يسال عليها وحد عارف بيجاوبه
# Line not matched: لو في توبك نتناقش فيه
# Line not matched: [8.07.2024, 12:09:58 AM] Mai Samir PS: هو ايه اللي حصل انا مش فاهمة😂
# Line not matched: [8.07.2024, 12:10:25 AM] Younes PS: انا موجود في ال genral
# Line not matched: [8.07.2024, 12:10:55 AM] ibrahim Orabi PS: فاتحين فين
# Line not matched: [8.07.2024, 12:21:19 AM] Younes PS: general
# Line not matched: [8.07.2024, 1:41:26 AM] Mai Samir PS: https://leetcode.com/explore/learn/card/the-leetcode-beginners-guide/
# Line not matched: [8.07.2024, 1:41:40 AM] Mai Samir PS: @201148705548
# Line not matched: [8.07.2024, 1:44:29 AM] Mai Samir PS: هالو ي شباب ده لينك ل حاجة اسمها
# Line not matched: Leet code Beginner's Guide
# Line not matched: لو حد مش متعود على الويب سايت بتاع ليت كود و عايز يعرف ينڤيجات ازاى وكدة ممكن بيص عليه سريعا.
# Line not matched: [8.07.2024, 1:47:15 AM] Mai Samir PS: انا مش عارفة مفروض اشيروه هنا ولا فى جروب الريسورسز عشان الادمن و نظام الجروبات وكدة😂
# Line not matched: بس كنا فى ميتينج دلوقتى انا و ابراهيم و يونس و كنا اتكلمنا على الموضوع ده
# Line not matched: شكرا على وقتكم ي شباب
# Line not matched: [8.07.2024, 1:59:41 AM] Mai Samir PS: حاجة كمان حابة اضيفها لما اتكلمت مع الشباب فى الميتينج قولتلهم انا بذاكر ازاى و كنت عايزة اشارك معاكم طريقة مذاكرتى عشان ممكن تفيد حد
# Line not matched: و على فكرة أنا مستوايا مش عالى اوى
# Line not matched: طبعا ادمن الجروب كان حاطط فى ال pinned messages اللى المفروض نذاكره ف وقت معين
# Line not matched: ارراى و سترينج فى عشر ايام يعنى خمسة للاراى و خمسة للسترينج
# Line not matched: ممكن اول يوم يبقى مذاكرة للتوبيك بشكل عام من اى مصدر يوتيوب مثلا و بقيت الاربع ايام فى سشكن فى الهاندبوك اسمه essential questions
# Line not matched: ممكن كل يوم من الاربع ايام ناخد مسألة واحدة من المسائل الموجودة فيه (دى عبارة عن لينكات مسائل على ليت كود) نحاول نحلها مع نفسنا فى ساعة لو معرفناش ناخد اسم المسألة برقمها و نشرس على يوتيوب هتلاقى كذا حد شارحها
# Line not matched: وعادى جدا انك تفهم المسألة غلط
# Line not matched: وعادى انك متعرفش تحل أو حتى متعرفش تفكر
# Line not matched: بس المهم تاخد خبرة و تعرف حلول أو شرح من كذا حد ده هيخليك تعرف تفكر قدام
# Line not matched: دى كانت وجهة نظرى و اكيد اكيد فى ناس هنا اشطر منى و عندها بلان افضل بس قولت ممكن كلامى يفرق مع حد مبتدأ زيي ‎<This message was edited>
# Line not matched: [9.07.2024, 12:10:54 AM] Hüsam: ميعاد ال progress sharing 📢
# Line not matched: عملتو ايه انهاردة
# Line not matched: [9.07.2024, 12:25:50 AM] ☆아말☆أمل PS: انا اول مرة اذاكر ds فلسه بحاول استوعب مصطلحات بشوفها و بذاكر فال array و حليت مسألة
# Line not matched: انا عارفه انى بطيئة 🌚
# Line not matched: بس هحاول انجز عشان اكون معاكم على نفس الخط ان شاء الله
# Line not matched: [9.07.2024, 12:27:18 AM] Hasnaa PS: راجعت على ال array
# Line not matched: [9.07.2024, 12:27:37 AM] Hasnaa PS: ان شاء الله اذاكر ال string بكرا او النهاردة على حسب
# Line not matched: [9.07.2024, 12:55:20 AM] Mai Samir PS: انا كنت بدأت فى حل مسألة
# Line not matched: Product of array except self
# Line not matched: امبارح مع نفسي تفكير ووقف معايا مشكلة time limit exceeded
# Line not matched: و مكنتش عارفة افكر ازاى اعملها امبروڤمنت ف شوفت انهاردة شرح فديو ليها على قناة احمد الامام و كام بيشرحها بشمهندس اسمه احمد جمال بجد شارحها واحدة واحدة و كان فديو كويس
# Line not matched: [9.07.2024, 12:56:16 AM] Mai Samir PS: براڤو👏
# Line not matched: [9.07.2024, 12:56:33 AM] Mai Samir PS: عظيم 👏
# Line not matched: [9.07.2024, 12:58:59 AM] Hüsam: مفيش حد بطيء المهم بتستفادي وبتطبقي
# Line not matched: [9.07.2024, 12:59:02 AM] Hüsam: مسالة وقت
# Line not matched: [9.07.2024, 12:59:45 AM] Hüsam: السؤال دا اول مرة احله قعدت فيه ٣ ايام
# Line not matched: [10.07.2024, 10:53:29 PM] Younes PS: حد فاضي ندخل ديس علي 11 نحل مسئلة كدة ولا حاجة
# Line not matched: [10.07.2024, 11:01:02 PM] Amany Mohammed PS: +1
# Line not matched: [10.07.2024, 11:06:32 PM] Younes PS: احنا في general ياشباب اللي حابب يجي
# Line not matched: [10.07.2024, 11:37:52 PM] Mai Samir PS: بتحلو سترينج ولا ايه ؟
# Line not matched: [10.07.2024, 11:39:12 PM] Younes PS: Product of Array Except Self
# Line not matched: [11.07.2024, 10:37:20 PM] Hüsam: بيقولك مرة ديدلاين بعد ٤ ايام
# Line not matched: [11.07.2024, 10:39:31 PM] Omnia Ashraf PS: حسام : ان كنت ناسى افكرك😂😂😂
# Line not matched: [11.07.2024, 10:40:29 PM] Hüsam: 👹
# Line not matched: ‎[11.07.2024, 10:41:57 PM] Gehad PS: ‎sticker omitted
# Line not matched: [11.07.2024, 10:44:02 PM] Islam PS: اي اللي 4 ايام هو انتم وديتو الاسبوع فين
# Line not matched: [11.07.2024, 10:44:03 PM] Islam PS: هو انتم بتاكلوا في الايام يعم ولا اي
# Line not matched: [11.07.2024, 10:49:29 PM] Hüsam: صباح الفل
# Line not matched: [13.07.2024, 2:15:13 AM] Hüsam: جماعة
# Line not matched: الديديلاين بعد يومين
# Line not matched: وال مذاكرش هيطلع من الجروب عشان محدش يزعل 😔
# Line not matched: [13.07.2024, 2:37:29 AM] Youssef Elmelegy PS: ‎Youssef Elmelegy PS left
# Line not matched: [13.07.2024, 2:43:44 AM] Gehad PS: ‎Gehad PS left
# Line not matched: [13.07.2024, 3:09:54 AM] Amany Mohammed PS: هوا إيه اللي المفروض هايحصل بعد ال deadline ؟
# Line not matched: [13.07.2024, 3:10:58 AM] Ayash PS: حسام هيطردني من الجروب ‎<This message was edited>
# Line not matched: [13.07.2024, 3:13:09 AM] Mayar PS: حسام:انا بصفى مين ف صفى
# Line not matched: ‎[13.07.2024, 4:00:56 AM] NamNam Twtr: ‎sticker omitted
# Line not matched: [13.07.2024, 4:43:53 AM] Younes PS: يعني هيبقي سيشن ولا تاسك ولا ايه
# Line not matched: [13.07.2024, 4:49:35 AM] Hasnaa PS: التقييم ازاى!
# ...
# Line not matched: ‎[2.09.2024, 12:14:29 PM] Hasnaa PS: ‎image omitted
# Line not matched: [2.09.2024, 12:32:32 PM] Salah Mohamed Twtr: الله عال Indentation
# Line not matched: [2.09.2024, 12:44:22 PM] Hasnaa PS: ‎This message was deleted.
# Line not matched: [2.09.2024, 1:03:18 PM] Ahmed Jamal Sultan PS: فيه طريقه اسهل من دي
# Line not matched: ‎[2.09.2024, 1:05:11 PM] Ahmed Jamal Sultan PS: ‎image omitted
# Line not matched: [2.09.2024, 1:55:48 PM] Hasnaa PS: ياريت نعمل جروب الناس تنزل حلولها فيه
# Line not matched: و ياه لو كان على الديلى تبقى جمدان
# Line not matched: [2.09.2024, 1:57:21 PM] Hasnaa PS: يلا  ps - daily leetcode
# Line not matched: @905525834783
# Line not matched: [2.09.2024, 2:03:40 PM] Hasnaa PS: بس هو & بتعمل ايه بالظبط
# Line not matched: حاسانى قريتها قبل كدا لكن مش فاكرة
# Line not matched: [2.09.2024, 2:06:54 PM] Ahmed Jamal Sultan PS: دي اسمها and مهمتها بتشوف ال most significant bit للرقم يعني بتحوله باينري وتشوف ايه اكبر bit ليه لو الرقم باور ٢ لازم تبقى اعلى bit ب 1 ف لو عملنا and ليه مع الرقم اللي قبله لو طلع ناتج ال and gate ب 1 كده ده مش رقم باور ٢ لو طلع الناتج ب صفر كده اللي معايا رقم باور ٢
# Line not matched: [2.09.2024, 2:41:15 PM] Hüsam: Solutions
# Line not matched: [2.09.2024, 3:15:38 PM] Hasnaa PS: دا ميت
# Line not matched: ماحدش بيعت عليه غيرى
# Line not matched: [2.09.2024, 3:54:06 PM] Hüsam: جامدة دي
# Line not matched: [2.09.2024, 3:54:31 PM] Hüsam: اما الناس بتلاقيكي بتبعتي هيشاركوكي
# Line not matched: [2.09.2024, 8:05:12 PM] Habiba Gamal PS: فكره حلوه والله نعمل جروب او نستخدم جروب الsolution نفسو ان نحل مجموعه مسائل ولزم نتناقش فيها يوميا او نشارك حالنا بحيث نشوف حلول كتير مختلفه واللي مكسل يتشجع
# Line not matched: [2.09.2024, 10:38:18 PM] ~ Zoe💜: حلو ده
# Line not matched: [3.09.2024, 1:03:56 AM] ~ Islam El-Naggar: ‎~ Islam El-Naggar requested to join
# Line not matched: [3.09.2024, 1:04:03 AM] ~ Esraa Salah: ‎~ Esraa Salah requested to join
# Line not matched: [3.09.2024, 1:56:24 AM] Hasnaa PS: هانبقى نحل الديلى
# Line not matched: [3.09.2024, 8:37:25 AM] ~ Mahmoud: ‎~ Mahmoud requested to join
# Line not matched: [3.09.2024, 8:37:25 AM] ~ Mahmoud: ‎~ Mahmoud requested to join
# Line not matched: [4.09.2024, 1:45:38 PM] ~ Tarek: ‎~ Tarek requested to join
# Line not matched: [4.09.2024, 11:01:08 PM] Amany Mohammed PS: Done
# Line not matched: [4.09.2024, 11:02:29 PM] Younes PS: ✅
# Line not matched: [4.09.2024, 11:02:42 PM] Abdelhadi PS: Done
# Line not matched: [4.09.2024, 11:02:58 PM] Amira PS: تم إنجاز
# Line not matched: [4.09.2024, 11:09:30 PM] مُحَمَّد PS: Done
# Line not matched: [5.09.2024, 9:53:24 AM] Salah Mohamed Twtr: Done
# Line not matched: [5.09.2024, 3:29:40 PM] ☆아말☆أمل PS: Done
# Line not matched: [5.09.2024, 3:43:57 PM] Hüsam: اعذروني يجماعة اسف، مضغوط ف الشغل وعندي فاينل ومسافر بكرة والدنيا ملغبطة معايا
# Line not matched:
# Line not matched: ال ذاكر يقول فضلا
# Line not matched: [5.09.2024, 3:47:10 PM] Mohamed Ibrahim PS: ربنا يقويك يخويا
# Line not matched: [5.09.2024, 3:47:14 PM] Mohamed Ibrahim PS: انا تم
# Line not matched: [5.09.2024, 3:47:55 PM] David PS: Done
# Line not matched: [5.09.2024, 3:48:56 PM] ~ Ahmed Usama: Done
# Line not matched: [5.09.2024, 3:50:03 PM] ~ Menna Waleed: Done
# Line not matched: [5.09.2024, 3:50:37 PM] Salah Mohamed Twtr: let him cook
# Line not matched: [5.09.2024, 3:50:56 PM] Salah Mohamed Twtr: Done
# Line not matched: [5.09.2024, 3:51:04 PM] Elknz PS: Done
# Line not matched: [5.09.2024, 4:21:48 PM] Mariam Osman PS: Done
# Line not matched: [5.09.2024, 4:25:55 PM] ~ Khaled Shabrawy: Done
# Line not matched: [5.09.2024, 4:26:14 PM] ~ Mo7amed Galal: Done
# Line not matched: [5.09.2024, 5:26:30 PM] Ahmed Mounir PS: Done
# Line not matched: [5.09.2024, 7:06:15 PM] ~ محمد بن محمود الهواري: تم
# Line not matched: [5.09.2024, 7:11:27 PM] Yos S3D Twtr: Done
# Line not matched: [5.09.2024, 7:20:00 PM] Mai Samir PS: Done
# Line not matched: [5.09.2024, 7:21:13 PM] Abdelrahman Adel PS: انا خلصت مذاكرة بدون حل
# Line not matched: [5.09.2024, 7:43:33 PM] Ahmed Salman PS: Done
# Line not matched: [5.09.2024, 9:16:01 PM] Amany Mohammed PS: Done
# Line not matched: [5.09.2024, 9:16:56 PM] Amira PS: Done
# Line not matched: [5.09.2024, 9:17:18 PM] Ziad Nasser PS: Done
# Line not matched: [5.09.2024, 9:20:01 PM] Abdelrahman Adel PS: ربنا يكون في عونك
# Line not matched: [5.09.2024, 9:21:17 PM] ~ Adam♡: ربنا يقويك
# Line not matched: Done
# Line not matched: [5.09.2024, 10:08:34 PM] * PS: Done كحيانة
# Line not matched: [5.09.2024, 10:09:28 PM] Hüsam: مش محسوبة المذاكرة طالما محليتش
# Line not matched: [5.09.2024, 10:10:25 PM] Abdelrahman Adel PS: والله عندي امتحانات فاينل وكذه بروجيكت شغال عليه 😢
# Line not matched: [5.09.2024, 10:16:28 PM] Hüsam: مش تقليل مجهود بس انت كدا مستفدتش حاجة
# Line not matched: [5.09.2024, 10:17:10 PM] Abdelrahman Adel PS: لا انا هحل بس بقول انا عملت اي ذاكرت بس لحد دلوقتي ‎<This message was edited>
# Line not matched: [5.09.2024, 11:11:28 PM] Motaz PS: Done
# Line not matched: [6.09.2024, 12:48:24 AM] ~ Aysha: Done ✅
# Line not matched: ‎[6.09.2024, 1:54:48 AM] Hasnaa PS: ‎sticker omitted
# Line not matched: [6.09.2024, 10:51:05 AM] Shahd Tamer PS: Done
# Line not matched: [6.09.2024, 12:11:06 PM] Ahmed Abdelsamie PS: Done
# Line not matched: [6.09.2024, 12:48:07 PM] ~ Ahmed Usama: هو الكونتنت الجديد المفروض بينزل امتى يا شباب معلش 🙃
# Line not matched: [6.09.2024, 12:54:58 PM] Hüsam: انهاردة :)
# Line not matched: [6.09.2024, 11:50:07 PM] ~ Ichraf 🤓👩‍💻: ‎~ Ichraf 🤓👩‍💻 requested to join
# Line not matched: [7.09.2024, 12:36:45 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [7.09.2024, 12:37:47 PM] Hüsam: اديلي ٧، ٨ شهور مش بتاخر ع ديدلاين وممشي الدنيا بالمسطرة
# Line not matched: احمد اسامة ف اول مرة اتاخر*
# Line not matched: [7.09.2024, 12:37:51 PM] Hüsam: ع العموم
# Line not matched: ‎[7.09.2024, 12:38:08 PM] Hüsam: ‎video omitted
# Line not matched: [7.09.2024, 12:42:06 PM] Hüsam: المطلوب للديدلاين السادس 🚨
# Line not matched:
# Line not matched: هنذاكر Matrix
# Line not matched: صراحة توبك سهل ولكن محتاج وقت + بييجي كتير جدا ف الانترڤيوز
# Line not matched: - يُفضل تذاكرها من articles لان شرحها افضل ومش هيفرق بتذاكر منين يعني
# Line not matched: - ⁠اهم حاجة ف المذاكرة الحل لانك بتختبر ال ذاكرته وهل انت فاهم ١٠٠‎%‎ ولا لا
# Line not matched: - وكالعادة الزتونة هنا شوفها بعد ما تخلص
# Line not matched: https://www.techinterviewhandbook.org/algorithms/matrix/
# Line not matched: - اخر حاجة واهم حاجة صديقنا نور الدين⁩ عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين يوم ١٤ ‎<This message was edited>
# Line not matched: [7.09.2024, 1:54:53 PM] ~ Tarek: ‎~ Tarek requested to join
# Line not matched: [7.09.2024, 5:18:05 PM] ~ ميخا: ‎~ ميخا requested to join
# Line not matched: [8.09.2024, 1:57:45 AM] ~ Tarek: ‎You added ~ Tarek
# Line not matched: [8.09.2024, 2:26:02 AM] ~ ميخا: ‎You added ~ ميخا
# Line not matched: [10.09.2024, 12:49:13 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [10.09.2024, 12:49:25 AM] Hüsam: كله هيتحاسب
# Line not matched: ‎[10.09.2024, 12:49:42 AM] Hüsam: ‎image omitted
# Line not matched: [10.09.2024, 6:53:56 PM] ~ Aya Anwar: ‎~ Aya Anwar requested to join
# Line not matched: [10.09.2024, 8:32:57 PM] ~ MKonsowa: ‎~ MKonsowa requested to join
# Line not matched: [11.09.2024, 3:32:02 PM] Salah Mohamed Twtr: @201127473182
# Line not matched: matrix resources رجاء
# Line not matched: [11.09.2024, 3:47:33 PM] ~ Zoe💜: +1
# Line not matched: [11.09.2024, 4:57:19 PM] * PS: لو Article،
# Line not matched: Articles geeks of geeks  كويسه
# Line not matched: [12.09.2024, 10:31:20 AM] David PS: بعتذرلك اني مقدرتش ابعت لان للاسف بمر بظرف صعب جدا اتمنى يعدي
# Line not matched: ياريت لو حد من الشباب في الجروب يساعد ويبعت
# Line not matched: [12.09.2024, 10:32:30 AM] Hasnaa PS: ربنا معاك يا ديفيد
# Line not matched: [12.09.2024, 10:50:19 AM] Salah Mohamed Twtr: الله معك ويعديها علي خير ان شاء الله
# Line not matched: [12.09.2024, 4:15:51 PM] Mai Samir PS: ربنا معاك وكله يعدى
# Line not matched: [12.09.2024, 5:01:34 PM] Abdelrahman Adel PS: ربنا معك وان شاء تتحل علي خير
# Line not matched: [13.09.2024, 1:49:30 AM] Hüsam: سلامو عليكو
# Line not matched: بكرة يوم ١٤ (الديدلاين)
# Line not matched: [13.09.2024, 3:49:01 AM] ~ Tarek: يا شباب انا معرفش حاجة عن الds خالص غير الarray بس اظن ، اروح فين واجي ازاي
# Line not matched: [13.09.2024, 3:49:29 AM] Hüsam: صبرك عليا
# Line not matched: [13.09.2024, 3:50:12 AM] Hüsam: @201013095201
# Line not matched: [13.09.2024, 3:50:34 AM] ~ Tarek: مش عندي الاتنين
# Line not matched: [13.09.2024, 3:50:43 AM] ~ Tarek: انا دخلت بعدهم
# Line not matched: [13.09.2024, 3:50:53 AM] Hüsam: المطلوب للديدلاين السادس 🚨
# Line not matched:
# Line not matched: هنذاكر Matrix
# Line not matched: صراحة توبك سهل ولكن محتاج وقت + بييجي كتير جدا ف الانترڤيوز
# Line not matched: - يُفضل تذاكرها من articles لان شرحها افضل ومش هيفرق بتذاكر منين يعني
# Line not matched: - ⁠اهم حاجة ف المذاكرة الحل لانك بتختبر ال ذاكرته وهل انت فاهم ١٠٠‎%‎ ولا لا
# Line not matched: - وكالعادة الزتونة هنا شوفها بعد ما تخلص
# Line not matched: https://www.techinterviewhandbook.org/algorithms/matrix/
# Line not matched: - اخر حاجة واهم حاجة صديقنا نور الدين⁩ عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين يوم ١٤
# Line not matched: ‎[13.09.2024, 3:54:51 AM] Abdelhadi PS: ‎sticker omitted
# Line not matched: [13.09.2024, 5:41:23 AM] * PS: Done
# Line not matched: [13.09.2024, 8:07:51 AM] Mohamed Ibrahim PS: انا اتهزمت 😞
# Line not matched: [13.09.2024, 10:56:23 AM] ~ Ali Ismail: Done
# Line not matched: [13.09.2024, 11:49:18 AM] Shahd Tamer PS: Done
# Line not matched: [13.09.2024, 12:42:18 PM] 𓂆 PS: ‎𓂆 PS requested to join
# Line not matched: [13.09.2024, 2:10:43 PM] ~ Mazen: انا لسه بذاكر فيه بصراحه 😞
# Line not matched: [13.09.2024, 2:23:01 PM] ~ Menna Waleed: Done
# Line not matched: [13.09.2024, 2:55:23 PM] ~ Zoe💜: Done
# Line not matched: [13.09.2024, 4:44:56 PM] Abdelrahman Adel PS: Done
# Line not matched: [13.09.2024, 4:50:11 PM] ~ Khaled Shabrawy: Done
# Line not matched: [13.09.2024, 5:16:37 PM] Elknz PS: Done
# Line not matched: [13.09.2024, 6:42:17 PM] Younes PS: done
# Line not matched: [13.09.2024, 6:45:36 PM] Ahmed Salman PS: Done
# Line not matched: [13.09.2024, 6:56:04 PM] Salah Mohamed Twtr: Done
# Line not matched: [13.09.2024, 9:26:35 PM] Yos S3D Twtr: ضن
# Line not matched: [13.09.2024, 10:18:30 PM] Mariam Osman PS: Done
# Line not matched: [13.09.2024, 10:18:43 PM] ~ Tarek: done
# Line not matched: [13.09.2024, 10:20:54 PM] * PS: لا ادي نفسك فرصه كمان
# Line not matched: ح تقدر ان شاءالله.  ال topic نوعا ما بسيط
# Line not matched: [13.09.2024, 10:54:08 PM] ~ Mohamed Osama: ‎~ Mohamed Osama requested to join
# Line not matched: [13.09.2024, 11:30:27 PM] Mai Samir PS: Done
# Line not matched: [14.09.2024, 2:59:41 AM] ~ Mohamed🦅: ‎~ Mohamed🦅 requested to join
# Line not matched: [14.09.2024, 1:55:02 AM] Hüsam: 🛑🛑🛑🛑🛑🛑🛑🛑
# Line not matched: مساء الخير يولاد، الديدلاين جه
# Line not matched: ياريت نركز ف الكلمتين دول
# Line not matched: ١. ال بعت done يبعت تاني عشان هنحاسب من دلوقت
# Line not matched: ٢. ⁠هتبعت مسدج واحدة فيها “done” اي حاجة غير كدا invalid
# Line not matched: ٣. ⁠من دلوقت لحد بكرة ١٢ بالليل بنبعت done وبعدها بنركب القطر
# Line not matched:
# Line not matched:
# Line not matched: بشكر نور الدين⁩ تاني ع الاسكريبت ال انقذ حياتي (حرفيا) وهيختصر وقت كتير ❤️ ‎<This message was edited>
# Line not matched: [14.09.2024, 1:55:47 AM] Yos S3D Twtr: Done
# Line not matched: [14.09.2024, 1:56:04 AM] ~ Ali Ismail: done
# Line not matched: [14.09.2024, 1:56:15 AM] Mai Samir PS: done
# Line not matched: [14.09.2024, 1:56:40 AM] ~ ميخا: Done
# Line not matched: [14.09.2024, 2:43:02 AM] ☆아말☆أمل PS: done
# Line not matched: [14.09.2024, 7:16:44 AM] Hasnaa PS: Done
# Line not matched: [14.09.2024, 9:18:07 AM] Ahmed Salman PS: Done
# Line not matched: [14.09.2024, 10:29:10 AM] Salah Mohamed Twtr: done
# Line not matched: [14.09.2024, 11:40:17 AM] ~ Mariam Salah: Done
# Line not matched: [14.09.2024, 11:41:01 AM] Abdelrahman Adel PS: Done
# Line not matched: [14.09.2024, 12:03:56 PM] Shahd Tamer PS: done
# Line not matched: [14.09.2024, 1:42:38 PM] ~ محمد بن محمود الهواري: done
# Line not matched: [14.09.2024, 1:49:59 PM] ~ Ahmed Usama: done
# Line not matched: [14.09.2024, 2:01:23 PM] Amany Mohammed PS: Done
# Line not matched: [14.09.2024, 2:23:25 PM] ~ Mo7amed Galal: Done
# Line not matched: [14.09.2024, 5:15:48 PM] مُحَمَّد PS: done
# Line not matched: [14.09.2024, 5:21:39 PM] Ahmed Abdelsamie PS: done
# Line not matched: [14.09.2024, 5:49:14 PM] Ahmed Mounir PS: done
# Line not matched: [14.09.2024, 5:51:13 PM] ~ Khaled Shabrawy: done
# Line not matched: [14.09.2024, 6:03:05 PM] Mohamed Ibrahim PS: done
# Line not matched: [14.09.2024, 6:06:28 PM] * PS: Done
# Line not matched: [14.09.2024, 9:18:00 PM] ~ Zoe💜: Done
# Line not matched: [15.09.2024, 12:06:18 AM] رُفَيده سَعْد PS: Done
# Line not matched: [15.09.2024, 12:06:29 AM] PS-StudyingDS 📔: ‎You changed this group's settings to allow only admins to send messages to this group
# Line not matched: [15.09.2024, 2:06:33 AM] Hüsam: نور عامل الاسكريبت محدش يستخدمه غيره باين
# Line not matched: [15.09.2024, 4:34:48 PM] Hüsam: المطلوب للديدلاين السابع 🚨
# Line not matched:
# Line not matched: - هنذاكر Trees 🌳
# Line not matched: - اخدنا وقتنا ف ال recursion ف اظن هيكون سهل، محتاج وقت بس ع الدنيا تظبط
# Line not matched:
# Line not matched: المطلوب:
# Line not matched: - ال tree as a concept
# Line not matched: - ⁠ال binary tree
# Line not matched: - ⁠ال AVL tree
# Line not matched: - ⁠ال Big O لل trees
# Line not matched:
# Line not matched:
# Line not matched: لو هحط ريسورسز لل trees ف اكيد هحط الفيديوهات دي لل MIT
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=U1JYwHcFfso&list=PLUl4u3cNGP63EdVPNLG3ToM6LaEUuStEY&index=10&t=1s&pp=iAQB
# Line not matched: - https://www.youtube.com/watch?v=9Jry5-82I68&pp=ygUIdHJlZSBtaXQ%3D
# Line not matched: دول بيشرحو ال core لل trees بالتفصيل الممل ( كل كلمة تقريبا مهمة ) بعد كدا شوف بت implement ال tree ازاي ف ال language بتاعتك وال operations عليها ازاي
# Line not matched:
# Line not matched: كالعادة الزتونة هنا
# Line not matched: https://www.techinterviewhandbook.org/algorithms/tree/
# Line not matched:
# Line not matched:
# Line not matched: ال data structure و ال algorithms هم حاجة واحدة بنسبة كبيرة ف ممكن حاجة ناخدها هنا وناخدها تاني ف ال algos والعكس
# Line not matched:
# Line not matched: الديدلاين يوم ٣٠ ‎<This message was edited>
# Line not matched: [15.09.2024, 4:35:24 PM] Hüsam: بما اني مش عارف اشغل الاسكريبت، ف هنقول المطلوب واما نور ييجي يشغله ع تقريبا عامله باسوورد ( بهزر مش عارف اشغله )
# Line not matched: [15.09.2024, 4:43:16 PM] Hüsam: تقريبا دا اطول ديدلاين ومن اهم ال topics ف
# Line not matched: I will make sure to remove the ones who did not study
# Line not matched: [15.09.2024, 4:43:24 PM] ‎You: ‎You pinned a message
# Line not matched: [15.09.2024, 4:43:32 PM] ‎You: ‎You pinned a message
# Line not matched: [15.09.2024, 4:46:52 PM] PS-StudyingDS 📔: ‎You changed this group's settings to allow all members to send messages to this group
# Line not matched: [15.09.2024, 4:47:07 PM] PS-StudyingDS 📔: ‎You changed the group description
# Line not matched: [15.09.2024, 4:47:24 PM] PS-StudyingDS 📔: ‎You changed the group description
# Line not matched: [15.09.2024, 6:24:35 PM] ~ Mahmoud Samy: ‎~ Mahmoud Samy requested to join
# Line not matched: [15.09.2024, 7:24:56 PM] Motaz PS: done
# Line not matched: [15.09.2024, 7:29:15 PM] Mariam Osman PS: done
# Line not matched: [15.09.2024, 7:57:26 PM] Amira PS: Done
# Line not matched: [16.09.2024, 12:13:03 AM] ~ نورهان: ‎~ نورهان requested to join
# Line not matched: [16.09.2024, 1:18:32 PM] 𓂆 PS: ‎You added 𓂆 PS
# Line not matched: [16.09.2024, 3:55:10 PM] ~ Mazen: Done
#
# Group members who sent messages between 02.05.2024 and 17.09.2024:
# No messages found in the given date range.
