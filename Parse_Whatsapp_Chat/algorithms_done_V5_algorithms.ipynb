# %% [markdown]
# # Part 1: Function to Parse WhatsApp Chat for Task Completion

# %%
import re
from datetime import datetime, date  # Importing date to use date.today()

def parse_task_completion_and_additions(file_path, start_date, end_date):
	"""
	Read the WhatsApp file path, handle the date format, convert start and end dates to determine object,
	use regex to capture the date, time, user, and message. Additionally, capture user additions.
	"""
	# Set to store users who have sent 'done', 'dn', or 'تم'
	done_users = set()
	
	# Set to store users who were added or who added someone
	added_users = set()
	added_by_others = set()
	requested_to_join_users = set()

	# Read the WhatsApp file
	with open(file_path, 'r', encoding='utf-8') as f:
		lines = f.readlines()

	# format (dd.mm.yyyy)
	date_format = '%d.%m.%Y'

	# Convert the start and end dates to datetime objects
	start_date = datetime.strptime(start_date, date_format).date()
	end_date = datetime.strptime(end_date, date_format).date()

	# Regex patterns
	# message_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
	# added_pattern = re.compile(r'~\s*(.*?) was added')
	# added_by_pattern = re.compile(r'~\s*(.*?) added ~\s*(.*)')
	message_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
	added_pattern = re.compile(r'~\s*(.*?) was added')
	added_by_pattern = re.compile(r'~\s*(.*?) added ~\s*(.*)')
	join_from_community_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*) joined from the community')
	requested_to_join_pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] ~\s*(.*?): ~\s*(.*) requested to join')


	current_user = None
	current_message = ""

	for line in lines:
		match = message_pattern.match(line)
		join_match = join_from_community_pattern.match(line)
		request_match = requested_to_join_pattern.match(line)
		
		if match:
			# If there's a new match, process the previous message before resetting
			if current_user and current_message:
				# Process the previous message for task completion
				cleaned_message = current_message.strip().lower()
				if ('done' in cleaned_message or 
					'dn' in cleaned_message or 
					'✅' in cleaned_message or
					'done✅' in cleaned_message or
					'done' in cleaned_message or
					'تم ' in cleaned_message or
					'ضن' in cleaned_message or
					re.search(r'\bتم\b', cleaned_message) or 
					cleaned_message == 'تم' or 
					'تم' in cleaned_message):
					done_users.add(current_user)

			# Start a new message
			date_str, time_str, user, message = match.groups()
			current_user = user.strip()
			current_message = message.strip()

			# Convert message date to a date object and check if within date range
			message_date = datetime.strptime(date_str, date_format).date()

			if not (start_date <= message_date <= end_date):
				current_user = None  # Ignore this message if it's not in the date range
				current_message = ""
				continue

			# Check for added users or users added by someone
			added_match = added_pattern.search(current_message)
			added_by_match = added_by_pattern.search(current_message)

			if added_match:
				added_user = added_match.group(1).strip()
				added_users.add(added_user)

			if added_by_match:
				added_by = added_by_match.group(1).strip()
				added_user = added_by_match.group(2).strip()
				added_users.add(added_user)
				added_by_others.add(added_by)
				
			elif join_match:
				# Process the "joined from the community" message
				date_str, time_str, user, _ = join_match.groups()
				user = user.strip()
				added_users.add(user)

			elif request_match:
				# Process the "requested to join" message
				date_str, time_str, user, _ = request_match.groups()
				user = user.strip()
				requested_to_join_users.add(user)
			

		else:
			# If no match, it means this is a continuation of the current message (multi-line)
			current_message += " " + line.strip()

	# Process the last message after the loop ends
	if current_user and current_message:
		cleaned_message = current_message.strip().lower()
		if ('done' in cleaned_message or 
			'dn' in cleaned_message or 
			'✅' in cleaned_message or
			'done✅' in cleaned_message or
			'done' in cleaned_message or
			'تم ' in cleaned_message or
			'ضن' in cleaned_message or
			re.search(r'\bتم\b', cleaned_message) or 
			cleaned_message == 'تم' or 
			'تم' in cleaned_message):
			done_users.add(current_user)

	return done_users, added_users, added_by_others, requested_to_join_users

# %% [markdown]
# # Part 2: Compare Group Members with Task Completion

# %%
def compare_group_with_done_users_and_added(done_users, added_users, added_by_others, requested_to_join_users):
    """
    Comparing the list of groups that I got from 18.08.2024 (after the deadline one) until now.
    And find the user that didn't match with the existing user that send from 26.08.2024 (deadline 3)
    Also prints added users and who added them.
    """
    # Full list of group members provided
    group_members = {
"* PS",
". PS",
"A7 Hmd PS",
"Abdelhadi PS",
"Abdelrahman Karim",
"Ahmed Abdelsamie PS",
"Ahmed Elkassrawy PS",
"Ahmed Hesham",
"Ahmed Jamal Sultan PS",
"Ahmed Mohamed Badran",
"Ahmed Mounir PS",
"Ahmed Salman PS",
"Ali Ismail",
"Amal Eltelbany PS",
"Amany Mohammed PS",
"Amira PS",
"Asma 🪄",
"Asmaa",
"Ayash PS",
"Aysha",
"BΛSΛNT",
"David PS",
"Elknz PS",
"Eman Ashraf PS",
"Esraa",
"Esraa Alaa",
"Gehad PS",
"Gehad🌺",
"Habiba Gamal PS",
"Hadi Heikal PS",
"Hasnaa PS",
"Hoda Salim PS",
"Hüsam",
"Ichraf 🤓👩‍💻",
"KHALED𓂆",
"Karema PS",
"MGamal",
"MORo",
"Mahmoud",
"Mahmoud Elsheemy PS",
"Mai Samir PS",
"Manar PS",
"Mariam Osman PS",
"Mennatallah",
"Minno",
"Mohamed Rabee PS",
"Motaz PS",
"Nada Fahmy PS",
"Nada Osama",
"NourEldien Alsharif PS",
"Omnia Ashraf PS",
"Omnia PS",
"Omr PS",
"Os!Rabe3 PS",
"PS-StudyingAlgos 📚",
"Salah Mohamed Twtr",
"Sara",
"Shahd Tamer PS",
"Shaimaa",
"TURBO PS",
"Tarek",
"Wafaa",
"Yos S3D Twtr",
"Younes PS",
"Youssef Yousry PS",
"Zeyad",
"Zeyad Albadawy PS",
"Ziad Nasser PS",
"mahmoud elshony",
"أَدْهَم عَلَّاَم PS",
"رُفَيده سَعْد PS",
"رِيمُو PS",
"‎You",
"𓂆 PS",
"𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚",
"𝓐𝓁𝒶𝒶 PS",
}


    # Find users in the group who have not completed the task
    not_done_users = group_members - done_users

    # Output users who did NOT complete the task
    print("\nUsers who did NOT complete the task:")
    if not_done_users:
        for user in sorted(not_done_users):
            print(user)
    else:
        print("All users completed the task.")

    print("\n==================================")
    print("\nUsers who completed the task:")
    for user in sorted(done_users):
        print(user)

    # Output users who were added to the group
    print("\n==================================")
    print("\nUsers who were added to the group:")
    for user in sorted(added_users):
        print(user)

    # Output users who added others to the group
    print("\n==================================")
    print("\nUsers who added someone to the group:")
    for user in sorted(added_by_others):
        print(user)
        
	# Output users who requested to join the group
    print("\n==================================")
    print("\nUsers who requested to join the group:")
    for user in sorted(requested_to_join_users):
        print(user)

# %% [markdown]
# # Part 3: Main Function

# %%
def main():
    """Main Function to apply all the functions written above"""
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_5_algo.txt'

    # Specify the date range (start date and end date)
    start_date = '13.09.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract users who completed the task, users who were added, and who requested to join
    done_users, added_users, added_by_others, requested_to_join_users = parse_task_completion_and_additions(file_path, start_date, end_date)

    # Compare the task completion with the full list of group members and output added users and who requested to join
    compare_group_with_done_users_and_added(done_users, added_users, added_by_others, requested_to_join_users)

if __name__ == '__main__':
    main()
# Out:
# Users who did NOT complete the task:
# * PS
# . PS
# Abdelrahman Karim
# Ahmed Jamal Sultan PS
# Ahmed Mohamed Badran
# Amal Eltelbany PS
# Asmaa
# Ayash PS
# Aysha
# BΛSΛNT
# David PS
# Esraa Alaa
# Gehad PS
# Gehad🌺
# Habiba Gamal PS
# Hadi Heikal PS
# Ichraf 🤓👩‍💻
# KHALED𓂆
# MGamal
# MORo
# Mahmoud
# Minno
# Nada Osama
# Omnia Ashraf PS
# Omnia PS
# Omr PS
# PS-StudyingAlgos 📚
# Sara
# Wafaa
# Ziad Nasser PS
# mahmoud elshony
# أَدْهَم عَلَّاَم PS
# رِيمُو PS
# ‎You
# 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚
#
# ==================================
#
# Users who completed the task:
# A7 Hmd PS
# Abdelhadi PS
# Ahmed Abdelsamie PS
# Ahmed Elkassrawy PS
# Ahmed Hesham
# Ahmed Mounir PS
# Ahmed Salman PS
# Ali Ismail
# Amany Mohammed PS
# Amira PS
# Asma 🪄
# Elknz PS
# Eman Ashraf PS
# Esraa
# Hasnaa PS
# Hoda Salim PS
# Hüsam
# Karema PS
# Mahmoud Elsheemy PS
# Mai Samir PS
# Manar PS
# Mariam Osman PS
# Mennatallah
# Mohamed Rabee PS
# Motaz PS
# Nada Fahmy PS
# NourEldien Alsharif PS
# Os!Rabe3 PS
# Salah Mohamed Twtr
# Shahd Tamer PS
# Shaimaa
# TURBO PS
# Tarek
# Yos S3D Twtr
# Younes PS
# Youssef Yousry PS
# Zeyad
# Zeyad Albadawy PS
# رُفَيده سَعْد PS
# 𓂆 PS
# 𝓐𝓁𝒶𝒶 PS
#
# ==================================
#
# Users who were added to the group:
#
# ==================================
#
# Users who added someone to the group:
#
# ==================================
#
# Users who requested to join the group:

# %% [markdown]
# # PART4: Generate a list of Group-members
# ### `(with a specific date until now)`

# %%
def extract_group_members(file_path, start_date, end_date):
    # Set to store unique users
    group_members = set()

    # Read the WhatsApp export file
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    # Specify the date format that matches your WhatsApp's export format (dd.mm.yyyy)
    date_format = '%d.%m.%Y'

    # Convert the start and end dates to datetime objects
    start_date = datetime.strptime(start_date, date_format).date()
    end_date = datetime.strptime(end_date, date_format).date()

    # Regex pattern to capture WhatsApp message with date, time, user, and message
    # pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4}) (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')
    pattern = re.compile(r'\[(\d{1,2}\.\d{1,2}\.\d{4})(?:,)? (\d{2}:\d{2}:\d{2})\] (?:~\s*|)(.*?): (.*)')

    for line in lines:
        match = pattern.match(line)
        if match:
            date_str, time_str, user, message = match.groups()

            # Convert message date to a date object
            message_date = datetime.strptime(date_str, date_format).date()

            # Check if the message date is within the specified date range
            if start_date <= message_date <= end_date:
                # Clean up the user name by stripping extra spaces or non-visible characters
                user = user.strip()

                # Debugging: Print the users being processed
                print(f"Processing message from: {user} at {date_str}")

                group_members.add(user)
        else:
            # Log lines that don't match to debug why certain messages are missed
            print(f"Line not matched: {line.strip()}")

    return group_members

def main():
    # File path of exported WhatsApp chat (change it to your file's location)
    file_path = '_chat_5_algo.txt'

    # Specify the date range (start date and end date)
    start_date = '18.08.2024'
    end_date = date.today().strftime('%d.%m.%Y')  # Use today's date

    # Extract group members who sent messages between the start and end date
    group_members = extract_group_members(file_path, start_date, end_date)

    # Output the group members
    print(f"\nGroup members who sent messages between {start_date} and {end_date}:")
    if group_members:
        for member in sorted(group_members):
            print(f'"{member}",')
    else:
        print("No messages found in the given date range.")

if __name__ == '__main__':
    main()
# Out:
# Line not matched: هنمشيها ازاي مذاكرة algo
# Line not matched: ‎OPTION: اسبوع اسبوع (15 votes)
# Line not matched: ‎OPTION: نحط خطة شهرية (0 votes)
# Line not matched: ابعت الpoll تاني كدا
# Line not matched: مذاكرة algo
# Line not matched: ‎OPTION: نحط بلان اسبوعيا (4 votes)
# Line not matched: ‎OPTION: بلان شهريا (1 vote)
# Line not matched: ‎OPTION: بلان اسبوعي + شهري (17 votes)
# Line not matched: ‎[6.04.2024, 05:27:15] Hüsam: ‎sticker omitted
# Line not matched: هنذاكرو من هنا ؟
# Line not matched: تيلجرام احسن تطبيق في حاجات بتاع المجتمعات ومنظم اكتر
# Line not matched: وبعد العيد جد الجد
# Line not matched: وكورس التطبيق على الخوارزميات بتاع عادل نسيم هتلاقيه على جروب ال resources هو DS برضه
# Line not matched:
# Line not matched: https://youtube.com/playlist?list=PL1DUmTEdeA6JlommmGP5wicYLxX5PVCQt&si=Yrg68XX0TITSMiD0
# Line not matched: ال عايز يبعت ريسورس يعملي منشن او يبعتلي برايفيت مسدج اللينك مع كلمتين شرح ايه الريسورس وبيشرح ايه بس
# Line not matched: وشكرا
# Line not matched: ‎[6.04.2024, 05:36:31] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: ‎[6.04.2024, 05:37:36] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: لو منهج حاسبات القاهرة فالرجل ده كويس اوي
# Line not matched: ‎[6.04.2024, 05:40:26] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: بس بجد تحفه
# Line not matched: ‎[6.04.2024, 05:41:32] Ayash PS: ‎image omitted
# Line not matched: ‎[6.04.2024, 05:41:44] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: ‎[6.04.2024, 05:42:03] ~ Nada: ‎sticker omitted
# Line not matched: اي المطلوب من الواحد عشان يبدأ يحل ؟
# Line not matched: ‎[6.04.2024, 05:43:54] Hüsam: ‎sticker omitted
# Line not matched: طب هتكلم عن نفسي شوية
# Line not matched: @201098140950 ‎<This message was edited>
# Line not matched: أو بتبعت هنا والناس بتديك hint
# Line not matched: "خير الأعمال أدومها وإن قل".
# Line not matched: لو نيت كود دا الحل من جروب معين ممكن الرابط ؟
# Line not matched: ولو الموقع بادئ كدا اصلا ف خلاص جزاك الله خيرا
# Line not matched: ‎[6.04.2024, 07:54:42] Ayash PS: Grokking Algorithms - Full - Cover - No Watermark.pdf • ‎245 pages ‎document omitted
# Line not matched: ما شاء الله بدايات مبشرة بكل خير.
# Line not matched: ‎[7.04.2024, 00:46:20] Ayash PS: ‎image omitted
# Line not matched: وخش على د مصطفى سعد
# Line not matched: بلاي ليست اسمها cpp for beginners
# Line not matched: واتعلمت جافا برضو عشان كانت عندى فى الكلية
# Line not matched: د مصطفى هيخليك تحل كمية محترمة على كل توبيك فى اللغة
# Line not matched: ‎[7.04.2024, 01:08:24] Amira PS: ‎sticker omitted
# Line not matched: https://codeforces.com/group/MWSDmqGsZm/contests#
# Line not matched: سمعتوا كام فيديو؟
# Line not matched: بس مدري المفروض نتابع سوا ازي، خاصه ان اول ٥ فيديوهات مفيهمش حاجه صعبة
# Line not matched: Algo 1st task (5 videos)
# Line not matched: ‎OPTION: خلصت (6 votes)
# Line not matched: ‎OPTION: مخلصتش (0 votes)
# Line not matched: ‎OPTION: محتاج مساعدة (1 vote)
# Line not matched: وانا تعبت جامد فيه 🥲
# Line not matched: ازاي ما شاء الله انتو شاطرين ف البروبليم سولفينج والبرمجة عموما
# Line not matched: التدرج كان ازاي
# Line not matched: من كلية وغيره
# Line not matched: وحاليا مركزه اني احل اكتر بc++
# Line not matched: بس اجي احل عادى ع اللوب والكوندشن والقي يجي ان تايم ليمت بس بقف بقي مبكنش عارفه اعمل اي
# Line not matched: شكرا جدا
# Line not matched: هشوفه ان شاء الله
# Line not matched: ‎[9.04.2024, 20:33:57] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: لان سعات دماغي تقف خالص فبقوم سيبها واشوف غيرها
# Line not matched: يعني اي phase 1
# Line not matched: يعني كدا أنا خلصت الأساسيات ولا اي
# Line not matched: ‎[9.04.2024, 21:25:22] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[9.04.2024, 21:25:39] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ف أنا ك واحد عايز اتأسس صح
# Line not matched: اللي هوا انفع مسابقات انترفيوهات كله
# Line not matched: اعمل اي
# Line not matched: واي المعرفه المطلوبة عشان أبدا
# Line not matched: او على الاقل الحاجة الأساسية والباقي اتعلمه معاهم ف الخطه دي
# Line not matched: بس الواحد تايه شوية😅💔
# Line not matched: ‎[9.04.2024, 21:38:29] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: نشوف الموضوع دا وربنا يسهل أن شاء الله
# Line not matched: وعندنا داتا ستراكشر السنة دى، فـ كده كده هذاكرها مذاكرة أى كلام دلوقت عشان أعدى فيها والحق أذاكر باقى المواد
# Line not matched: المبلغ المدفوع للمسابقة السنة دي كبير عن السنين اللي فاتت، فبلاش تصرفيهم على الفاضي لو مش معاك حاجات متقدمة شوية علشان مش هتعرفي تحلي حاجة بدون خوارزميات و DS.
# Line not matched: أنا مستوايا حاليا مش زيرو اوى، يدوب أحل مسائل الـ نيو كامرز، أما حاجة فيها خوارزميات وداتا ستراكشر لسة بصراحة
# Line not matched: ‎[10.04.2024, 18:50:47] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: هشوف بقا كده الـ STL والـ Number theory أحاول كده أذاكرهم وأشوف كده
# Line not matched: تمام، تسلم جدًّا يا غالى ❤️❤️🌱
# Line not matched: ‎[10.04.2024, 18:56:35] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[10.04.2024, 18:59:13] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[10.04.2024, 19:08:45] ~ mn1655: ‎image omitted
# Line not matched: ‎[10.04.2024, 19:10:17] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[13.04.2024, 22:16:57] Ayash PS: ‎image omitted
# Line not matched: ‎[14.04.2024, 09:16:02] Omr PS: ‎sticker omitted
# Line not matched: تاسك انهاردة ال time complexity من bari playlist
# Line not matched: 1.5.1 + 1.5.2 +1.5.3
# Line not matched: Algo 2nd task (3 videos)
# Line not matched: ‎OPTION: خلصت (2 votes)
# Line not matched: ‎OPTION: مخلصتش (1 vote)
# Line not matched: ‎OPTION: محتاج مساعدة + السؤال (0 votes)
# Line not matched: @905525834783 ‎<This message was edited>
# Line not matched: ‎[15.04.2024, 13:46:09] Omr PS: ‎image omitted
# Line not matched: ‎[16.04.2024, 01:13:05] Gehad PS: ‎image omitted
# Line not matched: ‎[16.04.2024, 01:13:14] Gehad PS: ‎image omitted
# Line not matched: ‎[16.04.2024, 01:14:59] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[16.04.2024, 01:17:55] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[16.04.2024, 01:25:07] ~ Nada: ‎image omitted
# Line not matched: ‎[16.04.2024, 01:25:29] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:25:50] Gehad PS: ‎sticker omitted
# Line not matched: بس ترشحو كتاب اى
# Line not matched: خدنا بس جزء ال time complixty حتي الان
# Line not matched: انا كنت مذاكرة ال time complixty قبل كده وضافلي حبة حاجات
# Line not matched: هو هندي فعلا ؟؟
# Line not matched: شوف لينك من اللينكات بتاع درايف هتلاقيه
# Line not matched: ‎[16.04.2024, 01:28:48] Shvms PS: ‎sticker omitted
# Line not matched: بس لو انتي مبتدأه تماما وعايزه حاجه تاخدك ع اد عقلك بشكل كويس ف هو مناسب جدا يعني
# Line not matched: هتلاقي هنا نسخة pdf جاهزة
# Line not matched: ‎[16.04.2024, 01:31:48] Gehad PS: ‎sticker omitted
# Line not matched: يعني نخلص التوبيك مع عبد الباري نقرأ من الكتاب عن نفس الجزء
# Line not matched: ايه رايكم؟
# Line not matched: @201011571434 @201017076715
# Line not matched: بس الكتاب لسه🏃🏻‍♀️
# Line not matched: لينك البلاي ليست
# Line not matched:
# Line not matched: الكتاب
# Line not matched:
# Line not matched: https://youtube.com/playlist?list=PLDN4rrl48XKpZkf03iYFl-O29szjTrs_O&si=CIxFecs8cA2r6mJA
# Line not matched:
# Line not matched: البلاي ليست
# Line not matched: المجال دا مش مجالك ي شابه
# Line not matched: ‎[16.04.2024, 01:38:12] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:38:26] Gehad PS: Grokking Algorithms-9781617292231.pdf • ‎448 pages ‎document omitted
# Line not matched: ‎[16.04.2024, 01:38:41] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:38:52] Omr PS: ‎sticker omitted
# Line not matched: فرهدتو حسام معاكم والاخر مش مركزين
# Line not matched: ‎[16.04.2024, 01:40:02] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:40:17] ~ Mohamed Ezat: ‎sticker omitted
# Line not matched: هنشوف كام فيديو ونقرأ ايه😂😂😂
# Line not matched: ‎[16.04.2024, 01:41:18] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:41:54] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:42:06] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:42:07] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:42:35] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:43:26] khld: ‎sticker omitted
# Line not matched: ممكن نشوف ١.٦، ١.٧
# Line not matched: ونخلص التايم كومبليكستي من الكتاب
# Line not matched: لسه مكتشفه دا النهارده وراااائئئععععع
# Line not matched: ‎[16.04.2024, 01:44:11] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:44:39] dawoud PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:46:01] ~ Nada: ‎sticker omitted
# Line not matched: انا حذرت
# Line not matched: هو و mdn من روائع المشوار التكنولوجي
# Line not matched: حلو قولولى حاجات كمان استفيد منكو 😂🤡
# Line not matched: ‎[16.04.2024, 01:47:41] ~ Nada: ‎sticker omitted
# Line not matched: هنسيطر ع المرستان دا ازاي
# Line not matched: ‎[16.04.2024, 01:50:02] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:50:58] Gehad PS: ‎sticker omitted
# Line not matched: بدأتي البورتفوليو؟
# Line not matched: ‎[16.04.2024, 01:52:57] ~ Nada: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:55:53] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:56:17] Omr PS: ‎video omitted
# Line not matched: ‎[16.04.2024, 01:56:39] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:57:02] Omr PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:57:27] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 01:57:36] khld: ‎sticker omitted
# Line not matched: ماتتكلمش تاني
# Line not matched: ‎[16.04.2024, 01:59:21] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:01:05] khld: ‎sticker omitted
# Line not matched: واخر واحد ف ال ٥ كان بداية ال time complixty
# Line not matched: ‎[16.04.2024, 02:03:03] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:03:32] khld: ‎sticker omitted
# Line not matched: خايفه انسي المعلومات 😂😭😭
# Line not matched: ‎[16.04.2024, 02:06:06] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:07:21] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:08:51] Gehad PS: ‎sticker omitted
# Line not matched: نفس المقارنة بين ال devops وال c
# Line not matched: ‎[16.04.2024, 02:11:08] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:11:30] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:13:29] khld: ‎sticker omitted
# Line not matched: هبقى مريض نفسى
# Line not matched: ‎[16.04.2024, 02:15:15] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:17:04] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: 20/2/2023
# Line not matched: خلصنا
# Line not matched: 5/4/2024
# Line not matched: حليت مساله اليوم بالعافيه 🧑‍🦯
# Line not matched: ‎[16.04.2024, 02:20:15] khld: ‎sticker omitted
# Line not matched: احنا مش هنوقف
# Line not matched: ‎[16.04.2024, 02:27:26] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 02:48:22] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 03:30:44] Omr PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 08:28:03] Ayash PS: Grokking Algorithms - Full - Cover - No Watermark.pdf • ‎245 pages ‎document omitted
# Line not matched: ‎[16.04.2024, 08:32:05] Ayash PS: شهادة CCNA 200-301.pdf • ‎772 pages ‎document omitted
# Line not matched:
# Line not matched: اللي حابب يذاكر algorithms هبدأ زي م @201550112675 اقترحت ب playlist عبدالباري
# Line not matched:
# Line not matched: انا عملت ال trello board دي متقسمة بالاسابيع ، وكل اسبوع فيه اليوم 6 ايام بالتاريخ (هناخد الجمعة اجازة) + جوا كل يوم فيه اللينكات اللي هنشوفها
# Line not matched:
# Line not matched: انا حطيت فيديوهين ف اليوم ع نبدأ خفيف + فيه فيديوهات صغيرة بس المحتوي بتاعها محتاج مذاكرة وسيرش يعني
# Line not matched: برضو لو حد شاطر وحابب يدوس it's okay
# Line not matched:
# Line not matched: نوت صغيرة بس: اي حد هيدخل ع اللينك لازم يعمل اكونت وكمان بيبقي معاه ال access انه يعدل علشان trello محترم شوية وعايزنا ندفع ع ال features الزيادة
# Line not matched:
# Line not matched: ممكن نبقي نعمل نوشن احسن بس خلينا نجرب الاسبوع دا ونشوف هل ف عدد وعلي اساسه نطور
# Line not matched:
# Line not matched: https://trello.com/invite/b/hxzxwGsv/ATTIf94213e7aba6cb7b349ecb50eb4c123a853AD534/study-algorithms
# Line not matched: ‎[16.04.2024, 19:42:11] ~ 𝔄𝔥𝔪𝔞𝔡 𝔍𝔞𝔪𝔞𝔩: ‎image omitted
# Line not matched: ‎[16.04.2024, 20:17:14] dawoud PS: ‎sticker omitted
# Line not matched: خلصت ادايه؟
# Line not matched: ‎OPTION: Day 1 (11 votes)
# Line not matched: ‎OPTION: Day 2 (9 votes)
# Line not matched: ‎OPTION: Day 3 (6 votes)
# Line not matched: يوسف عمل بلان
# Line not matched:
# Line not matched: اللي حابب يذاكر algorithms هبدأ زي م @⁨Gehad⁩ اقترحت ب playlist عبدالباري
# Line not matched:
# Line not matched: انا عملت ال trello board دي متقسمة بالاسابيع ، وكل اسبوع فيه اليوم 6 ايام بالتاريخ (هناخد الجمعة اجازة) + جوا كل يوم فيه اللينكات اللي هنشوفها
# Line not matched:
# Line not matched: انا حطيت فيديوهين ف اليوم ع نبدأ خفيف + فيه فيديوهات صغيرة بس المحتوي بتاعها محتاج مذاكرة وسيرش يعني
# Line not matched: برضو لو حد شاطر وحابب يدوس it's okay
# Line not matched:
# Line not matched: نوت صغيرة بس: اي حد هيدخل ع اللينك لازم يعمل اكونت وكمان بيبقي معاه ال access انه يعدل علشان trello محترم شوية وعايزنا ندفع ع ال features الزيادة
# Line not matched:
# Line not matched: ممكن نبقي نعمل نوشن احسن بس خلينا نجرب الاسبوع دا ونشوف هل ف عدد وعلي اساسه نطور
# Line not matched:
# Line not matched: https://trello.com/invite/b/hxzxwGsv/ATTIf94213e7aba6cb7b349ecb50eb4c123a853AD534/study-algorithms
# Line not matched: جربي ده كده
# Line not matched: فتحت اول الكتاب ملقتش الجزء ده في الاول
# Line not matched: تعرف موجود او لا؟
# Line not matched: ‎[16.04.2024, 21:09:51] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:11:45] Gehad PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:12:46] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:12:59] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:15:23] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:16:07] ~ ريم الجارحي: ‎image omitted
# Line not matched: هو بس عليه تقسيمة كل يوم هنعمل ايه علي مدار اسبوع
# Line not matched: ‎[16.04.2024, 21:22:43] khld: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 21:26:44] ~ دُنيــا: ‎image omitted
# Line not matched:
# Line not matched: https://t.co/wS1wXD37q8
# Line not matched: انتي وصلتي لفين ف الفديوهات ؟ مفروض تكوني النهارده خلصتي اول 5
# Line not matched: ادعولي أتقبل 🤲🏼
# Line not matched: ‎[16.04.2024, 21:35:35] Yos Bn5alto: ‎audio omitted
# Line not matched: ‎[16.04.2024, 22:25:33] Omr PS: ‎sticker omitted
# Line not matched: ‎[16.04.2024, 22:32:08] ~ ريم الجارحي: ‎image omitted
# Line not matched: ‎[16.04.2024, 22:35:25] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: اخوكم شكله هيبقى اول احتكاك ليه مع competitive فى ecpc الجاى
# Line not matched: اى نصايح عشان يدوب حليت شيتات اسيوط وكام مساله بره 🧑‍🦯
# Line not matched: ف بجد شدو حيلكم وهتوصلو وهتسبقو الناس التقيلة ال موجودة دلوقت
# Line not matched: الناس ال بتقول عندها ١٩ سنة وحاسة انها متأخرة انا مفتكرش ان كان عندي لاب وانا ١٩ سنة وكنت lifeless فشخ
# Line not matched: ‎[16.04.2024, 23:58:36] Thoria PS: ‎sticker omitted
# Line not matched: احسن من الضغط ده كله
# Line not matched: حد يقولى بقى احل ايه عشان قولتوا المسائل دى بتاعه انترفيو عاوزين حاجه تمشى معنا الدنيا
# Line not matched: ابقى lifeless ومطرود
# Line not matched: ‎[17.04.2024, 00:03:32] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: بس انا بحب البطاطس السورى
# Line not matched: ‎[17.04.2024, 00:07:13] Hüsam: ‎video omitted
# Line not matched: هي بتذاكر معاكو algo ؟ لو كدا اطلعها م الجروب ‎<This message was edited>
# Line not matched: لو انا بتكلم بقي كان زمانه داخل يذيع ع الناس ال بترغي
# Line not matched: ‎[17.04.2024, 00:12:18] khld: ‎sticker omitted
# Line not matched: والمسالة هتعدي
# Line not matched: ‎[17.04.2024, 00:15:56] khld: ‎sticker omitted
# Line not matched: ‎[17.04.2024, 00:16:10] Omr PS: ‎sticker omitted
# Line not matched: ٣ فيديوهات
# Line not matched: واليومين كل واحد واحد
# Line not matched: شوف خلصت ادايه واعمل فوت
# Line not matched: تحس فيه نص برازيلى
# Line not matched: ‎[17.04.2024, 00:28:47] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: Abdul Rahman
# Line not matched: Abdul Bary
# Line not matched:
# Line not matched: وهكذا، وممكن تلاقي الموضوع ده في الصومال برضه شوية،
# Line not matched: فغير المسلمين كانوا بيفتكروا إن هما اسمين مش اسم واحد فبينادوهم عبدول وغالبا بيستسهلوا برضه.
# Line not matched: فاتشهرت أي "عبد الإله" يُطلق عليه عبدول.
# Line not matched:
# Line not matched: بالنسبة للي هيذاكر معانا كورس عمنا عبدالباري ، عملنا update للينك ال resources وحطيناه ع نوشن ودا اللينك اهو:
# Line not matched: https://relieved-octave-ae7.notion.site/Study-Algorithms-8df404452dcb4d7ba846793555dcbbf8
# Line not matched:
# Line not matched: احنا برضو حطينا لينك الكتاب بتاع grokking algorithms وهنبدأ من النهاردة اول شابتر ، هناخد كل يوم شابتر برضو وهو خفيف عموما ومعظم الناس عارفة ال topics اللي ف الاول ف هيبقي سهل ان شاء الله.
# Line not matched:
# Line not matched: اللي حابب يذاكر يعمل ريأكت ع المسدج دي ع لو ملتزمش هنخلي @201550112675 تتفاهم معاه.
# Line not matched: يلا بينا نشوف الكتاب بقا
# Line not matched: هتاخد رمز الطالب المتميز خلاص
# Line not matched: ‎[17.04.2024, 16:35:57] Ayash PS: ‎sticker omitted
# Line not matched: أحب الأعمال إلى الله أدومها وإن قل
# Line not matched: بس ارجوك ذاكر اللي مطلوب
# Line not matched: بجرب ال page marker وبيقولي كدة
# Line not matched: ‎[17.04.2024, 18:19:27] Sarah: ‎image omitted
# Line not matched: أن العَقلَ زينةُ الوِلٰدانِ
# Line not matched: ما لم يُزَيِّنْ عَقلُكَ عُمْرَكَ
# Line not matched: فما أنت إلا شَيْبَةٌ صِبياني
# Line not matched: ‎[17.04.2024, 19:35:02] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: درست العروض؟
# Line not matched: عشان دي كانت تاني خطوة عندي
# Line not matched: ‎[17.04.2024, 19:35:52] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: https://youtube.com/playlist?list=PLFAirtVWvzBEWaAeieq2q8ctaC8jaZRNp&si=6tUBDKDgWfh6boRq
# Line not matched: ‎[17.04.2024, 19:45:28] ~ Tohamy: ‎image omitted
# Line not matched: ‎[17.04.2024, 19:47:11] Omr PS: ‎sticker omitted
# Line not matched: ده بتلخبط بين السين والصاد
# Line not matched: ‎[17.04.2024, 20:16:02] ~ mn1655: ‎sticker omitted
# Line not matched: وهو فيه ال binary search
# Line not matched: مين يحب يطبق عليها النهارده نوحد المسائل؟👀
# Line not matched: معهد ابن مالك لتعليم العربية هيفتح قريب، هو برسوم بس أعتقد مش كتير وفي نظام مساعدات ممكن تُعفى من المصاريف كلياً أو جزئياً.
# Line not matched: مدة الدراسة ٤ سنوات
# Line not matched: والمنهج متاح لو حد حابب يبص عليه أو يبدأ فيه لوحده من دلوقتي.
# Line not matched:
# Line not matched: أنا هجمع المصادر اللي ألاقيها وأعمل زي الجدول دا بس hyperlinked إن شاء الله
# Line not matched: ‎[17.04.2024, 20:45:20] Ayash PS: ‎video omitted
# Line not matched: صلي على النبي كدا انا بدأ احل عليه وبصيح اكتر م بحل
# Line not matched: خلود كان معاها حق والله 😂
# Line not matched: CS50 databases
# Line not matched: وياخده slow paced
# Line not matched: Daily log
# Line not matched: ‎OPTION: 1.5.1 (5 votes)
# Line not matched: ‎OPTION: 1.5.2 (5 votes)
# Line not matched: ‎OPTION: Chapter 1 (5 votes)
# Line not matched: كنت خلصت اسبوعين بعد كده انشغلت في الشغل ووقفت
# Line not matched: فبشوف حد نشجع بعض
# Line not matched: I’m looking for fresh graduates 🎓
# Line not matched: with computer science bachelor’s degree or any relevant studies for a very quite interesting position to join #Fawry team
# Line not matched: Send me your CV at the following mail “Rana.ElQady@Fawry.com ” mention “ computer science grade” in the mail subject and will reach you out the soonest
# Line not matched: ف بجد مفيش حد ذاكر أي حاجة؟😃
# Line not matched: ‎[18.04.2024, 00:51:47] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: ‎[18.04.2024, 00:54:45] Ayash PS: Grokking Algorithms-9781617292231.pdf • ‎448 pages ‎document omitted
# Line not matched: ‎[18.04.2024, 00:54:45] Ayash PS: Grokking Algorithms - Full - Cover - No Watermark.pdf • ‎245 pages ‎document omitted
# Line not matched: ‎[18.04.2024, 00:58:25] Gehad PS: ‎sticker omitted
# Line not matched: وصلت فين يباشا؟😂
# Line not matched: ‎[18.04.2024, 01:12:57] Elhrbty PS: ‎image omitted
# Line not matched: ‎[18.04.2024, 01:14:20] Gehad PS: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 01:15:06] Ayash PS: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 02:08:53] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: عشان كل شوية المسدجات تتراكم عليا🫠
# Line not matched: هكمل الفيديوهات بكرة ☕
# Line not matched: ع أساس مش هصحي اتخانق يعني😂
# Line not matched: ‎[18.04.2024, 08:49:16] ~ Menna Esmael: ‎image omitted
# Line not matched: ‎[18.04.2024, 08:49:44] ~ Menna Esmael: ‎sticker omitted
# Line not matched: التوصيل كويس والخامة كويسة برضو
# Line not matched: ‎[18.04.2024, 11:14:57] ~ Menna Esmael: ‎image omitted
# Line not matched:
# Line not matched: انا كنت بنسي اروح الميد ب القلم ونا همتحن اقتصاد والالة الحاسبة كدا كدا مبناخدهاش
# Line not matched: ‎[18.04.2024, 11:45:30] Omr PS: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 11:46:27] ~ Tohamy: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 11:48:24] ~ Tohamy: ‎sticker omitted
# Line not matched: والاتنين دول يجيبوا اتنين ..
# Line not matched: ‎[18.04.2024, 13:02:10] ~ Menna Esmael: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 13:02:33] Yos Bn5alto: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 13:03:52] ~ Menna Esmael: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 13:04:27] Omr PS: ‎sticker omitted
# Line not matched: ففي الحالة دي أنت بتطبع الكتاب لاستخدامك الشخصي فقط ما بتشتريهوش.
# Line not matched: ‎[18.04.2024, 15:09:26] Hasnaa PS: ‎sticker omitted
# Line not matched: فوائد قطع الكهرباء
# Line not matched: لما النور يجي بقا حل مسائل عليهم وابعتلنا
# Line not matched: اوقات واحد واوقات اتنين حسب الفيديو
# Line not matched: ‎[18.04.2024, 15:49:26] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: ‎[18.04.2024, 15:55:11] Yos Bn5alto: ‎audio omitted
# Line not matched: ثانكيوو
# Line not matched: لأن ممكن تكتب كود تفكره O(n) مثلا يطلع بسبب حاجة استخدمتها في النص O(n^2)
# Line not matched: أو أنا متخيل كدا يعني 🤓
# Line not matched: ‎[18.04.2024, 16:31:41] Yos Bn5alto: ‎audio omitted
# Line not matched: مين شاف فيديو النهاردة وقرأ الشابتر التاني 👀
# Line not matched: ‎OPTION: قرأته اه (3 votes)
# Line not matched: ‎OPTION: قرأته بس متصدعناش (1 vote)
# Line not matched: ‎OPTION: مقرأتش اطردني من الجروب (2 votes)
# Line not matched: ‎OPTION: هقرأه لسة اليوم مخلصش (1 vote)
# Line not matched: ‎[19.04.2024, 00:21:21] ~ Noor: ‎image omitted
# Line not matched: ‎[19.04.2024, 00:36:13] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[19.04.2024, 00:39:08] ~ Ahmed Ehab: ‎image omitted
# Line not matched: ‎[19.04.2024, 00:40:41] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: تنزلوا مسائل ريليتد يالتوبيك بتاع الكوتاب :)
# Line not matched: من هنا group 3
# Line not matched: فيه مسئلة كل يوم
# Line not matched: ‎[19.04.2024, 01:01:47] ~ Ahmed Ehab: ‎image omitted
# Line not matched: ‎[19.04.2024, 01:02:04] ~ Ahmed Ehab: ‎image omitted
# Line not matched: قوله جايلك من طرف هربيطي هيعملك بلوك
# Line not matched: Errichto اجنبي ‎<This message was edited>
# Line not matched: ‎[19.04.2024, 01:19:35] ~ OMNIA♡: ‎image omitted
# Line not matched: بس مش فاهمه ليه؟
# Line not matched: ‎[19.04.2024, 01:29:31] ~ OMNIA♡: ‎image omitted
# Line not matched: ‎[19.04.2024, 01:31:51] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[19.04.2024, 01:39:42] Omr PS: ‎image omitted
# Line not matched: المفروض في الجدول بتاعنا الجمعة أجازة
# Line not matched: وعلميا برده باختلاف مستوايتنا نقدر نخلص المطلوب ده قبل ما نبدأ أسبوع جديد خاصة إن كلنا هنكون مبسوطين لو حد جه يناقش فكرة مش فاهمها
# Line not matched: بعد إذنكم نخلص من الكتاب ال 2 شابتر ونخلص في الفيديوهات لحد 1.5.3 عشان نبدأ الأسبوع اللي جاي علي رواق وكلنا نكون سوا🫶🏻
# Line not matched: صدقوني مفيش شعور يضاهي شعور الإنجاز ف بلاش تنشغلوا بتراكمات الحياة وتراكموا الجروب ده كمان🥳
# Line not matched: جمعة مباركة عليكم🫶🏻
# Line not matched: مش أدمن جدع لا
# Line not matched: اني اسف😂😂😂😂
# Line not matched: Rapid Eye Movement
# Line not matched: كناية عن أنها في الأحلام
# Line not matched: ‎[19.04.2024, 01:52:48] Omr PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 01:53:12] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 01:53:38] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: أما الكمبيوتر غبي بصحيح
# Line not matched: ‎[19.04.2024, 01:54:59] Gehad PS: ‎sticker omitted
# Line not matched: طبعا لو مشروع كبير معنديش رفاهية إني أبدأ من الصفر🏃🏻‍♀️
# Line not matched: ‎[19.04.2024, 02:01:17] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: عاش
# Line not matched: ‎[19.04.2024, 02:29:42] Gehad PS: ‎sticker omitted
# Line not matched: هي مش مجرد كناية بدون سبب، هي حاجة علمية.
# Line not matched: لما الشخص بينام وبيدخل في مرحلة النوم العميق عينه بتتحرك بشكل غريب وسريع، ويُقال إن هي دي الفترة اللي الناس بتحلم فيها ‎<This message was edited>
# Line not matched: ‎[19.04.2024, 05:00:52] ~ Mohamed Ezat: ‎image omitted
# Line not matched: ‎[19.04.2024, 07:39:20] ~ 3obd: ‎video omitted
# Line not matched: ‎[19.04.2024, 17:13:57] Gehad PS: ‎audio omitted
# Line not matched: بما إني لسه محلتش حاجة النهارده مين يشجعني نحل علي حاجة معينة سوا؟😂
# Line not matched: ‎[19.04.2024, 21:22:38] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 21:29:39] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 21:30:46] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 21:33:05] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 21:37:25] Gehad PS: ‎sticker omitted
# Line not matched: منتهي العشوائية من غير ما أقرأ
# Line not matched: روح خد درس مع بتوع علمى رياضة
# Line not matched: عشان تبتدى  من الاول بالاساسيات قبل ما تخش بقى على المراجع والنظريات  والتخصص نفسه
# Line not matched: جايبلي إيرور في سطر 37
# Line not matched: و من ناحية تانية الاقي سكة ال DE
# Line not matched: مش عارف
# Line not matched:
# Line not matched: https://github.com/ossu/math
# Line not matched: هبص عليه
# Line not matched: شوفوا مسائلكم والموقع بتاعكم ‎<This message was edited>
# Line not matched: ‎[19.04.2024, 22:21:35] Ayash PS: ‎image omitted
# Line not matched: ‎[19.04.2024, 22:21:42] Ayash PS: ‎image omitted
# Line not matched: ‎[19.04.2024, 22:21:47] Gehad PS: ‎sticker omitted
# Line not matched: انا اوريدي بقرأ من واحد بس معرفش هو الاحسن و لا لا
# Line not matched: Class solution
# Line not matched: اللي بتكون في اول الايديتور هل انت شيلتها؟
# Line not matched: ‎[19.04.2024, 22:28:46] Hasnaa PS: ‎image omitted
# Line not matched: 1-sort
# Line not matched: 2- find the largest index
# Line not matched: 3-max size of subsequence is idx+1
# Line not matched: ‎[19.04.2024, 22:44:01] Ayash PS: ‎image omitted
# Line not matched: ‎[19.04.2024, 23:03:53] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 23:05:07] Gehad PS: ‎sticker omitted
# Line not matched: ‎[19.04.2024, 23:15:36] Ayash PS: ‎sticker omitted
# Line not matched: علشان انا مراكمه وعايزه الحقو
# Line not matched: وفي أي نحلو 🙂🚶‍♀️
# Line not matched: ‎[20.04.2024, 00:26:41] ~ Nada: ‎sticker omitted
# Line not matched: شابتر ٢
# Line not matched: ظاهر عندي رسالة الريسورس ورسالة الابلكيشن التاني
# Line not matched: يا رب ابطل مرقعه 😂
# Line not matched: ‎[20.04.2024, 00:30:38] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 00:31:04] ~ Nada: ‎sticker omitted
# Line not matched: باجى افتحه يدينى ايرور ومسحته ونزلته بس برضه نفس الرساله ومش عارفه اعمل اى
# Line not matched: ‎[20.04.2024, 04:42:07] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 04:48:30] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 04:52:55] Habiba Gamal PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 04:56:33] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 04:58:17] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 04:59:11] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 05:03:01] Habiba Gamal PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 05:45:14] ~ mn1655: ‎image omitted
# Line not matched: ‎[20.04.2024, 12:09:46] Yos Bn5alto: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 12:15:58] Yos Bn5alto: ‎audio omitted
# Line not matched: ‎[20.04.2024, 12:16:12] Yos Bn5alto: ‎audio omitted
# Line not matched: ‎[20.04.2024, 12:32:25] Gehad PS: ‎audio omitted
# Line not matched: ‎[20.04.2024, 12:33:54] Gehad PS: ‎audio omitted
# Line not matched: ‎[20.04.2024, 12:42:19] Omr PS: ‎sticker omitted
# Line not matched: 1.6
# Line not matched: 1.7
# Line not matched: نص شابتر 3
# Line not matched: ‎[20.04.2024, 13:28:17] Ayash PS: ‎sticker omitted
# Line not matched: ده
# Line not matched: dynamic programming?
# Line not matched: سقفولى
# Line not matched: الdp مشروحه ف جروكنج اعتقد شابتر 9 او حاجه
# Line not matched: https://youtu.be/xrMppTpoqdw?si=yGnLCk9wkb6wNVNE
# Line not matched: ده بالعربي وبيطبق cpp
# Line not matched:
# Line not matched: https://youtube.com/playlist?list=PL2_aWCzGMAwL3ldWlrii6YeLszojgH77j&si=xCdjgiamMNt_VCw2 ‎<This message was edited>
# Line not matched: ‎[20.04.2024, 17:30:44] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: علشان مكسل أدخل المسابقة السنة دي
# Line not matched: ‎[20.04.2024, 18:20:40] Omr PS: ‎image omitted
# Line not matched: ‎[20.04.2024, 18:31:48] Esraa: ‎sticker omitted
# Line not matched: بجد مش عارفه المفروض بعرف الايرو ازاي
# Line not matched: او تحولها ل pdf
# Line not matched: يعني للقدر اللي يخليني اعرف افرق بين الحل وايه انسب حل وكدا
# Line not matched: ‎[20.04.2024, 22:52:44] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 22:53:28] khld: ‎sticker omitted
# Line not matched: ملحقتش العز اللي انتو لحقتوه
# Line not matched: ‎[20.04.2024, 22:55:48] Mo7 Tahr Twtr: ‎sticker omitted
# Line not matched: في الكام شهر دول
# Line not matched: ‎[20.04.2024, 22:57:43] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 22:58:05] Mo7 Tahr Twtr: ‎sticker omitted
# Line not matched: ايه ااجي امسك الماركتنج بدالكم
# Line not matched: انا اللي فهمني الدنيا حسام الله يباركله، وبعدين دخلت سبيس على تويتر
# Line not matched: وتوكلت على الله
# Line not matched: ‎[20.04.2024, 23:07:55] Yos Bn5alto: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:08:28] khld: ‎sticker omitted
# Line not matched: إن شاء الله
# Line not matched: ‎[20.04.2024, 23:10:50] Yos Bn5alto: ‎audio omitted
# Line not matched: ‎[20.04.2024, 23:14:55] Ayash PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:15:44] Ayash PS: ‎video omitted
# Line not matched: ‎[20.04.2024, 23:18:56] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:19:19] Gehad PS: ‎sticker omitted
# Line not matched: لكن انا مش راجل ف عادي اعمل كده
# Line not matched: ‎[20.04.2024, 23:22:36] khld: ‎image omitted
# Line not matched: ‎[20.04.2024, 23:23:17] Gehad PS: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:29:09] Ayash PS: ‎sticker omitted
# Line not matched: الصدقة حاجة حلوة
# Line not matched: ‎[20.04.2024, 23:31:56] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:33:40] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:33:41] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:33:43] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:33:43] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:35:26] Hüsam: ‎video omitted
# Line not matched: ‎[20.04.2024, 23:36:40] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:40:15] khld: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:42:54] Yos Bn5alto: ‎sticker omitted
# Line not matched: ‎[20.04.2024, 23:46:18] khld: ‎sticker omitted
# Line not matched: شوفيها كدا ضميها للعصابة
# Line not matched: ‎[21.04.2024, 00:37:48] Gehad PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 00:39:17] Gehad PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 00:43:10] Gehad PS: ‎sticker omitted
# Line not matched: يوسف نام😂
# Line not matched: وقاعدة بشكر نفسي اني خليت اليوم بسيط وسهل كده🤣
# Line not matched: ف أي حد مخلصش فرصتك جتلك وقوموا خلصوا💃🏻
# Line not matched: أشطر جهاد
# Line not matched: ‎[21.04.2024, 02:26:56] Gehad PS: ‎sticker omitted
# Line not matched: أنأاااا
# Line not matched: ‎[21.04.2024, 15:19:45] Ayash PS: ‎image omitted
# Line not matched: ‎[21.04.2024, 15:29:40] Gehad PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 15:37:51] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: بتطرقنا عشان تذاكر هي 😡😡😡
# Line not matched: ‎[21.04.2024, 17:12:59] khld: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:13:55] khld: ‎sticker omitted
# Line not matched: عياش ال معندوش ريحة السينس :
# Line not matched: ‎[21.04.2024, 17:15:13] khld: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:15:23] Omr PS: ‎sticker omitted
# Line not matched: بس يتبلو دي عالم تاني
# Line not matched: فايتك حصيلة لغوية خلودية شكلي كده هخليها ماتفوتكش
# Line not matched: اللغه العربيه وبساطتها بس انت ال بتتحنيك
# Line not matched: ‎[21.04.2024, 17:20:03] Omr PS: ‎sticker omitted
# Line not matched: علشان الأولى فعل والثانية اسم، وأنا عمال أحاول ألاقي حد اسمه يتبلو.
# Line not matched: المبتلي هو الله
# Line not matched: ‎[21.04.2024, 17:26:15] Omr PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:27:35] khld: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:32:36] Omr PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:32:59] Omr PS: ‎sticker omitted
# Line not matched: أي ارتفع
# Line not matched: ‎[21.04.2024, 17:37:22] Elhrbty PS: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 17:39:45] khld: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 18:49:58] khld: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 19:11:28] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 19:12:39] Habiba Gamal PS: ‎sticker omitted
# Line not matched: كل حد فينا بيبعت بقاله كام يوم منتظم بما انك اول يوم تبداي ب Day 1🙈
# Line not matched: ‎[21.04.2024, 19:36:47] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[21.04.2024, 22:15:50] khld: ‎sticker omitted
# Line not matched: ده انا جاي أتعلم منكم والله ❤️
# Line not matched: الاخت @201096942964 شريكة برضو
# Line not matched: و @201550112675 مديرة المشروع كمان
# Line not matched: ‎[21.04.2024, 22:18:51] khld: ‎sticker omitted
# Line not matched: https://delicious-caraway-75c.notion.site/ProblemSolving-a85000883a1842ddafd70b5376e2e21a
# Line not matched: انا اتشرفت بيكم جميعاً 🙏🏻
# Line not matched: متحسسنيش إن انا السبب 😈
# Line not matched: ‎[21.04.2024, 23:07:42] khld: ‎sticker omitted
# Line not matched: طمنوني وصلتوا لايه في الخطة؟
# Line not matched: ‎[22.04.2024, 01:34:50] Gehad PS: ‎sticker omitted
# Line not matched: يريت قترحه تانى عشان انا عرفت هعمل ايه فالمواصلات 😶‍🌫️
# Line not matched: بغير كل فتره عادى ☝️
# Line not matched: ‎[22.04.2024, 01:51:57] Youssef Elmelegy PS: ‎sticker omitted
# Line not matched: حرام ي سيدي
# Line not matched: مثلا ده هيفيدك ف ايه؟ هيفيدك ف انك تعرف تحل مشاكل ال ps بتاع ال run time
# Line not matched: وعلي المدى للابعد لما تيجي تعمل مشروع كبير هتلاقي نفسك بتقارن بين الحاجات عشان اعتمادا علي وقتها هتختارها
# Line not matched: يعني انت عايز الوقت يكون ادايه؟ وال space كمان
# Line not matched: ف دي حاجات بتأثر ع النطاق الصغير والنطاق الأكبر
# Line not matched: البلاي ليست طويلة جدا بس الراجل بيشرح بتفاصيل كويسة تخليك تحسن إدراكك وانت بتكتب او تقرأ كود
# Line not matched: ‎[22.04.2024, 02:32:15] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: ‎[22.04.2024, 02:33:36] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: ‎[22.04.2024, 02:34:14] Omr PS: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 02:36:05] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 02:42:14] Gehad PS: ‎sticker omitted
# Line not matched: وحليت جزء من تاسكات alx
# Line not matched: وجزء من البناء المنهجي🏃🏻‍♀️
# Line not matched: الباقي كان مجاني بس حاليا لا
# Line not matched: شكرا جدا
# Line not matched: ‎[22.04.2024, 12:29:05] Ahmed Mounir PS: ‎image omitted
# Line not matched: غير كده هيبقي لا وعايزينك تقدم عادي ف المدفوع
# Line not matched: ‎[22.04.2024, 12:36:01] Ahmed Mounir PS: ‎image omitted
# Line not matched: ‎[22.04.2024, 12:40:08] Ahmed Mounir PS: ‎image omitted
# Line not matched: بسيطه هتقدر تنجزهم ف 6 سنين
# Line not matched: ‎[22.04.2024, 12:40:59] khld: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 12:41:09] Gehad PS: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 12:43:12] Ahmed Mounir PS: ‎image omitted
# Line not matched: جهاد المتفائله ومغفله :
# Line not matched: ‎[22.04.2024, 12:43:56] khld: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 12:44:54] khld: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 12:47:35] khld: ‎sticker omitted
# Line not matched: طب الحق يلا ركز مع البرمجة🏃🏻‍♀️
# Line not matched: ‎[22.04.2024, 12:49:34] khld: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 12:50:37] khld: ‎sticker omitted
# Line not matched: هي برضو:
# Line not matched: أنا مخلص fundamentals ofc++ وبحل بقالي شهر ونص كدا problem solving
# Line not matched: ‎[22.04.2024, 12:51:19] khld: ‎sticker omitted
# Line not matched: وبعدين ارجع ذاكر تاسكات c👀
# Line not matched: github, bash, vim
# Line not matched: بتنزلي سطر ازاي؟
# Line not matched: درسنا c
# Line not matched: الفكره ف تاسكات alx انها بتديك اساسيات الاساسيات وبتعيد سيكلة الC ، وهي لو ليفل عن الC++ اصلا كمان، مش حاجات بسيطه زي مانت متخيل لكن فايدتها كبيره بجد لما تيجي بعدين تتعلم اي لغه تانيه
# Line not matched: فانت لو مبتدأ تماما ممكن تبدأ من مانث 3 تركز ف تاسكاته كويس وف الايام الاجازه من التاسكات ترجع تاخد تاسك او اتنين من مانث 0 وهكذا ..
# Line not matched: ‎[22.04.2024, 12:56:30] khld: ‎sticker omitted
# Line not matched: مخرجتش اوي ف اللغات برا زون alx
# Line not matched: ‎[22.04.2024, 12:59:06] Ahmed Mounir PS: ‎image omitted
# Line not matched: وربنا يجازيكوا جميعًا كل خير
# Line not matched: يعني يعرفني المفروض أعمل إيه بالضبط عشان اكون ماشي صح
# Line not matched: ‎[22.04.2024, 13:26:52] khld: ‎sticker omitted
# Line not matched:
# Line not matched: عااااااش♥️
# Line not matched: انا خلصت كورس محمد الدسوقي بتاع data structures
# Line not matched: ده https://youtube.com/playlist?list=PL1DUmTEdeA6JlommmGP5wicYLxX5PVCQt&si=yBr_uXmdsg0xR5xl
# Line not matched: هل دلوقتي ادخل على كورس عبد الباري على طول ولا لسه في حاجه ناقصه
# Line not matched: حاولي تذاكري ل وقتها 🏃🏻‍♀️
# Line not matched: ‎[22.04.2024, 17:00:31] Shahd Tamer PS: ‎sticker omitted
# Line not matched: ‎[22.04.2024, 17:04:44] Shahd Tamer PS: ‎image omitted
# Line not matched: بيبقى easy فعلا؟ ولا بيبقى لها ريت ولا ايه الوضع فيها
# Line not matched: تحت ال description
# Line not matched: لو فوق ال 45% يعني الى حد ما سهلة تحت كدا بتبقى صعبة -الرقم دا اعتباطي لسه مخترعه دلوقت-
# Line not matched: ‎[22.04.2024, 22:22:12] ~ Aya Elsheshtawy: ‎image omitted
# Line not matched: وفيه مسائل medium الفكرة ممكن تيجي ف دماغك اول م تشوفي السؤال
# Line not matched: ف الموضوع مطاط شوية المقياس بتاعه بيختلف من شخص للتاني
# Line not matched: يعني ال acceptance فوق ال %45 دا بالنسبالي ممكن يكون لحد 40% سهل بالنسبة لحد
# Line not matched: فاهماني ؟
# Line not matched: بس بعدين وقفت وم ساعتها مكملتش ولا فتحته تاني
# Line not matched: بس عندي مرض ابدأ اي حاجه اذاكر فيها شوية حلوين ومكملهاش
# Line not matched: انا خلصت 4
# Line not matched: ‎[23.04.2024, 01:22:43] Omr PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 02:13:10] Gehad PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 02:16:29] Gehad PS: ‎sticker omitted
# Line not matched: فاتحة ليه؟
# Line not matched: ‎[23.04.2024, 02:18:49] Omr PS: ‎sticker omitted
# Line not matched: بس رجعيني تانى انا طيبه 😂🤡🤡
# Line not matched: ليلتك مش فايتة يا ندى☠️
# Line not matched: خوفينا انت اي حد
# Line not matched: ‎[23.04.2024, 02:20:24] Gehad PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 02:26:58] Gehad PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 02:27:51] Gehad PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 02:30:35] Hüsam: ‎video omitted
# Line not matched: ‎[23.04.2024, 02:34:33] khld: ‎sticker omitted
# Line not matched: سامو عليكو دا مش الجروب بتاعي وانا من المنوفية وجيت هنا بالغدةلط وعايز ٢٠ جني اروح بيها .. المهم
# Line not matched: ‎OPTION: خلصت المُقرر من الكتاب ؟ (4 votes)
# Line not matched: ‎OPTION: خلصت المُقرر من البلاي ليست ؟ (5 votes)
# Line not matched: ‎[23.04.2024, 17:25:58] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 17:27:05] khld: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 17:28:50] khld: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 20:22:11] Ayash PS: ‎sticker omitted
# Line not matched: ايه رأيكم؟
# Line not matched: ‎[23.04.2024, 20:56:04] Ayash PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 21:00:15] Ayash PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 21:02:34] Omr PS: ‎sticker omitted
# Line not matched: احيانا python, c++
# Line not matched: ونادرا c
# Line not matched: ‎[23.04.2024, 22:10:10] khld: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 22:11:43] Hüsam: ‎image omitted
# Line not matched: ‎[23.04.2024, 22:12:03] Gehad PS: ‎sticker omitted
# Line not matched: {
# Line not matched: '1': 2,
# Line not matched: Some lines
# Line not matched: '10': 3
# Line not matched: }
# Line not matched: عايزة اطبعه ال } ف نفس السطر
# Line not matched: ‎[23.04.2024, 22:23:00] Yousef Fathy PS: ‎audio omitted
# Line not matched: يفضل زي ما هو بس ال } بتاع الديكشنري تكون ف اول سطر واخر سطر
# Line not matched: مش منفردين
# Line not matched: {
# Line not matched: "key1": "value1",
# Line not matched: "key2": "value2",
# Line not matched: "key3": "value3"
# Line not matched: }
# Line not matched: Alx مش راضية
# Line not matched: عيزاه
# Line not matched: { "key1": "value1",
# Line not matched: ..
# Line not matched: "Key3:v3}
# Line not matched: ‎[23.04.2024, 22:29:40] khld: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 22:30:14] Yousef Fathy PS: ‎audio omitted
# Line not matched: ‎[23.04.2024, 22:34:00] Gehad PS: ‎image omitted
# Line not matched: ‎[23.04.2024, 22:35:02] Yousef Fathy PS: ‎audio omitted
# Line not matched: ‎[23.04.2024, 22:35:40] Gehad PS: ‎sticker omitted
# Line not matched: فين اللينك
# Line not matched: ‎[23.04.2024, 22:45:02] Yousef Fathy PS: ‎image omitted
# Line not matched: ‎[23.04.2024, 22:49:03] Gehad PS: ‎sticker omitted
# Line not matched: key1: 'value1',
# Line not matched: key2: 'value2',
# Line not matched: key3: 'value3'
# Line not matched: };
# Line not matched:
# Line not matched: let jsonString = '{\n';
# Line not matched:
# Line not matched: for (let currentKey in yourDictionary) {
# Line not matched: const allKeys = Object.keys(yourDictionary);
# Line not matched: const firstKey = allKeys[0];
# Line not matched: const lastKey = allKeys[allKeys.length - 1];
# Line not matched:
# Line not matched: if (allKeys.indexOf(currentKey) === 0) {
# Line not matched: jsonString += `  "${currentKey}": "${yourDictionary[currentKey]}",\n`;
# Line not matched: } else if (allKeys.indexOf(currentKey) === allKeys.length - 1) {
# Line not matched: jsonString += `  ...\n`;
# Line not matched: jsonString += `  "${currentKey}": "${yourDictionary[currentKey]}"\n`;
# Line not matched: }
# Line not matched: }
# Line not matched:
# Line not matched: jsonString += '}';
# Line not matched: console.log(jsonString);
# Line not matched: + مش معايا بس وماله نتصرف😔
# Line not matched: ‎[23.04.2024, 22:56:22] khld: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 22:56:51] Omr PS: ‎sticker omitted
# Line not matched:
# Line not matched: بتقعدوا كام في المسألة لغاية ما تشوفوا الحل لو معرفتوش تجيبوها :))
# Line not matched: أنك لقطت الفكرة بس عطلان في التنفيذ
# Line not matched: وفي أنك مش عارف تتجاب ازاي أصلا
# Line not matched: ‎[23.04.2024, 23:13:37] Omr PS: ‎sticker omitted
# Line not matched: ‎[23.04.2024, 23:13:41] Omr PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 12:31:06] khld: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 12:43:40] Gehad PS: ‎audio omitted
# Line not matched: ‎[24.04.2024, 12:43:50] Gehad PS: ‎audio omitted
# Line not matched: يعني ايه "ع" اللي كلكم بتكتبوها دي؟
# Line not matched: ‎[24.04.2024, 13:05:34] Ayash PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 13:05:51] Ayash PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 13:07:37] khld: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 13:16:06] Gehad PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 13:22:55] Hüsam: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 13:58:54] khld: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 14:22:26] Gehad PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 15:28:50] khld: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 15:29:15] Tut: ‎sticker omitted
# Line not matched: Chapter 5 انهاردة😂🤌🏻
# Line not matched: اعتبره اتذاكر😂
# Line not matched: ‎[24.04.2024, 17:04:19] Omr PS: ‎sticker omitted
# Line not matched: أنا دايس عليا قطر
# Line not matched: ‎[24.04.2024, 20:04:04] Ayash PS: ‎image omitted
# Line not matched: ‎[24.04.2024, 20:04:45] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: بلاش ديكتاتورية
# Line not matched: عمالين تقفلوا الجروبات،
# Line not matched: واللي متفق مع كلامي اللي فوق ده محتاج يتعالج.
# Line not matched: كويس إنك قفلته
# Line not matched: ‎[24.04.2024, 20:08:16] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 20:08:21] Gehad PS: ‎sticker omitted
# Line not matched: @201017076715 @201098140950
# Line not matched: هنا
# Line not matched: او نوشن
# Line not matched: أمال أنت كنت متابعة مع مين
# Line not matched: ‎[24.04.2024, 20:09:19] ~ ريم الجارحي: ‎video omitted
# Line not matched: + هي بقت كدا
# Line not matched: ‎[24.04.2024, 20:09:52] Gehad PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 20:12:36] Hüsam: ‎audio omitted
# Line not matched: ‎[24.04.2024, 20:13:44] Ayash PS: ‎GIF omitted
# Line not matched: ‎[24.04.2024, 20:14:51] Gehad PS: ‎sticker omitted
# Line not matched: اتعاملوا أنتو مع صياح ريم
# Line not matched: ‎[24.04.2024, 20:18:20] Gehad PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 20:19:36] Ayash PS: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 22:27:37] Hüsam: ‎sticker omitted
# Line not matched: ‎[24.04.2024, 22:30:13] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: خلصتوا ادايه يا شباب؟
# Line not matched: وهستني بكرة تخلص الخامس🥳
# Line not matched: كنت بروح شبين
# Line not matched: بس مش بستلطفهم
# Line not matched: ‎[25.04.2024, 03:10:36] ~ Ahmed Ehab: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 04:05:19] khld: ‎sticker omitted
# Line not matched: لو بيساويه اطبعلي كذا ووقف البرنامج
# Line not matched: definitely Aya
# Line not matched: ‎[25.04.2024, 12:14:21] ~ ريم الجارحي: ‎image omitted
# Line not matched: حسبي الله
# Line not matched: ‎[25.04.2024, 12:15:05] ~ ريم الجارحي: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 12:21:35] ~ ريم الجارحي: ‎image omitted
# Line not matched: ‎[25.04.2024, 12:25:44] Ayash PS: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 12:27:14] ~ ريم الجارحي: ‎image omitted
# Line not matched: ميفضلش يطبع wrong  لما لانهاية
# Line not matched: حسيت بس بحتة بصمجة فقلت أتأكد
# Line not matched: ‎[25.04.2024, 12:38:40] Ayash PS: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 13:33:12] Yos Bn5alto: ‎audio omitted
# Line not matched: ‎[25.04.2024, 16:38:58] Gehad PS: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 18:10:57] Ayash PS: ‎video omitted
# Line not matched: الچينيص؟
# Line not matched: انا خلصت نص البلاي ليست وreread ل ال 8 شباتر
# Line not matched: عايزه عاركه
# Line not matched: ‎[25.04.2024, 19:08:14] khld: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 19:10:57] khld: ‎sticker omitted
# Line not matched: ‎[25.04.2024, 19:15:21] Omr PS: ‎sticker omitted
# Line not matched: مين خلص لغاية فيديو ال best & worst case اللي هو 1.11 ؟
# Line not matched: ‎OPTION: اه (7 votes)
# Line not matched: ‎OPTION: اه بس متصدعناش (1 vote)
# Line not matched: ‎OPTION: لا (4 votes)
# Line not matched: ‎OPTION: معا لطرد يوسف من الجروب (1 vote)
# Line not matched: أي حد مراكم أي حاجة من الالجوريزم او فيه نقطة مش واثق انه فهمها كويس، جتلك فرصة😂
# Line not matched: ف أتمني كل شخص يبدأ الأسبوع الجديد بنية جديدة ومخلص كل اللي وراه🤌🏻
# Line not matched: وأي حد خلص اللي وراه تختاروا مسألة عن المواضيع اللي ذاكرنها نحلها ونتناقش فيها؟
# Line not matched: ‎[26.04.2024, 16:01:46] Ayash PS: ‎sticker omitted
# Line not matched:
# Line not matched: هنبدأ ال recurrence relation ودا توبيك تقيل شويتين ف كل يوم فيديو 😂
# Line not matched: باقي 6 شباتر ف الكتاب هنقسمهم ع الاسبوعين الجايين
# Line not matched: ‎[26.04.2024, 23:17:24] Gehad PS: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:17:59] Omr PS: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:18:15] khld: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:18:17] Omr PS: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:18:21] khld: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:18:33] Omr PS: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:20:27] khld: ‎sticker omitted
# Line not matched: ‎[26.04.2024, 23:22:20] ~ Aya Elsheshtawy: ‎sticker omitted
# Line not matched: ‎[27.04.2024, 00:10:45] Yos Bn5alto: ‎sticker omitted
# Line not matched: ‎[27.04.2024, 00:32:46] ~ Ahmed Ehab: ‎audio omitted
# Line not matched: ‎[27.04.2024, 00:39:22] Thoria PS: ‎sticker omitted
# Line not matched: ممكن نعتبر النهارده اننا ف جروب ال streak وتقولولي كل واحد وصل فين؟
# ...
# Processing message from: David PS at 2.09.2024
# Line not matched: ‎[2.09.2024, 20:08:14] أَدْهَم عَلَّاَم PS: ‎sticker omitted
# Processing message from: Salah Mohamed Twtr at 2.09.2024
# Processing message from: Omnia PS at 3.09.2024
# Processing message from: Mahmoud at 3.09.2024
# Processing message from: Mahmoud at 3.09.2024
# Processing message from: . PS at 3.09.2024
# Processing message from: أَدْهَم عَلَّاَم PS at 3.09.2024
# Line not matched:
# Line not matched: عموماً الجزء اللي فصل فيه كانت مسألة هارد فا مش مهمة لحد مبتدئ يعني دلوقتي
# Processing message from: Salah Mohamed Twtr at 3.09.2024
# Processing message from: Salah Mohamed Twtr at 3.09.2024
# Processing message from: أَدْهَم عَلَّاَم PS at 3.09.2024
# Processing message from: Zeyad at 4.09.2024
# Processing message from: Karema PS at 4.09.2024
# Processing message from: Karema PS at 4.09.2024
# Line not matched: ‎[4.09.2024, 13:38:47] Karema PS: ‎sticker omitted
# Processing message from: Hüsam at 4.09.2024
# Processing message from: Tarek at 4.09.2024
# Processing message from: David PS at 4.09.2024
# Processing message from: MGamal at 4.09.2024
# Processing message from: Habiba Gamal PS at 4.09.2024
# Processing message from: Hüsam at 4.09.2024
# Processing message from: Habiba Gamal PS at 4.09.2024
# Processing message from: Ahmed Mounir PS at 4.09.2024
# Line not matched: المفروض أبقا عارف ايه في ال recursive دا وال Asymptotic دا بالظبط عشان أقول إني فاهم الدرس كويس..يعني الproofs والمعادلات اللي بتتشرح دي بتحسسني إني تايه ومش فاهم حاجة!!
# Processing message from: Ahmed Hesham at 4.09.2024
# Processing message from: Ahmed Mounir PS at 4.09.2024
# Line not matched: زي مثلا
# Line not matched: F(n)=c.g(n)
# Processing message from: Ahmed Hesham at 4.09.2024
# Processing message from: Ahmed Mounir PS at 4.09.2024
# Processing message from: Ahmed Hesham at 4.09.2024
# Processing message from: Ahmed Mounir PS at 4.09.2024
# Line not matched: ‎[4.09.2024, 16:08:29] ~ Ahmed Hesham: ‎audio omitted
# Processing message from: Ahmed Mounir PS at 4.09.2024
# Processing message from: Ahmed Hesham at 4.09.2024
# Processing message from: Sara at 4.09.2024
# Processing message from: Sara at 4.09.2024
# Processing message from: Hoda Salim PS at 4.09.2024
# Processing message from: Amira PS at 4.09.2024
# Processing message from: Yos S3D Twtr at 4.09.2024
# Processing message from: Elknz PS at 4.09.2024
# Processing message from: Amany Mohammed PS at 4.09.2024
# Processing message from: Amal Eltelbany PS at 4.09.2024
# Processing message from: Abdelhadi PS at 4.09.2024
# Processing message from: Salah Mohamed Twtr at 5.09.2024
# Processing message from: Zeyad Albadawy PS at 5.09.2024
# Processing message from: Ahmed Elkassrawy PS at 5.09.2024
# Processing message from: Zeyad at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: Esraa at 5.09.2024
# Processing message from: * PS at 5.09.2024
# Line not matched:
# Line not matched: ٩ فيديوهات ع ال recursion in deep knowledge
# Line not matched:
# Line not matched: https://delicious-caraway-75c.notion.site/f713b73ec88d41e0a8529d729fe7a8db?v=e6e8bc1ee4f5423f838e39dc9c28352b&pvs=74
# Line not matched:
# Line not matched: الديدلاين يوم 2
# Processing message from: Zeyad at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Line not matched: . هنذاكر من عبدول ان شاء الله ولو حد حابب يزوّد هحط فيديو من MIT لان شرحهم كويس جدا
# Line not matched: . هنذاكر اول ٨ ڤيديوهات
# Line not matched: . الڤيديوهات والديدلاين هنا وهنتابع ع نوشن هنا
# Line not matched: https://delicious-caraway-75c.notion.site/1-Deadline-ca1627135a824ad48a253ee5344b3df6?pvs=74
# Line not matched: . احنا كالعادة هنعمل ديدلاين ونركّب القطر، بس كملت ع فكرة نوشن بتاع @⁨~Yousef Ahmed⁩ و @⁨~Gehad⁩ بحيث لو حد مش عاجبه نظام الديدلاين وكدا ممكن يشوف هنذاكر ايه ويتابع معانا (مع ان الديدلاين بيجبرك يذاكر بس كل واحد ع راحته)
# Line not matched:
# Line not matched:
# Line not matched: . الديدلاين يوم ١٥ ونعمل مذبحة القلعة راوند تو
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Line not matched: تقريبا ٧ ڤيديوهات بس
# Line not matched: حاططهم هنا
# Line not matched: https://delicious-caraway-75c.notion.site/f713b73ec88d41e0a8529d729fe7a8db?v=e6e8bc1ee4f5423f838e39dc9c28352b&pvs=74
# Line not matched:
# Line not matched: ال مش عاجبه عبدول ممكن يذاكر من اي مكان عادي مش اجباري بس يشوف احنا بنذاكر ايه ويمشي معانا
# Line not matched:
# Line not matched: الديدلاين يوم ٢٤
# Processing message from: Karema PS at 5.09.2024
# Processing message from: Hüsam at 5.09.2024
# Line not matched:
# Line not matched: ال ذاكر يقول فضلا
# Processing message from: KHALED𓂆 at 5.09.2024
# Processing message from: David PS at 5.09.2024
# Processing message from: David PS at 5.09.2024
# Processing message from: Salah Mohamed Twtr at 5.09.2024
# Processing message from: Karema PS at 5.09.2024
# Processing message from: Mariam Osman PS at 5.09.2024
# Processing message from: Ahmed Salman PS at 5.09.2024
# Processing message from: Esraa at 5.09.2024
# Processing message from: Ahmed Mounir PS at 5.09.2024
# Processing message from: Mai Samir PS at 5.09.2024
# Processing message from: Amany Mohammed PS at 5.09.2024
# Processing message from: Amira PS at 5.09.2024
# Processing message from: Asma 🪄 at 5.09.2024
# Processing message from: Shaimaa at 5.09.2024
# Processing message from: Ahmed Jamal Sultan PS at 5.09.2024
# Processing message from: * PS at 5.09.2024
# Processing message from: Motaz PS at 5.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 5.09.2024
# Processing message from: رِيمُو PS at 5.09.2024
# Processing message from: Aysha at 6.09.2024
# Line not matched: ‎[6.09.2024, 01:45:02] Hasnaa PS: ‎sticker omitted
# Processing message from: Younes PS at 6.09.2024
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Younes PS at 6.09.2024
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Younes PS at 6.09.2024
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Younes PS at 6.09.2024
# Line not matched: والنص التاني on
# Line not matched: وكذلك ال ai models برضو
# Processing message from: Shaimaa at 6.09.2024
# Processing message from: Sara at 6.09.2024
# Processing message from: Shahd Tamer PS at 6.09.2024
# Processing message from: Ahmed Abdelsamie PS at 6.09.2024
# Processing message from: Ichraf 🤓👩‍💻 at 6.09.2024
# Processing message from: Mennatallah at 7.09.2024
# Processing message from: Mennatallah at 7.09.2024
# Line not matched:
# Processing message from: PS-StudyingAlgos 📚 at 7.09.2024
# Line not matched: ‎[7.09.2024, 12:25:01] Hüsam: ‎video omitted
# Processing message from: Hüsam at 7.09.2024
# Line not matched:
# Line not matched: - حاجات بسيطة فاضلة ع ال recursion
# Line not matched: - ⁠هنبدأ ف ال searching algos
# Line not matched:
# Line not matched: - مش لاقي فيديو ف MIT بيشرح searching لو حد لاقاه يبعتلي نضيفه
# Line not matched:
# Line not matched: - الديدلاين يوم ١٤
# Line not matched: - اخر حاجة واهم حاجة صديقنا @905314084287 عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين والريسورسز هنا
# Line not matched: https://delicious-caraway-75c.notion.site/f713b73ec88d41e0a8529d729fe7a8db?v=e6e8bc1ee4f5423f838e39dc9c28352b&pvs=74
# Processing message from: ‎You at 7.09.2024
# Processing message from: BΛSΛNT at 7.09.2024
# Processing message from: Tarek at 8.09.2024
# Processing message from: PS-StudyingAlgos 📚 at 10.09.2024
# Processing message from: Hüsam at 10.09.2024
# Processing message from: * PS at 10.09.2024
# Processing message from: Ayash PS at 11.09.2024
# Line not matched:
# Line not matched: Breaking the algos
# Processing message from: Mennatallah at 12.09.2024
# Processing message from: Mohamed Rabee PS at 12.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Sara at 13.09.2024
# Processing message from: Sara at 13.09.2024
# Processing message from: Sara at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Amira PS at 13.09.2024
# Processing message from: Karema PS at 13.09.2024
# Processing message from: Eman Ashraf PS at 13.09.2024
# Processing message from: Hasnaa PS at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hoda Salim PS at 13.09.2024
# Processing message from: Karema PS at 13.09.2024
# Processing message from: Amira PS at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Amira PS at 13.09.2024
# Processing message from: Amira PS at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Tarek at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Tarek at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Tarek at 13.09.2024
# Processing message from: Tarek at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hasnaa PS at 13.09.2024
# Processing message from: Hüsam at 13.09.2024
# Line not matched:
# Line not matched: - حاجات بسيطة فاضلة ع ال recursion
# Line not matched: - ⁠هنبدأ ف ال searching algos
# Line not matched:
# Line not matched: - مش لاقي فيديو ف MIT بيشرح searching لو حد لاقاه يبعتلي نضيفه
# Line not matched:
# Line not matched: - الديدلاين يوم ١٤
# Line not matched: - اخر حاجة واهم حاجة صديقنا @905314084287 عمل سكريبت بيشوف مين قال done ويفلتر ويجيبلي ارقام الباقي ع نركبّهم القطر، ف شدو حيلكو شوية ع حاسس بتخاذل الفترة ال فاتت
# Line not matched:
# Line not matched: الديدلاين والريسورسز هنا
# Line not matched: https://delicious-caraway-75c.notion.site/f713b73ec88d41e0a8529d729fe7a8db?v=e6e8bc1ee4f5423f838e39dc9c28352b&pvs=74
# Processing message from: Tarek at 13.09.2024
# Line not matched: ‎[13.09.2024, 03:52:24] Hüsam: ‎sticker omitted
# Line not matched: ‎[13.09.2024, 03:52:26] Hüsam: ‎sticker omitted
# Processing message from: Hüsam at 13.09.2024
# Processing message from: Hasnaa PS at 13.09.2024
# Processing message from: Manar PS at 13.09.2024
# Line not matched: ‎[13.09.2024, 03:59:31] Manar PS: ‎sticker omitted
# Processing message from: Ali Ismail at 13.09.2024
# Processing message from: Shahd Tamer PS at 13.09.2024
# Processing message from: Abdelhadi PS at 13.09.2024
# Processing message from: Youssef Yousry PS at 13.09.2024
# Processing message from: Zeyad at 13.09.2024
# Processing message from: 𝓐𝓁𝒶𝒶 PS at 13.09.2024
# Processing message from: Younes PS at 13.09.2024
# Processing message from: Ahmed Salman PS at 13.09.2024
# Processing message from: TURBO PS at 13.09.2024
# Processing message from: Shaimaa at 13.09.2024
# Processing message from: A7 Hmd PS at 13.09.2024
# Processing message from: Os!Rabe3 PS at 13.09.2024
# Processing message from: Yos S3D Twtr at 13.09.2024
# Processing message from: 𓂆 PS at 13.09.2024
# Processing message from: Salah Mohamed Twtr at 13.09.2024
# Processing message from: Mariam Osman PS at 13.09.2024
# Processing message from: Karema PS at 13.09.2024
# Processing message from: Tarek at 13.09.2024
# Processing message from: Mai Samir PS at 13.09.2024
# Processing message from: Hüsam at 14.09.2024
# Line not matched: مساء الخير يولاد، الديدلاين جه
# Line not matched: ياريت نركز ف الكلمتين دول
# Line not matched: ١. ال بعت done يبعت تاني عشان هنحاسب من دلوقت
# Line not matched: ٢. ⁠هتبعت مسدج واحدة فيها “done” اي حاجة غير كدا invalid
# Line not matched: ٣. ⁠من دلوقت لحد بكرة ١٢ بالليل بنبعت done وبعدها بنركب القطر
# Line not matched:
# Line not matched:
# Line not matched: بشكر @905314084287 تاني ع الاسكريبت ال انقذ حياتي (حرفيا) وهيختصر وقت كتير ❤️
# Processing message from: Mennatallah at 14.09.2024
# Processing message from: Zeyad at 14.09.2024
# Processing message from: Shaimaa at 14.09.2024
# Processing message from: Ali Ismail at 14.09.2024
# Processing message from: Yos S3D Twtr at 14.09.2024
# Processing message from: Mai Samir PS at 14.09.2024
# Processing message from: Abdelhadi PS at 14.09.2024
# Processing message from: * PS at 14.09.2024
# Processing message from: Manar PS at 14.09.2024
# Processing message from: NourEldien Alsharif PS at 14.09.2024
# Processing message from: NourEldien Alsharif PS at 14.09.2024
# Processing message from: Nada Fahmy PS at 14.09.2024
# Processing message from: Karema PS at 14.09.2024
# Processing message from: A7 Hmd PS at 14.09.2024
# Processing message from: Asma 🪄 at 14.09.2024
# Processing message from: Eman Ashraf PS at 14.09.2024
# Processing message from: 𓂆 PS at 14.09.2024
# Processing message from: Elknz PS at 14.09.2024
# Processing message from: Ahmed Salman PS at 14.09.2024
# Processing message from: Mohamed Rabee PS at 14.09.2024
# Processing message from: Salah Mohamed Twtr at 14.09.2024
# Processing message from: رُفَيده سَعْد PS at 14.09.2024
# Processing message from: Ayash PS at 14.09.2024
# Processing message from: Shahd Tamer PS at 14.09.2024
# Processing message from: Amany Mohammed PS at 14.09.2024
# Processing message from: Ahmed Elkassrawy PS at 14.09.2024
# Processing message from: Zeyad Albadawy PS at 14.09.2024
# Processing message from: Hasnaa PS at 14.09.2024
# Processing message from: Hüsam at 14.09.2024
# Line not matched: just write “done” in a message
# Processing message from: Mahmoud Elsheemy PS at 14.09.2024
# Processing message from: Ahmed Hesham at 14.09.2024
# Processing message from: Ahmed Abdelsamie PS at 14.09.2024
# Processing message from: Os!Rabe3 PS at 14.09.2024
# Processing message from: Ahmed Mounir PS at 14.09.2024
# Processing message from: Esraa at 14.09.2024
# Processing message from: * PS at 14.09.2024
# Processing message from: PS-StudyingAlgos 📚 at 15.09.2024
# Processing message from: رِيمُو PS at 15.09.2024
# Processing message from: 𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚 at 15.09.2024
# Processing message from: Hüsam at 15.09.2024
# Processing message from: Hüsam at 15.09.2024
# Line not matched:
# Line not matched: هنذاكر شوية sorting و matrix ع خفيف و greedy حبتين حلوين
# Line not matched:
# Line not matched: المطلوب هنا
# Line not matched: https://delicious-caraway-75c.notion.site/f713b73ec88d41e0a8529d729fe7a8db?v=e6e8bc1ee4f5423f838e39dc9c28352b&pvs=74
# Line not matched:
# Line not matched: الديدلاين يوم ٣٠
# Line not matched:
# Line not matched: تقريبا دا اطول ديدلاين ف
# Line not matched: I will make sure to remove the ones who did not study ‎<This message was edited>
# Processing message from: ‎You at 15.09.2024
# Processing message from: PS-StudyingAlgos 📚 at 15.09.2024
# Processing message from: Gehad PS at 15.09.2024
# Processing message from: PS-StudyingAlgos 📚 at 15.09.2024
# Processing message from: Motaz PS at 15.09.2024
# Processing message from: Mariam Osman PS at 15.09.2024
# Processing message from: Amira PS at 15.09.2024
#
# Group members who sent messages between 18.08.2024 and 17.09.2024:
# "* PS",
# ". PS",
# "A7 Hmd PS",
# "Abdelhadi PS",
# "Abdelrahman Karim",
# "Ahmed Abdelsamie PS",
# "Ahmed Elkassrawy PS",
# "Ahmed Hesham",
# "Ahmed Jamal Sultan PS",
# "Ahmed Mohamed Badran",
# "Ahmed Mounir PS",
# "Ahmed Salman PS",
# "Ali Ismail",
# "Amal Eltelbany PS",
# "Amany Mohammed PS",
# "Amira PS",
# "Asma 🪄",
# "Asmaa",
# "Ayash PS",
# "Aysha",
# "BΛSΛNT",
# "David PS",
# "Elknz PS",
# "Eman Ashraf PS",
# "Esraa",
# "Esraa Alaa",
# "Gehad PS",
# "Gehad🌺",
# "Habiba Gamal PS",
# "Hadi Heikal PS",
# "Hasnaa PS",
# "Hoda Salim PS",
# "Hüsam",
# "Ichraf 🤓👩‍💻",
# "KHALED𓂆",
# "Karema PS",
# "MGamal",
# "MORo",
# "Mahmoud",
# "Mahmoud Elsheemy PS",
# "Mai Samir PS",
# "Manar PS",
# "Mariam Osman PS",
# "Mennatallah",
# "Minno",
# "Mohamed Rabee PS",
# "Motaz PS",
# "Nada Fahmy PS",
# "Nada Osama",
# "NourEldien Alsharif PS",
# "Omnia Ashraf PS",
# "Omnia PS",
# "Omr PS",
# "Os!Rabe3 PS",
# "PS-StudyingAlgos 📚",
# "Salah Mohamed Twtr",
# "Sara",
# "Shahd Tamer PS",
# "Shaimaa",
# "TURBO PS",
# "Tarek",
# "Wafaa",
# "Yos S3D Twtr",
# "Younes PS",
# "Youssef Yousry PS",
# "Zeyad",
# "Zeyad Albadawy PS",
# "Ziad Nasser PS",
# "mahmoud elshony",
# "أَدْهَم عَلَّاَم PS",
# "رُفَيده سَعْد PS",
# "رِيمُو PS",
# "‎You",
# "𓂆 PS",
# "𝐈𝐬𝐥𝐚𝐦 𝐆𝐨𝐦𝐚𝐚",
# "𝓐𝓁𝒶𝒶 PS",
